# %%
import os
import requests
import json
import csv
from collections import Counter
from itertools import combinations
import pandas as pd
import re
import unicodedata
import dotenv

# %%
dotenv.load_dotenv()

# %%
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
if not GITHUB_TOKEN:
    raise RuntimeError("GITHUB_TOKEN is not set; create a .env with GITHUB_TOKEN=<token>")

# %%
github_url = "https://api.github.com/graphql"

# %%
session = requests.Session()
session.headers.update(
    {
        "Authorization": f"Bearer {GITHUB_TOKEN}",
        "Content-Type": "application/json"
    }
)

# %%
# Simple test query to verify API connection
query = """
{
  viewer {
    login
    name
    repositories(first: 5) {
      nodes {
        name
        url
        description
      }
    }
  }
}
"""

# Send the query
response = session.post(github_url, json={"query": query})
print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: {'data': {'viewer': {'login': 'Grim2Hot', 'name': 'Alexander Sweet', 'repositories': {'nodes': [{'name': 'NI_Tests', 'url': 'https://github.com/Grim2Hot/NI_Tests', 'description': 'Testing Ground for Implementing Features for NI'}, {'name': 'pytrade_bot', 'url': 'https://github.com/Grim2Hot/pytrade_bot', 'description': 'An exploration into algo-trading using Statistics and (hopefully) Machine Learning in Python.'}, {'name': 'uni_work', 'url': 'https://github.com/KeilanEvans/uni_work', 'description': None}, {'name': 'ML-For-Beginners', 'url': 'https://github.com/Grim2Hot/ML-For-Beginners', 'description': '12 weeks, 26 lessons, 52 quizzes, classic Machine Learning for all'}, {'name': 'ai-agents-for-beginners', 'url': 'https://github.com/Grim2Hot/ai-agents-for-beginners', 'description': '10 Lessons to Get Started Building AI Agents'}]}}}}

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "data": {
#     "viewer": {
#       "login": "Grim2Hot",
#       "name": "Alexander Sweet",
#       "repositories": {
#         "nodes": [
#           {
#             "name": "NI_Tests",
#             "url": "https://github.com/Grim2Hot/NI_Tests",
#             "description": "Testing Ground for Implementing Features for NI"
#           },
#           {
#             "name": "pytrade_bot",
#             "url": "https://github.com/Grim2Hot/pytrade_bot",
#             "description": "An exploration into algo-trading using Statistics and (hopefully) Machine Learning in Python."
#           },
#           {
#             "name": "uni_work",
#             "url": "https://github.com/KeilanEvans/uni_work",
#             "description": null
#           },
#           {
#             "name": "ML-For-Beginners",
#             "url": "https://github.com/Grim2Hot/ML-For-Beginners",
#             "description": "12 weeks, 26 lessons, 52 quizzes, classic Machine Learning for all"
#           },
#           {
#             "name": "ai-agents-for-beginners",
#             "url": "https://github.com/Grim2Hot/ai-agents-for-beginners",
#             "description": "10 Lessons to Get Started Building AI Agents"
#           }
#         ]
#       }
#     }
#   }
# }

# %%
# Create a request for issues
issue_query = """
{
  repository(owner: "huggingface", name: "transformers") {
    issues(last: 100, states: OPEN) {
      nodes {
        title
        url
        createdAt
        author { 
            ... on User {
                login
                url
                location
            }
        }
      }
    }
  }
}
"""

response = session.post(github_url, json={"query": issue_query})
print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
print(json.dumps(response.json(), indent=2) )
# Out:
# {
#   "data": {
#     "repository": {
#       "issues": {
#         "nodes": [
#           {
#             "title": "All vitpose model were brokentransformers/models/vitpose_",
#             "url": "https://github.com/huggingface/transformers/issues/42222",
#             "createdAt": "2025-11-15T14:56:04Z",
#             "author": {
#               "login": "lucasjinreal",
#               "url": "https://github.com/lucasjinreal",
#               "location": "Sanfancisco"
#             }
#           },
#           {
#             "title": "`parse_response` should drop EOS",
#             "url": "https://github.com/huggingface/transformers/issues/42249",
#             "createdAt": "2025-11-17T18:14:56Z",
#             "author": {
#               "login": "qgallouedec",
#               "url": "https://github.com/qgallouedec",
#               "location": "Canada"
#             }
#           },
#           {
#             "title": "How to fine-tune SAM 3D models?",
#             "url": "https://github.com/huggingface/transformers/issues/42344",
#             "createdAt": "2025-11-23T17:40:57Z",
#             "author": {
#               "login": "bruno686",
#               "url": "https://github.com/bruno686",
#               "location": null
#             }
#           },
#           {
#             "title": "SAM3 single image inference with multiple text prompt",
#             "url": "https://github.com/huggingface/transformers/issues/42375",
#             "createdAt": "2025-11-25T06:20:09Z",
#             "author": {
#               "login": "iariav",
#               "url": "https://github.com/iariav",
#               "location": null
#             }
#           },
#           {
#             "title": "ValueError: Unrecognized model in OrdalieTech/Solon-embeddings-large-0.1. Should have a `model_type` key in its config.json",
#             "url": "https://github.com/huggingface/transformers/issues/42381",
#             "createdAt": "2025-11-25T08:54:07Z",
#             "author": {
#               "login": "vador31",
#               "url": "https://github.com/vador31",
#               "location": "Toulouse - France"
#             }
#           },
#           {
#             "title": "LlamaRMSNorm and equivalent module implementations using torch ops",
#             "url": "https://github.com/huggingface/transformers/issues/42398",
#             "createdAt": "2025-11-25T16:17:25Z",
#             "author": {
#               "login": "mstojkovicTT",
#               "url": "https://github.com/mstojkovicTT",
#               "location": null
#             }
#           },
#           {
#             "title": "The `get_(text|image|audio|video)_features` methods have inconsistent output formats, needs aligning for Sentence Transformers",
#             "url": "https://github.com/huggingface/transformers/issues/42401",
#             "createdAt": "2025-11-25T16:37:20Z",
#             "author": {
#               "login": "tomaarsen",
#               "url": "https://github.com/tomaarsen",
#               "location": "Netherlands"
#             }
#           },
#           {
#             "title": "Integrate FA4 (Flash Attention for Blackwell) into HF Transformers",
#             "url": "https://github.com/huggingface/transformers/issues/42405",
#             "createdAt": "2025-11-25T17:33:50Z",
#             "author": {
#               "login": "sambhavnoobcoder",
#               "url": "https://github.com/sambhavnoobcoder",
#               "location": "Bhopal,India"
#             }
#           },
#           {
#             "title": "Custom nn.Parameter initialization in PreTrainedModel subclasses is overwritten by post_init()/from_pretrained() causing NaNs/Zeros",
#             "url": "https://github.com/huggingface/transformers/issues/42418",
#             "createdAt": "2025-11-26T10:29:57Z",
#             "author": {
#               "login": "Noietch",
#               "url": "https://github.com/Noietch",
#               "location": null
#             }
#           },
#           {
#             "title": "Performance Improvement: Avoid host\u2194device synchronizations caused by tensor-to-Python conversions and certain tensor ops",
#             "url": "https://github.com/huggingface/transformers/issues/42422",
#             "createdAt": "2025-11-26T13:45:10Z",
#             "author": {
#               "login": "Dhruv88",
#               "url": "https://github.com/Dhruv88",
#               "location": null
#             }
#           },
#           {
#             "title": "StaticCache crashes when the batch-size changes",
#             "url": "https://github.com/huggingface/transformers/issues/42454",
#             "createdAt": "2025-11-27T13:37:58Z",
#             "author": {
#               "login": "mobicham",
#               "url": "https://github.com/mobicham",
#               "location": "Berlin, Germany"
#             }
#           },
#           {
#             "title": "Add SAM 3D Objects Encoder",
#             "url": "https://github.com/huggingface/transformers/issues/42464",
#             "createdAt": "2025-11-27T19:48:28Z",
#             "author": {
#               "login": "Aznix07",
#               "url": "https://github.com/Aznix07",
#               "location": null
#             }
#           },
#           {
#             "title": "now transformers is support Rust ,why not to develop java /scala3",
#             "url": "https://github.com/huggingface/transformers/issues/42469",
#             "createdAt": "2025-11-28T10:46:40Z",
#             "author": {
#               "login": "mullerhai",
#               "url": "https://github.com/mullerhai",
#               "location": null
#             }
#           },
#           {
#             "title": "The LoRA model trained with qwen3_moe on hf4.x cannot be used on the current main branch (hf5.x).",
#             "url": "https://github.com/huggingface/transformers/issues/42491",
#             "createdAt": "2025-11-29T03:57:15Z",
#             "author": {
#               "login": "B-201",
#               "url": "https://github.com/B-201",
#               "location": null
#             }
#           },
#           {
#             "title": "Automatic Speech Recognition pipline raises error when torchcodec is installed but not valid",
#             "url": "https://github.com/huggingface/transformers/issues/42499",
#             "createdAt": "2025-12-01T01:06:36Z",
#             "author": {
#               "login": "litagin02",
#               "url": "https://github.com/litagin02",
#               "location": null
#             }
#           },
#           {
#             "title": "Add ModernVBERT models",
#             "url": "https://github.com/huggingface/transformers/issues/42503",
#             "createdAt": "2025-12-01T08:33:46Z",
#             "author": {
#               "login": "paultltc",
#               "url": "https://github.com/paultltc",
#               "location": "San Francisco"
#             }
#           },
#           {
#             "title": "gpt-oss is not working with flash-attention",
#             "url": "https://github.com/huggingface/transformers/issues/42533",
#             "createdAt": "2025-12-01T17:26:09Z",
#             "author": {
#               "login": "avihu111",
#               "url": "https://github.com/avihu111",
#               "location": "Tel Aviv, Israel"
#             }
#           },
#           {
#             "title": "Error with text generation pipeline in v5",
#             "url": "https://github.com/huggingface/transformers/issues/42539",
#             "createdAt": "2025-12-02T01:50:32Z",
#             "author": {
#               "login": "davidmezzetti",
#               "url": "https://github.com/davidmezzetti",
#               "location": " Washington, DC Metro "
#             }
#           },
#           {
#             "title": "cannot import name 'PreTrainedModel' from 'transformers'",
#             "url": "https://github.com/huggingface/transformers/issues/42548",
#             "createdAt": "2025-12-02T09:10:32Z",
#             "author": {
#               "login": "missTL",
#               "url": "https://github.com/missTL",
#               "location": "china"
#             }
#           },
#           {
#             "title": "Parallelize the model download with the weight loading",
#             "url": "https://github.com/huggingface/transformers/issues/42559",
#             "createdAt": "2025-12-02T14:34:02Z",
#             "author": {
#               "login": "LysandreJik",
#               "url": "https://github.com/LysandreJik",
#               "location": "Paris"
#             }
#           },
#           {
#             "title": "Error with Kyutai Speech-To-Text inference",
#             "url": "https://github.com/huggingface/transformers/issues/42581",
#             "createdAt": "2025-12-03T03:29:46Z",
#             "author": {
#               "login": "alien-0119",
#               "url": "https://github.com/alien-0119",
#               "location": null
#             }
#           },
#           {
#             "title": "bug in Mistral3",
#             "url": "https://github.com/huggingface/transformers/issues/42585",
#             "createdAt": "2025-12-03T09:46:17Z",
#             "author": {
#               "login": "foldl",
#               "url": "https://github.com/foldl",
#               "location": null
#             }
#           },
#           {
#             "title": "model type `deepseek_v32`",
#             "url": "https://github.com/huggingface/transformers/issues/42590",
#             "createdAt": "2025-12-03T11:02:16Z",
#             "author": {
#               "login": "fernandaspets",
#               "url": "https://github.com/fernandaspets",
#               "location": null
#             }
#           },
#           {
#             "title": "Ministral-3-3B-Instruct-2512-ONNX does not work on Electron",
#             "url": "https://github.com/huggingface/transformers/issues/42608",
#             "createdAt": "2025-12-03T19:30:08Z",
#             "author": {
#               "login": "abdullah-cod9",
#               "url": "https://github.com/abdullah-cod9",
#               "location": "Iraq"
#             }
#           },
#           {
#             "title": "Not able to run 3d_parallel.py",
#             "url": "https://github.com/huggingface/transformers/issues/42617",
#             "createdAt": "2025-12-04T10:14:17Z",
#             "author": {
#               "login": "quic-meetkuma",
#               "url": "https://github.com/quic-meetkuma",
#               "location": null
#             }
#           },
#           {
#             "title": "Routing Replay for MoEs",
#             "url": "https://github.com/huggingface/transformers/issues/42638",
#             "createdAt": "2025-12-04T23:58:14Z",
#             "author": {
#               "login": "qgallouedec",
#               "url": "https://github.com/qgallouedec",
#               "location": "Canada"
#             }
#           },
#           {
#             "title": "Cannot inference llava-next with transformers==4.57.1 on dtype=\"auto\" bug",
#             "url": "https://github.com/huggingface/transformers/issues/42641",
#             "createdAt": "2025-12-05T04:39:35Z",
#             "author": {
#               "login": "rebel-seinpark",
#               "url": "https://github.com/rebel-seinpark",
#               "location": null
#             }
#           },
#           {
#             "title": "Processor's attribute is mis-detected for child class from #41633",
#             "url": "https://github.com/huggingface/transformers/issues/42645",
#             "createdAt": "2025-12-05T10:02:24Z",
#             "author": {
#               "login": "MilkClouds",
#               "url": "https://github.com/MilkClouds",
#               "location": null
#             }
#           },
#           {
#             "title": "Voxtral ASR Pipeline Integration Broken in 4.57.3",
#             "url": "https://github.com/huggingface/transformers/issues/42656",
#             "createdAt": "2025-12-05T15:15:19Z",
#             "author": {
#               "login": "juzhxng",
#               "url": "https://github.com/juzhxng",
#               "location": null
#             }
#           },
#           {
#             "title": "Potential bug in Trainer+Accelerate integration",
#             "url": "https://github.com/huggingface/transformers/issues/42658",
#             "createdAt": "2025-12-05T15:53:33Z",
#             "author": {
#               "login": "quic-meetkuma",
#               "url": "https://github.com/quic-meetkuma",
#               "location": null
#             }
#           },
#           {
#             "title": "SAM3 Loss",
#             "url": "https://github.com/huggingface/transformers/issues/42659",
#             "createdAt": "2025-12-05T16:10:04Z",
#             "author": {
#               "login": "aselimc",
#               "url": "https://github.com/aselimc",
#               "location": null
#             }
#           },
#           {
#             "title": "TrainingArguments does not process fsdp arguments correctly",
#             "url": "https://github.com/huggingface/transformers/issues/42664",
#             "createdAt": "2025-12-05T16:34:23Z",
#             "author": {
#               "login": "quic-meetkuma",
#               "url": "https://github.com/quic-meetkuma",
#               "location": null
#             }
#           },
#           {
#             "title": "Qwen3ForCausalLM leaks VRAM if used in multiple dataloader threads",
#             "url": "https://github.com/huggingface/transformers/issues/42673",
#             "createdAt": "2025-12-06T09:01:40Z",
#             "author": {
#               "login": "dxqb",
#               "url": "https://github.com/dxqb",
#               "location": null
#             }
#           },
#           {
#             "title": "Missing imports for DetrLoss and DetrHungarianMatcher",
#             "url": "https://github.com/huggingface/transformers/issues/42674",
#             "createdAt": "2025-12-06T15:32:14Z",
#             "author": {
#               "login": "sammlapp",
#               "url": "https://github.com/sammlapp",
#               "location": "Pittsburgh"
#             }
#           },
#           {
#             "title": "Conditional DETR's `post_process_semantic_segmentation` removes one class",
#             "url": "https://github.com/huggingface/transformers/issues/42679",
#             "createdAt": "2025-12-07T01:29:01Z",
#             "author": {
#               "login": "simonreise",
#               "url": "https://github.com/simonreise",
#               "location": null
#             }
#           },
#           {
#             "title": "How to run Phi4MultimodalProcessor",
#             "url": "https://github.com/huggingface/transformers/issues/42690",
#             "createdAt": "2025-12-08T03:27:02Z",
#             "author": {
#               "login": "wcrzlh",
#               "url": "https://github.com/wcrzlh",
#               "location": "New York, U.S."
#             }
#           },
#           {
#             "title": "Some questions about the apply_multimodal_rotary_pos_emb function.",
#             "url": "https://github.com/huggingface/transformers/issues/42694",
#             "createdAt": "2025-12-08T08:24:06Z",
#             "author": {
#               "login": "Dyb3438",
#               "url": "https://github.com/Dyb3438",
#               "location": "Singapore, Singapore"
#             }
#           },
#           {
#             "title": "parse_response must not accept detokenized text",
#             "url": "https://github.com/huggingface/transformers/issues/42698",
#             "createdAt": "2025-12-08T12:20:39Z",
#             "author": {
#               "login": "kibergus",
#               "url": "https://github.com/kibergus",
#               "location": "London"
#             }
#           },
#           {
#             "title": "Outstanding issues / PR before we can release v5",
#             "url": "https://github.com/huggingface/transformers/issues/42710",
#             "createdAt": "2025-12-08T16:57:54Z",
#             "author": {
#               "login": "ArthurZucker",
#               "url": "https://github.com/ArthurZucker",
#               "location": "France"
#             }
#           },
#           {
#             "title": "Ensure that `OneFormerProcessor` place text `task_inputs` to the same device as other inputs",
#             "url": "https://github.com/huggingface/transformers/issues/42722",
#             "createdAt": "2025-12-08T22:56:29Z",
#             "author": {
#               "login": "simonreise",
#               "url": "https://github.com/simonreise",
#               "location": null
#             }
#           },
#           {
#             "title": "convert trocr to onnx",
#             "url": "https://github.com/huggingface/transformers/issues/42726",
#             "createdAt": "2025-12-09T06:28:28Z",
#             "author": {
#               "login": "cqray1990",
#               "url": "https://github.com/cqray1990",
#               "location": null
#             }
#           },
#           {
#             "title": "the training crashes at logging_steps when running on a single GPU",
#             "url": "https://github.com/huggingface/transformers/issues/42728",
#             "createdAt": "2025-12-09T07:22:13Z",
#             "author": {
#               "login": "gouchangjiang",
#               "url": "https://github.com/gouchangjiang",
#               "location": "Hangzhou China"
#             }
#           },
#           {
#             "title": "BERT-like models with RoPE",
#             "url": "https://github.com/huggingface/transformers/issues/42738",
#             "createdAt": "2025-12-09T11:30:40Z",
#             "author": {
#               "login": "hmellor",
#               "url": "https://github.com/hmellor",
#               "location": null
#             }
#           },
#           {
#             "title": "how to train trocr with transformers 4.57+?",
#             "url": "https://github.com/huggingface/transformers/issues/42740",
#             "createdAt": "2025-12-09T14:07:50Z",
#             "author": {
#               "login": "cqray1990",
#               "url": "https://github.com/cqray1990",
#               "location": null
#             }
#           },
#           {
#             "title": "Excluding weight decay not working properly on most LMs",
#             "url": "https://github.com/huggingface/transformers/issues/42754",
#             "createdAt": "2025-12-10T00:36:55Z",
#             "author": {
#               "login": "wwt17",
#               "url": "https://github.com/wwt17",
#               "location": null
#             }
#           },
#           {
#             "title": "Add support for Microsoft VibeVoice models",
#             "url": "https://github.com/huggingface/transformers/issues/42758",
#             "createdAt": "2025-12-10T04:19:25Z",
#             "author": {
#               "login": "AliBagheriNejad",
#               "url": "https://github.com/AliBagheriNejad",
#               "location": null
#             }
#           },
#           {
#             "title": "output_hidden_states is not working correctly with SiglipModel class",
#             "url": "https://github.com/huggingface/transformers/issues/42759",
#             "createdAt": "2025-12-10T06:59:18Z",
#             "author": {
#               "login": "hamzaakyildiz",
#               "url": "https://github.com/hamzaakyildiz",
#               "location": null
#             }
#           },
#           {
#             "title": "Support `BatchFeature` in `LengthGroupedSampler` for Multimodal compatibility",
#             "url": "https://github.com/huggingface/transformers/issues/42760",
#             "createdAt": "2025-12-10T07:31:01Z",
#             "author": {
#               "login": "npurson",
#               "url": "https://github.com/npurson",
#               "location": "Shanghai, China"
#             }
#           },
#           {
#             "title": "Generation config merging logic prevents explicit override of model-specific defaults back to global defaults",
#             "url": "https://github.com/huggingface/transformers/issues/42762",
#             "createdAt": "2025-12-10T08:11:35Z",
#             "author": {
#               "login": "albertvillanova",
#               "url": "https://github.com/albertvillanova",
#               "location": "Paris (France)"
#             }
#           },
#           {
#             "title": "FSDP of Trainer does not work well with Accelerate",
#             "url": "https://github.com/huggingface/transformers/issues/42771",
#             "createdAt": "2025-12-10T12:54:49Z",
#             "author": {
#               "login": "gouchangjiang",
#               "url": "https://github.com/gouchangjiang",
#               "location": "Hangzhou China"
#             }
#           },
#           {
#             "title": "Why the use of masked_fill",
#             "url": "https://github.com/huggingface/transformers/issues/42789",
#             "createdAt": "2025-12-11T01:32:07Z",
#             "author": {
#               "login": "tanmay2004",
#               "url": "https://github.com/tanmay2004",
#               "location": null
#             }
#           },
#           {
#             "title": "Add support for GPT_OSS with tp_plan or enable native tensor parallelism",
#             "url": "https://github.com/huggingface/transformers/issues/42791",
#             "createdAt": "2025-12-11T04:31:19Z",
#             "author": {
#               "login": "quic-akuruvil",
#               "url": "https://github.com/quic-akuruvil",
#               "location": null
#             }
#           },
#           {
#             "title": "Ministral-3-8B-Instruct tokenizer doesn't handle BPE markers properly",
#             "url": "https://github.com/huggingface/transformers/issues/42796",
#             "createdAt": "2025-12-11T07:35:35Z",
#             "author": {
#               "login": "yanancai",
#               "url": "https://github.com/yanancai",
#               "location": "Seattle, WA"
#             }
#           },
#           {
#             "title": "[`Quantization FP8`] Native `from_config` support",
#             "url": "https://github.com/huggingface/transformers/issues/42804",
#             "createdAt": "2025-12-11T10:17:47Z",
#             "author": {
#               "login": "vasqu",
#               "url": "https://github.com/vasqu",
#               "location": null
#             }
#           },
#           {
#             "title": "Remove unnessary `requests` module",
#             "url": "https://github.com/huggingface/transformers/issues/42817",
#             "createdAt": "2025-12-11T15:35:59Z",
#             "author": {
#               "login": "CoderTCY",
#               "url": "https://github.com/CoderTCY",
#               "location": null
#             }
#           },
#           {
#             "title": "Support batched torch Tensors in ASTFeatureExtractor",
#             "url": "https://github.com/huggingface/transformers/issues/42821",
#             "createdAt": "2025-12-11T19:58:41Z",
#             "author": {
#               "login": "psu-om",
#               "url": "https://github.com/psu-om",
#               "location": null
#             }
#           },
#           {
#             "title": "Accuracy issue associated with FineGrainedFP8",
#             "url": "https://github.com/huggingface/transformers/issues/42831",
#             "createdAt": "2025-12-12T07:47:42Z",
#             "author": {
#               "login": "sunghyuckhong",
#               "url": "https://github.com/sunghyuckhong",
#               "location": null
#             }
#           },
#           {
#             "title": "Question about tie_weights",
#             "url": "https://github.com/huggingface/transformers/issues/42832",
#             "createdAt": "2025-12-12T07:52:43Z",
#             "author": {
#               "login": "cjw-d",
#               "url": "https://github.com/cjw-d",
#               "location": null
#             }
#           },
#           {
#             "title": "Numeric values are not properly decoded in PaddleOCR-VL outputs",
#             "url": "https://github.com/huggingface/transformers/issues/42859",
#             "createdAt": "2025-12-13T16:18:12Z",
#             "author": {
#               "login": "passing2961",
#               "url": "https://github.com/passing2961",
#               "location": "Daejeon"
#             }
#           },
#           {
#             "title": "Tokenizer fails to load from cache when HF_HUB_OFFLINE=1 on 4.57.3",
#             "url": "https://github.com/huggingface/transformers/issues/42886",
#             "createdAt": "2025-12-15T23:17:06Z",
#             "author": {
#               "login": "chtruong814",
#               "url": "https://github.com/chtruong814",
#               "location": null
#             }
#           },
#           {
#             "title": "Divergence in UMT T5 Encoder numerical values from v4.57.3 to v5.0.0.rc*",
#             "url": "https://github.com/huggingface/transformers/issues/42889",
#             "createdAt": "2025-12-16T08:11:44Z",
#             "author": {
#               "login": "SolitaryThinker",
#               "url": "https://github.com/SolitaryThinker",
#               "location": null
#             }
#           },
#           {
#             "title": "tests/models/sam_hq/test_modeling_sam_hq.py::SamHQModelIntegrationTest may fail since a lot of cases are lack of set_seed()",
#             "url": "https://github.com/huggingface/transformers/issues/42890",
#             "createdAt": "2025-12-16T08:22:52Z",
#             "author": {
#               "login": "sywangyi",
#               "url": "https://github.com/sywangyi",
#               "location": "Shanghai, China"
#             }
#           },
#           {
#             "title": "`clean_up_tokenization_spaces` behavior changes in v5",
#             "url": "https://github.com/huggingface/transformers/issues/42898",
#             "createdAt": "2025-12-16T11:34:46Z",
#             "author": {
#               "login": "apaniukov",
#               "url": "https://github.com/apaniukov",
#               "location": null
#             }
#           },
#           {
#             "title": "Improve GPT OSS Conversion Script",
#             "url": "https://github.com/huggingface/transformers/issues/42902",
#             "createdAt": "2025-12-16T12:46:20Z",
#             "author": {
#               "login": "KyleMylonakisProtopia",
#               "url": "https://github.com/KyleMylonakisProtopia",
#               "location": "London, UK"
#             }
#           },
#           {
#             "title": "Failing to Save Dequantized Ministrals/Devstrals",
#             "url": "https://github.com/huggingface/transformers/issues/42907",
#             "createdAt": "2025-12-16T16:21:17Z",
#             "author": {
#               "login": "pandora-s-git",
#               "url": "https://github.com/pandora-s-git",
#               "location": null
#             }
#           },
#           {
#             "title": "Qwen2VLImageProcessor not respecting Qwen3VL config",
#             "url": "https://github.com/huggingface/transformers/issues/42910",
#             "createdAt": "2025-12-16T19:29:26Z",
#             "author": {
#               "login": "opherlieber",
#               "url": "https://github.com/opherlieber",
#               "location": "United States"
#             }
#           },
#           {
#             "title": "Unexpected tokenizer behavior difference from v4 to v5",
#             "url": "https://github.com/huggingface/transformers/issues/42913",
#             "createdAt": "2025-12-16T22:14:01Z",
#             "author": {
#               "login": "awni",
#               "url": "https://github.com/awni",
#               "location": "United States"
#             }
#           },
#           {
#             "title": "[Tokenizer][OFFLINE] chat_template.jinja not downloaded in cache",
#             "url": "https://github.com/huggingface/transformers/issues/42914",
#             "createdAt": "2025-12-16T22:35:31Z",
#             "author": {
#               "login": "khatrimann",
#               "url": "https://github.com/khatrimann",
#               "location": "Gurgaon"
#             }
#           },
#           {
#             "title": "Qwen3Moe failed with FineGrainedFP8Config",
#             "url": "https://github.com/huggingface/transformers/issues/42915",
#             "createdAt": "2025-12-17T07:35:47Z",
#             "author": {
#               "login": "jessiewiswjc",
#               "url": "https://github.com/jessiewiswjc",
#               "location": null
#             }
#           },
#           {
#             "title": "Mask2former model's ignore_value not used after definition",
#             "url": "https://github.com/huggingface/transformers/issues/42936",
#             "createdAt": "2025-12-17T22:44:36Z",
#             "author": {
#               "login": "mhmd-j",
#               "url": "https://github.com/mhmd-j",
#               "location": null
#             }
#           },
#           {
#             "title": "Continuous batching: output queue requeue starvation and request-scoped iterator does not terminate on completion",
#             "url": "https://github.com/huggingface/transformers/issues/42943",
#             "createdAt": "2025-12-18T11:35:58Z",
#             "author": {
#               "login": "pythongiant",
#               "url": "https://github.com/pythongiant",
#               "location": "India"
#             }
#           },
#           {
#             "title": "Gradient Checkpointing Ineffective with PEFT LoRA Despite Proper Configuration",
#             "url": "https://github.com/huggingface/transformers/issues/42947",
#             "createdAt": "2025-12-18T19:10:03Z",
#             "author": {
#               "login": "yurkoff-mv",
#               "url": "https://github.com/yurkoff-mv",
#               "location": null
#             }
#           },
#           {
#             "title": "XiaoMi MiMo",
#             "url": "https://github.com/huggingface/transformers/issues/42954",
#             "createdAt": "2025-12-19T11:15:41Z",
#             "author": {
#               "login": "ArthurZucker",
#               "url": "https://github.com/ArthurZucker",
#               "location": "France"
#             }
#           },
#           {
#             "title": "`LlavaNextForConditionalGeneration` forward pass broken",
#             "url": "https://github.com/huggingface/transformers/issues/42968",
#             "createdAt": "2025-12-19T21:42:30Z",
#             "author": {
#               "login": "qgallouedec",
#               "url": "https://github.com/qgallouedec",
#               "location": "Canada"
#             }
#           },
#           {
#             "title": "Please create a Huggingface Transformers SKILL for Claude",
#             "url": "https://github.com/huggingface/transformers/issues/42971",
#             "createdAt": "2025-12-20T15:17:03Z",
#             "author": {
#               "login": "Emasoft",
#               "url": "https://github.com/Emasoft",
#               "location": "Rome, Italy"
#             }
#           },
#           {
#             "title": "Add ViT NEPA",
#             "url": "https://github.com/huggingface/transformers/issues/42977",
#             "createdAt": "2025-12-21T05:33:08Z",
#             "author": {
#               "login": "sbucaille",
#               "url": "https://github.com/sbucaille",
#               "location": "Lille"
#             }
#           },
#           {
#             "title": "Change from v4 to v5c1: DeprecationWarning: builtin type SwigPyPacked/Object has no __module__ attribute",
#             "url": "https://github.com/huggingface/transformers/issues/42981",
#             "createdAt": "2025-12-21T19:04:58Z",
#             "author": {
#               "login": "jrp2014",
#               "url": "https://github.com/jrp2014",
#               "location": null
#             }
#           },
#           {
#             "title": "quantized model saving failed",
#             "url": "https://github.com/huggingface/transformers/issues/42994",
#             "createdAt": "2025-12-22T07:35:08Z",
#             "author": {
#               "login": "jiqing-feng",
#               "url": "https://github.com/jiqing-feng",
#               "location": null
#             }
#           },
#           {
#             "title": "is_flash_attn_2_available() gives packaging.version.InvalidVersion: Invalid version: 'N/A'",
#             "url": "https://github.com/huggingface/transformers/issues/42999",
#             "createdAt": "2025-12-22T11:44:51Z",
#             "author": {
#               "login": "dylanprins",
#               "url": "https://github.com/dylanprins",
#               "location": "Amsterdam"
#             }
#           },
#           {
#             "title": "VLM reloaded config provide wrong model_type attribution",
#             "url": "https://github.com/huggingface/transformers/issues/43005",
#             "createdAt": "2025-12-22T15:34:30Z",
#             "author": {
#               "login": "xin3he",
#               "url": "https://github.com/xin3he",
#               "location": null
#             }
#           },
#           {
#             "title": "Cache's (and Layer's) `update(...)` method to be decorated with `@torch.no_grad`",
#             "url": "https://github.com/huggingface/transformers/issues/43010",
#             "createdAt": "2025-12-23T03:08:33Z",
#             "author": {
#               "login": "vadimkantorov",
#               "url": "https://github.com/vadimkantorov",
#               "location": "Paris, France"
#             }
#           },
#           {
#             "title": "`StaticLayer` cache layer to implement `.crop(seq_len)` to match API of `DynamicLayer`",
#             "url": "https://github.com/huggingface/transformers/issues/43011",
#             "createdAt": "2025-12-23T03:13:30Z",
#             "author": {
#               "login": "vadimkantorov",
#               "url": "https://github.com/vadimkantorov",
#               "location": "Paris, France"
#             }
#           },
#           {
#             "title": "Compiling a bfloat16 model triggers float32 precision PyTorch warning",
#             "url": "https://github.com/huggingface/transformers/issues/43012",
#             "createdAt": "2025-12-23T03:59:45Z",
#             "author": {
#               "login": "vadimkantorov",
#               "url": "https://github.com/vadimkantorov",
#               "location": "Paris, France"
#             }
#           },
#           {
#             "title": "Dia model cannot load/ generation error",
#             "url": "https://github.com/huggingface/transformers/issues/43016",
#             "createdAt": "2025-12-23T07:59:41Z",
#             "author": {
#               "login": "jiqing-feng",
#               "url": "https://github.com/jiqing-feng",
#               "location": null
#             }
#           },
#           {
#             "title": "How to investigate \"CAS service error\" during model downloading?",
#             "url": "https://github.com/huggingface/transformers/issues/43023",
#             "createdAt": "2025-12-23T14:48:51Z",
#             "author": {
#               "login": "satyrmipt",
#               "url": "https://github.com/satyrmipt",
#               "location": null
#             }
#           },
#           {
#             "title": "Enable passing block_size and bf16_stochastic_round to torchao optimizers via TrainingArguments",
#             "url": "https://github.com/huggingface/transformers/issues/43025",
#             "createdAt": "2025-12-23T16:30:42Z",
#             "author": {
#               "login": "klae01",
#               "url": "https://github.com/klae01",
#               "location": null
#             }
#           },
#           {
#             "title": "Sequential Sampling",
#             "url": "https://github.com/huggingface/transformers/issues/43026",
#             "createdAt": "2025-12-24T01:48:28Z",
#             "author": {
#               "login": "jiosephlee",
#               "url": "https://github.com/jiosephlee",
#               "location": null
#             }
#           },
#           {
#             "title": "Implementation of Speculative Cascades",
#             "url": "https://github.com/huggingface/transformers/issues/43027",
#             "createdAt": "2025-12-24T04:13:54Z",
#             "author": {
#               "login": "radia78",
#               "url": "https://github.com/radia78",
#               "location": "Madison, WI"
#             }
#           },
#           {
#             "title": "DeepSeek v3.2 support",
#             "url": "https://github.com/huggingface/transformers/issues/43037",
#             "createdAt": "2025-12-25T06:38:29Z",
#             "author": {
#               "login": "freedom-cui",
#               "url": "https://github.com/freedom-cui",
#               "location": null
#             }
#           },
#           {
#             "title": "When using the Liger Kernel, torch.nn.functional.cross_entropy is called",
#             "url": "https://github.com/huggingface/transformers/issues/43039",
#             "createdAt": "2025-12-25T10:55:29Z",
#             "author": {
#               "login": "yurkoff-mv",
#               "url": "https://github.com/yurkoff-mv",
#               "location": null
#             }
#           },
#           {
#             "title": "Single-scale image input support for SAM3 Mask Decoder",
#             "url": "https://github.com/huggingface/transformers/issues/43043",
#             "createdAt": "2025-12-26T04:55:16Z",
#             "author": {
#               "login": "Enq666",
#               "url": "https://github.com/Enq666",
#               "location": "TianJin\uff0cChina"
#             }
#           },
#           {
#             "title": "Multimodal chat sample",
#             "url": "https://github.com/huggingface/transformers/issues/43045",
#             "createdAt": "2025-12-26T06:16:53Z",
#             "author": {
#               "login": "Wovchena",
#               "url": "https://github.com/Wovchena",
#               "location": null
#             }
#           },
#           {
#             "title": "Need to understand difference between TP support via transformers code v/s Pytorch's native parallelize_module API.",
#             "url": "https://github.com/huggingface/transformers/issues/43048",
#             "createdAt": "2025-12-26T10:05:38Z",
#             "author": {
#               "login": "quic-meetkuma",
#               "url": "https://github.com/quic-meetkuma",
#               "location": null
#             }
#           },
#           {
#             "title": "Tensor item cannot be called",
#             "url": "https://github.com/huggingface/transformers/issues/43051",
#             "createdAt": "2025-12-26T15:41:12Z",
#             "author": {
#               "login": "lumideez",
#               "url": "https://github.com/lumideez",
#               "location": null
#             }
#           },
#           {
#             "title": "Missing import of torch in distilbert docs",
#             "url": "https://github.com/huggingface/transformers/issues/43052",
#             "createdAt": "2025-12-26T18:59:00Z",
#             "author": {
#               "login": "PredictiveManish",
#               "url": "https://github.com/PredictiveManish",
#               "location": null
#             }
#           },
#           {
#             "title": "text embedding of siglip2 is much worse than siglip",
#             "url": "https://github.com/huggingface/transformers/issues/43054",
#             "createdAt": "2025-12-27T08:46:30Z",
#             "author": {
#               "login": "fancyerii",
#               "url": "https://github.com/fancyerii",
#               "location": "Beijing, China"
#             }
#           },
#           {
#             "title": "GemmaTokenizer - unclear purpose of Split pre_tokenizer on whitespace",
#             "url": "https://github.com/huggingface/transformers/issues/43062",
#             "createdAt": "2025-12-29T11:18:40Z",
#             "author": {
#               "login": "biuq",
#               "url": "https://github.com/biuq",
#               "location": null
#             }
#           },
#           {
#             "title": "Trainer.train() using v5 + FSDP2 + PEFT + cpu_ram_efficient_loading=True results in wrong optimizer states/params on all but 0th rank",
#             "url": "https://github.com/huggingface/transformers/issues/43064",
#             "createdAt": "2025-12-29T14:44:46Z",
#             "author": {
#               "login": "d5031",
#               "url": "https://github.com/d5031",
#               "location": null
#             }
#           },
#           {
#             "title": "Dummy `nn.Conv2d` in `Sam3PixelDecoder`",
#             "url": "https://github.com/huggingface/transformers/issues/43065",
#             "createdAt": "2025-12-29T15:28:42Z",
#             "author": {
#               "login": "james77777778",
#               "url": "https://github.com/james77777778",
#               "location": "Taipei, Taiwan"
#             }
#           },
#           {
#             "title": "Wrong tokenizer decoder type in Transformers v5",
#             "url": "https://github.com/huggingface/transformers/issues/43066",
#             "createdAt": "2025-12-29T15:31:04Z",
#             "author": {
#               "login": "awni",
#               "url": "https://github.com/awni",
#               "location": "United States"
#             }
#           }
#         ]
#       }
#     }
#   }
# }

# %%
locations = []
for i in range(len(response.json()['data']['repository']['issues']['nodes'])):
    issue = response.json()['data']['repository']['issues']['nodes'][i]
    locations.append(issue['author']['location'])

# %%
locations
# Out:
# ['Sanfancisco',
#  'Canada',
#  None,
#  None,
#  'Toulouse - France',
#  None,
#  'Netherlands',
#  'Bhopal,India',
#  None,
#  None,
#  'Berlin, Germany',
#  None,
#  None,
#  None,
#  None,
#  'San Francisco',
#  'Tel Aviv, Israel',
#  ' Washington, DC Metro ',
#  'china',
#  'Paris',
#  None,
#  None,
#  None,
#  'Iraq',
#  None,
#  'Canada',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Pittsburgh',
#  None,
#  'New York, U.S.',
#  'Singapore, Singapore',
#  'London',
#  'France',
#  None,
#  None,
#  'Hangzhou China',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Shanghai, China',
#  'Paris (France)',
#  'Hangzhou China',
#  None,
#  None,
#  'Seattle, WA',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Daejeon',
#  None,
#  None,
#  'Shanghai, China',
#  None,
#  'London, UK',
#  None,
#  'United States',
#  'United States',
#  'Gurgaon',
#  None,
#  None,
#  'India',
#  None,
#  'France',
#  'Canada',
#  'Rome, Italy',
#  'Lille',
#  None,
#  None,
#  'Amsterdam',
#  None,
#  'Paris, France',
#  'Paris, France',
#  'Paris, France',
#  None,
#  None,
#  None,
#  None,
#  'Madison, WI',
#  None,
#  None,
#  'TianJin，China',
#  None,
#  None,
#  None,
#  None,
#  'Beijing, China',
#  None,
#  None,
#  'Taipei, Taiwan',
#  'United States']

# %%
cleaned_locations = [location for location in locations if location is not None]
cleaned_locations
# Out:
# ['Sanfancisco',
#  'Canada',
#  'Toulouse - France',
#  'Netherlands',
#  'Bhopal,India',
#  'Berlin, Germany',
#  'San Francisco',
#  'Tel Aviv, Israel',
#  ' Washington, DC Metro ',
#  'china',
#  'Paris',
#  'Iraq',
#  'Canada',
#  'Pittsburgh',
#  'New York, U.S.',
#  'Singapore, Singapore',
#  'London',
#  'France',
#  'Hangzhou China',
#  'Shanghai, China',
#  'Paris (France)',
#  'Hangzhou China',
#  'Seattle, WA',
#  'Daejeon',
#  'Shanghai, China',
#  'London, UK',
#  'United States',
#  'United States',
#  'Gurgaon',
#  'India',
#  'France',
#  'Canada',
#  'Rome, Italy',
#  'Lille',
#  'Amsterdam',
#  'Paris, France',
#  'Paris, France',
#  'Paris, France',
#  'Madison, WI',
#  'TianJin，China',
#  'Beijing, China',
#  'Taipei, Taiwan',
#  'United States']

# %%
len(cleaned_locations)
# Out:
# 43

# %%
loc_set = set(cleaned_locations)
len(loc_set)
# Out:
# 34

# %%
rate_query = """
{
    rateLimit {
      limit
      cost
      remaining
      resetAt
      used
    }
}
"""

rate_response = session.post(github_url, json={"query": rate_query})
print("Rate Limit Status Code:", rate_response.status_code)
print("Rate Limit Response:", rate_response.json())
# Out:
# Rate Limit Status Code: 200
# Rate Limit Response: {'data': {'rateLimit': {'limit': 5000, 'cost': 1, 'remaining': 4906, 'resetAt': '2025-12-30T16:20:09Z', 'used': 94}}}

# %%
issue_query = """
{
    repository(owner: "huggingface", name: "transformers") {
    issues(last: 100, states: OPEN) {
      nodes {
        title
        url
        createdAt
        labels(first: 5) {
            nodes {
                name
            }
        }
        author { 
            ... on User {
                login
                url
                location
            }
        }
      }
    }
  }
}
"""

# %%
# open issues_data_10k.json file
with open('/home/chef/src/DAT6003/data/raw/issues_data_10k.json', 'r') as f:
    issues_data = json.load(f)

# %%
comments = []
no_comments = 0
authors = []

for issue in issues_data:
    if "comments" in issue:
        if len(issue["comments"]["nodes"]) == 0:
            no_comments += 1
        else:
            for comment in issue["comments"]["nodes"]:
                comments.append(comment['bodyText'])
                author = comment.get('author')
                if author and 'login' in author:
                    authors.append(author['login'])

authors_counted = Counter(authors)

print(no_comments)
print(len(comments))
# Out:
# 439
# 43035

# %%
authors_counted.most_common(10)
# Out:
# [('LysandreJik', 3406),
#  ('patrickvonplaten', 2311),
#  ('sgugger', 1634),
#  ('stas00', 1403),
#  ('thomwolf', 977),
#  ('patil-suraj', 885),
#  ('julien-c', 770),
#  ('NielsRogge', 744),
#  ('sshleifer', 674),
#  ('BramVanroy', 512)]

# %%
# Pull out nodes from the dataset
# Assumption that we can't infer direction of conversation due to lack of reply structure
# All replies are contained within an issue thread.
nodes = []

for issue in issues_data:
    if issue['author'] == {} or issue['author'] is None:
        continue
    else:
        nodes.append(issue['author']['login'])

    if "comments" in issue and len(issue["comments"]["nodes"]) > 0:
        for comment in issue["comments"]["nodes"]:
            if comment['author'] == {}:
                continue
            author = comment.get('author')
            if author and 'login' in author:
                nodes.append(author['login'])

nodes = set(nodes)
len(nodes)
# Out:
# 9384

# %%
# Extrapolate edges from the dataset
# The assumption is that any users commenting on the same issue are connected to each other.
# Issue authors are considered 'conversation starters' and are therefore also involved in the connections.
edge_weights = Counter()

for issue in issues_data:
    participants = set()

    # get the author of the issue
    if issue['author'] == {} or issue['author'] is None:
        continue
    issue_author = issue['author'].get('login')
    participants.add(issue_author)

    # get the commenters on the issue
    if "comments" in issue and len(issue["comments"]["nodes"]) > 0:
        for comment in issue["comments"]["nodes"]:
            author = comment.get('author')
            if author and 'login' in author:
                participants.add(author['login'])

    if len(participants) < 2:
        continue

    for u, v in combinations(sorted(participants), 2):
        edge_weights[(u, v)] += 1

edges = [(u, v, w) for (u, v), w in edge_weights.items()]

len(edges), edges[:5]
# Out:
# (34216,
#  [('ZhaoyueCheng', 'abeljim', 1),
#   ('ZhaoyueCheng', 'ethanjperez', 1),
#   ('ZhaoyueCheng', 'thomwolf', 1),
#   ('abeljim', 'ethanjperez', 1),
#   ('abeljim', 'thomwolf', 2)])

# %%
nodes_df = pd.DataFrame(list(nodes), columns=['id'])
nodes_df.to_csv('/home/chef/src/DAT6003/data/network/nodes.csv', index=False)

# %%
edges_df = pd.DataFrame(edges, columns=['Source', 'Target', 'Weight'])
edges_df["Type"] = "Undirected"
edges_df.to_csv('/home/chef/src/DAT6003/data/network/edges.csv', index=False)

# %%
# Get the locations of authors to see what needs cleaning
author_locations = []

for issue in issues_data:
    if issue['author'] == {} or issue['author'] is None:
        continue
    else:
        author_locations.append(issue['author']['location'])

    if "comments" in issue and len(issue["comments"]["nodes"]) > 0:
        for comment in issue["comments"]["nodes"]:
            if comment['author'] == {}:
                continue
            author = comment.get('author')
            if author and 'location' in author:
                author_locations.append(author['location'])

author_locations = set(author_locations)
print(len(author_locations))
# Out:
# 1675

# %%
# write out author locations to a csv for cleaning
with open('/home/chef/src/DAT6003/data/raw/author_locations.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['location'])
    for location in author_locations:
        writer.writerow([location])

# %%
# Normalise Unicode, remove emojis, but keep non-latin script
df = pd.read_csv('/home/chef/src/DAT6003/data/raw/author_locations.csv')

df["location_raw"] = df["location"].astype(str)

# %%
EMOJI_RE = re.compile(
    "["                       
    "\U0001F300-\U0001FAFF"   
    "\U00002600-\U000027BF"   
    "\U0001F1E0-\U0001F1FF"   
    "]+",
    flags=re.UNICODE
)

SEP_RE = re.compile(r"[|;/•·]+")
MULTISPACE_RE = re.compile(r"\s+")
TRAILING_PUNCT_RE = re.compile(r"^[,\.\-\s]+|[,\.\-\s]+$")

def normalise_text(s: str) -> str:
    if s == "":
        return ""
    
    if s is None:
        return ""
    s = str(s)

    # Unicode normalisation
    s = unicodedata.normalize("NFKC", s)

    # Remove emoji / pictographs
    s = EMOJI_RE.sub(" ", s)

    # Replace separators with commas
    s = SEP_RE.sub(",", s)

    # Replace newlines/tabs with spaces
    s = s.replace("\n", " ").replace("\r", " ").replace("\t", " ")

    # Strip quotes
    s = s.replace('"', "").replace("'", "")

    # Collapse whitespace
    s = MULTISPACE_RE.sub(" ", s).strip()

    # Trim leading/trailing punctuation/spaces
    s = TRAILING_PUNCT_RE.sub("", s).strip()

    return s

df['location_norm'] = df['location_raw'].fillna("").apply(normalise_text).str.lower()

# %%
df.head()
# Out:
#          location    location_raw   location_norm
# 0  China.Shanghai  China.Shanghai  china.shanghai
# 1   Pangyo, Korea   Pangyo, Korea   pangyo, korea
# 2        Tel Aviv        Tel Aviv        tel aviv
# 3              WH              WH              wh
# 4    Live Oak, FL    Live Oak, FL    live oak, fl

# %%
len(df)
# Out:
# 1675

# %%
MISSING_SET = {
    "", "none", "null", "nan", "n/a", "na", "unknown", "unspecified", "undefined", "-"
}

# Patterns that usually indicate not-a-location (add as you find them)
NONGEO_PATTERNS = [
    r"\bremote\b",
    r"\bearth\b",
    r"\bmars\b",
    r"\bmilky way\b",
    r"\bthe cloud\b",
    r"\binternet\b",
    r"\bgithub\b",
    r"\bonline\b",
    r"\bhome\b",
    r"\bbasement\b",
    r"\bworldwide\b",
    r"\beverywhere\b",
    r"\banywhere\b",
    r"\bunder your bed\b",
]

NONGEO_RE = re.compile("|".join(NONGEO_PATTERNS), flags=re.IGNORECASE)

def classify_basic(s: str) -> str:
    if s is None:
        return "missing"
    s = str(s).strip().lower()
    if s in MISSING_SET:
        return "missing"
    if NONGEO_RE.search(s):
        return "non-geographic"
    return "candidate"

df["location_status"] = df["location_norm"].map(classify_basic)

# %%
import pycountry
import geonamescache

# %%
gc = geonamescache.GeonamesCache()
print(gc.get_countries())
# Out:
# {'AD': {'geonameid': 3041565, 'name': 'Andorra', 'iso': 'AD', 'iso3': 'AND', 'isonumeric': 20, 'fips': 'AN', 'continentcode': 'EU', 'capital': 'Andorra la Vella', 'areakm2': 468, 'population': 77006, 'tld': '.ad', 'currencycode': 'EUR', 'currencyname': 'Euro', 'phone': '376', 'postalcoderegex': '^(?:AD)*(\\d{3})$', 'languages': 'ca', 'neighbours': 'ES,FR'}, 'AE': {'geonameid': 290557, 'name': 'United Arab Emirates', 'iso': 'AE', 'iso3': 'ARE', 'isonumeric': 784, 'fips': 'AE', 'continentcode': 'AS', 'capital': 'Abu Dhabi', 'areakm2': 82880, 'population': 9630959, 'tld': '.ae', 'currencycode': 'AED', 'currencyname': 'Dirham', 'phone': '971', 'postalcoderegex': '^\\d{5}-\\d{5}$', 'languages': 'ar-AE,fa,en,hi,ur', 'neighbours': 'SA,OM'}, 'AF': {'geonameid': 1149361, 'name': 'Afghanistan', 'iso': 'AF', 'iso3': 'AFG', 'isonumeric': 4, 'fips': 'AF', 'continentcode': 'AS', 'capital': 'Kabul', 'areakm2': 647500, 'population': 37172386, 'tld': '.af', 'currencycode': 'AFN', 'currencyname': 'Afghani', 'phone': '93', 'postalcoderegex': '', 'languages': 'fa-AF,ps,uz-AF,tk', 'neighbours': 'TM,CN,IR,TJ,PK,UZ'}, 'AG': {'geonameid': 3576396, 'name': 'Antigua and Barbuda', 'iso': 'AG', 'iso3': 'ATG', 'isonumeric': 28, 'fips': 'AC', 'continentcode': 'NA', 'capital': "St. John's", 'areakm2': 443, 'population': 96286, 'tld': '.ag', 'currencycode': 'XCD', 'currencyname': 'Dollar', 'phone': '+1-268', 'postalcoderegex': '', 'languages': 'en-AG', 'neighbours': ''}, 'AI': {'geonameid': 3573511, 'name': 'Anguilla', 'iso': 'AI', 'iso3': 'AIA', 'isonumeric': 660, 'fips': 'AV', 'continentcode': 'NA', 'capital': 'The Valley', 'areakm2': 102, 'population': 13254, 'tld': '.ai', 'currencycode': 'XCD', 'currencyname': 'Dollar', 'phone': '+1-264', 'postalcoderegex': '^(?:AZ)*(\\d{4})$', 'languages': 'en-AI', 'neighbours': ''}, 'AL': {'geonameid': 783754, 'name': 'Albania', 'iso': 'AL', 'iso3': 'ALB', 'isonumeric': 8, 'fips': 'AL', 'continentcode': 'EU', 'capital': 'Tirana', 'areakm2': 28748, 'population': 2866376, 'tld': '.al', 'currencycode': 'ALL', 'currencyname': 'Lek', 'phone': '355', 'postalcoderegex': '^(\\d{4})$', 'languages': 'sq,el', 'neighbours': 'MK,GR,ME,RS,XK'}, 'AM': {'geonameid': 174982, 'name': 'Armenia', 'iso': 'AM', 'iso3': 'ARM', 'isonumeric': 51, 'fips': 'AM', 'continentcode': 'AS', 'capital': 'Yerevan', 'areakm2': 29800, 'population': 3076200, 'tld': '.am', 'currencycode': 'AMD', 'currencyname': 'Dram', 'phone': '374', 'postalcoderegex': '^(\\d{6})$', 'languages': 'hy', 'neighbours': 'GE,IR,AZ,TR'}, 'AO': {'geonameid': 3351879, 'name': 'Angola', 'iso': 'AO', 'iso3': 'AGO', 'isonumeric': 24, 'fips': 'AO', 'continentcode': 'AF', 'capital': 'Luanda', 'areakm2': 1246700, 'population': 30809762, 'tld': '.ao', 'currencycode': 'AOA', 'currencyname': 'Kwanza', 'phone': '244', 'postalcoderegex': '', 'languages': 'pt-AO', 'neighbours': 'CD,NA,ZM,CG'}, 'AQ': {'geonameid': 6697173, 'name': 'Antarctica', 'iso': 'AQ', 'iso3': 'ATA', 'isonumeric': 10, 'fips': 'AY', 'continentcode': 'AN', 'capital': '', 'areakm2': 14000000, 'population': 0, 'tld': '.aq', 'currencycode': '', 'currencyname': '', 'phone': '', 'postalcoderegex': '', 'languages': '', 'neighbours': ''}, 'AR': {'geonameid': 3865483, 'name': 'Argentina', 'iso': 'AR', 'iso3': 'ARG', 'isonumeric': 32, 'fips': 'AR', 'continentcode': 'SA', 'capital': 'Buenos Aires', 'areakm2': 2766890, 'population': 44494502, 'tld': '.ar', 'currencycode': 'ARS', 'currencyname': 'Peso', 'phone': '54', 'postalcoderegex': '^[A-Z]?\\d{4}[A-Z]{0,3}$', 'languages': 'es-AR,en,it,de,fr,gn', 'neighbours': 'CL,BO,UY,PY,BR'}, 'AS': {'geonameid': 5880801, 'name': 'American Samoa', 'iso': 'AS', 'iso3': 'ASM', 'isonumeric': 16, 'fips': 'AQ', 'continentcode': 'OC', 'capital': 'Pago Pago', 'areakm2': 199, 'population': 55465, 'tld': '.as', 'currencycode': 'USD', 'currencyname': 'Dollar', 'phone': '+1-684', 'postalcoderegex': '96799', 'languages': 'en-AS,sm,to', 'neighbours': ''}, 'AT': {'geonameid': 2782113, 'name': 'Austria', 'iso': ' ...

# %%
tmp = gc.get_cities()
tmp
# Out:
# {'3040051': {'geonameid': 3040051,
#   'name': 'les Escaldes',
#   'latitude': 42.50729,
#   'longitude': 1.53414,
#   'countrycode': 'AD',
#   'population': 15853,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '08',
#   'alternatenames': ["Ehskal'des-Ehndzhordani",
#    'Escaldes',
#    'Escaldes-Engordany',
#    'Les Escaldes',
#    'esukarudesu=engorudani jiao qu',
#    'lai sai si ka er de-en ge er da',
#    'Эскальдес-Энджордани',
#    'エスカルデス＝エンゴルダニ教区',
#    '萊塞斯卡爾德-恩戈爾達',
#    '萊塞斯卡爾德－恩戈爾達']},
#  '3041563': {'geonameid': 3041563,
#   'name': 'Andorra la Vella',
#   'latitude': 42.50779,
#   'longitude': 1.52109,
#   'countrycode': 'AD',
#   'population': 20430,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '07',
#   'alternatenames': ['ALV',
#    'Ando-la-Vyey',
#    'Andora',
#    'Andora la Vela',
#    'Andora la Velja',
#    "Andora lja Vehl'ja",
#    'Andoro Malnova',
#    'Andorra',
#    'Andorra Tuan',
#    'Andorra a Vella',
#    'Andorra la Biella',
#    'Andorra la Vella',
#    'Andorra la Vielha',
#    'Andorra-a-Velha',
#    "Andorra-la-Vel'ja",
#    'Andorra-la-Vielye',
#    'Andorre-la-Vieille',
#    'Andò-la-Vyèy',
#    'Andòrra la Vièlha',
#    'an dao er cheng',
#    'andolalabeya',
#    'andwra la fyla',
#    'Ανδόρρα',
#    'Андора ла Веля',
#    'Андора ла Веља',
#    'Андора ля Вэлья',
#    'Андорра-ла-Велья',
#    'אנדורה לה וולה',
#    'أندورا لا فيلا',
#    'አንዶራ ላ ቬላ',
#    'アンドラ・ラ・ヴェリャ',
#    '安道爾城',
#    '안도라라베야']},
#  '290503': {'geonameid': 290503,
#   'name': 'Warīsān',
#   'latitude': 25.16744,
#   'longitude': 55.40708,
#   'countrycode': 'AE',
#   'population': 108759,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Warisan', 'Warsan', 'Warīsān', 'wrsan', 'ورسان']},
#  '290581': {'geonameid': 290581,
#   'name': 'Umm Suqaym',
#   'latitude': 25.15491,
#   'longitude': 55.21015,
#   'countrycode': 'AE',
#   'population': 16459,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Umm Suqaym',
#    'Umm Suqeim',
#    'Umm Suqeim 2',
#    'Umm as Suqaym',
#    'am sqym',
#    'أم سقيم']},
#  '290594': {'geonameid': 290594,
#   'name': 'Umm Al Quwain City',
#   'latitude': 25.56473,
#   'longitude': 55.55517,
#   'countrycode': 'AE',
#   'population': 59098,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '07',
#   'alternatenames': ['Oumm al Qaiwain',
#    'Oumm al Qaïwaïn',
#    'Um al Kawain',
#    'Um al Quweim',
#    'Umm Al Quwain City',
#    'Umm al Qaiwain',
#    'Umm al Qawain',
#    'Umm al Qaywayn',
#    'Umm al-Quwain',
#    "Umm-ehl'-Kajvajn",
#    'Yumul al Quwain',
#    'am alqywyn',
#    'mdynt am alqywyn',
#    'Умм-эль-Кайвайн',
#    'أم القيوين',
#    'مدينة ام القيوين']},
#  '290680': {'geonameid': 290680,
#   'name': 'Ţarīf Kalbā',
#   'latitude': 25.0695,
#   'longitude': 56.33115,
#   'countrycode': 'AE',
#   'population': 51000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Tarif Kalba', 'Ţarīf Kalbā']},
#  '291061': {'geonameid': 291061,
#   'name': 'Ar Rāshidīyah',
#   'latitude': 25.22499,
#   'longitude': 55.38947,
#   'countrycode': 'AE',
#   'population': 38425,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Rashidiya',
#    'Ar Rashidiyah',
#    'Ar Rāshidīyah',
#    'Rashdia',
#    'Rashidiyah',
#    'Rashīdīyah',
#    'alrashdyt',
#    'الراشدية']},
#  '291074': {'geonameid': 291074,
#   'name': 'Ras Al Khaimah City',
#   'latitude': 25.78953,
#   'longitude': 55.9432,
#   'countrycode': 'AE',
#   'population': 351943,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '05',
#   'alternatenames': ['Julfa',
#    'Khaimah',
#    'RAK City',
#    'RKT',
#    "Ra's al Khaymah",
#    "Ra's al-Chaima",
#    'Ras Al Khaimah City',
#    'Ras al Khaimah',
#    'Ras al-Khaimah',
#    'Ras el Khaimah',
#    'Ras el Khaïmah',
#    'Ras el-Kheima',
#    "Ras-ehl'-Khajma",
#    'Ra’s al Khaymah',
#    'Ra’s al-Chaima',
#    'mdynt ras alkhymt',
#    'ras alkhymt',
#    'Рас-эль-Хайма',
#    'رأس الخيمة',
#    'مدينة رأس الخيمة']},
#  '291580': {'geonameid': 291580,
#   'name': 'Zayed City',
#   'latitude': 23.65416,
#   'longitude': 53.70522,
#   'countrycode': 'AE',
#   'population': 63482,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ["Bid' Zayed",
#    'Bid’ Zayed',
#    "Madinat Za'id",
#    'Madinat Zayid',
#    'Madīnat Zāyid',
#    'Madīnat Zā’id',
#    'Zayed City',
#    'mdynt zayd',
#    'مدينة زايد']},
#  '291696': {'geonameid': 291696,
#   'name': 'Khawr Fakkān',
#   'latitude': 25.33132,
#   'longitude': 56.34199,
#   'countrycode': 'AE',
#   'population': 40677,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Fakkan',
#    'Fakkān',
#    'Khawr Fakkan',
#    'Khawr Fakkān',
#    'Khawr al Fakkan',
#    'Khawr al Fakkān',
#    'Khor Fakhan',
#    'Khor Fakkan',
#    'Khor Fakkan City',
#    'Khor Fakkān',
#    'Khor al Fakhan',
#    'Khor al Fakkan',
#    'Khor al Fākhān',
#    "Khor'fakkan",
#    'Khor-Fakkan',
#    'Khorfakan',
#    'Khorfakhan',
#    'Port Khor Fakkan',
#    'mdynt khwr fkan',
#    'Хор-Факкан',
#    'مدينة خور فكان']},
#  '291763': {'geonameid': 291763,
#   'name': 'Kalbā',
#   'latitude': 25.0513,
#   'longitude': 56.35422,
#   'countrycode': 'AE',
#   'population': 37545,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Ghalla',
#    'Ghallah',
#    'Ghālla',
#    'Ghāllah',
#    'Kalba',
#    'Kalbah',
#    'Kalbā',
#    'Qalba']},
#  '291775': {'geonameid': 291775,
#   'name': 'Jumayrā',
#   'latitude': 25.20795,
#   'longitude': 55.24969,
#   'countrycode': 'AE',
#   'population': 39080,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Jimeirah',
#    'Jumaira',
#    'Jumairah',
#    'Jumayra',
#    'Jumayrah',
#    'Jumayrā',
#    'Jumeira',
#    'Jumeirah',
#    'jmyra',
#    'جميرا']},
#  '292223': {'geonameid': 292223,
#   'name': 'Dubai',
#   'latitude': 25.07725,
#   'longitude': 55.30927,
#   'countrycode': 'AE',
#   'population': 3790000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['DXB',
#    'Dabei',
#    'Dibai',
#    'Dibay',
#    'Doubayi',
#    'Dubae',
#    'Dubai',
#    'Dubai City',
#    'Dubai emiraat',
#    'Dubaija',
#    'Dubaj',
#    'Dubajo',
#    'Dubajus',
#    'Dubay',
#    'Dubayy',
#    'Dubaï',
#    'Dubái',
#    'Dúbæ',
#    'Fort Dabei',
#    'Ntoumpai',
#    'dby',
#    'dbyy',
#    'di bai',
#    'dobai',
#    'du bai',
#    "duba'i",
#    'dubai',
#    'dubay',
#    'dubi',
#    'dwbyy',
#    'tupai',
#    'Ντουμπάι',
#    'Дубаи',
#    'Дубай',
#    'Դուբայ',
#    'דובאי',
#    'דוביי',
#    'دبئی',
#    'دبى',
#    'دبي',
#    'دبی',
#    'دوبەی',
#    'دۇبائى',
#    'दुबई',
#    'দুবাই',
#    'துபை',
#    'దుబాయ్',
#    'ದುಬೈ',
#    'ദുബായ്',
#    'ดูไบ',
#    'დუბაი',
#    'ドバイ',
#    '杜拜',
#    '迪拜',
#    '두바이']},
#  '292231': {'geonameid': 292231,
#   'name': 'Dibba Al-Fujairah',
#   'latitude': 25.59246,
#   'longitude': 56.26176,
#   'countrycode': 'AE',
#   'population': 30000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Al-Fujairah',
#    'BYB',
#    'Dibba Al-Fujairah',
#    'dba alfjyrt',
#    'دبا الفجيرة']},
#  '292239': {'geonameid': 292239,
#   'name': 'Dibba Al-Hisn',
#   'latitude': 25.61955,
#   'longitude': 56.27291,
#   'countrycode': 'AE',
#   'population': 26395,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['BYB',
#    'Daba',
#    'Daba al-Hisn',
#    'Dabā',
#    'Dabā al-Ḥiṣn',
#    'Diba',
#    'Diba Al Hisn',
#    'Diba al Hisn',
#    'Dibah',
#    'Dibba',
#    'Dibba Al Hisn',
#    "Dibba Al'-Khisn",
#    'Dibba Al-Hisn',
#    'Dibbah',
#    'Dibbā Al Ḩişn',
#    'Dibā',
#    'Dibā Al Ḩişn',
#    'Dībā al Ḩişn',
#    'Hisn Diba',
#    'Husn Dibba',
#    'Дибба Аль-Хисн',
#    'Ḩişn Dibā']},
#  '292261': {'geonameid': 292261,
#   'name': 'Dayrah',
#   'latitude': 25.27143,
#   'longitude': 55.30207,
#   'countrycode': 'AE',
#   'population': 400000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Daira',
#    'Dairah',
#    'Dayrah',
#    'Deira',
#    'Dirah',
#    'Dīrah',
#    'dyrt',
#    'ديرة']},
#  '292672': {'geonameid': 292672,
#   'name': 'Sharjah',
#   'latitude': 25.33737,
#   'longitude': 55.41206,
#   'countrycode': 'AE',
#   'population': 1800000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Al Sharjah',
#    "Ash 'Mariqah",
#    'Ash Shariqa',
#    'Ash Shariqah',
#    'Ash Shāriqa',
#    'Ash Shāriqah',
#    'Ash ’Mariqah',
#    'Ash-Shariqah emiraat',
#    'Ash-Shāriqah emiraat',
#    'Charjah',
#    'Ch·ardj·a',
#    'SHJ',
#    'Sardza',
#    'Sardzsa',
#    'Sarika',
#    'Sarja',
#    'Sarjo',
#    'Sarza',
#    'Schardscha',
#    'Shardza',
#    'Shardzha',
#    'Shardzha kuorat',
#    'Sharga',
#    'Sharijah',
#    'Shariqah',
#    'Sharja',
#    'Sharjah',
#    'Sharjah city',
#    'Shārijah',
#    'Shāriqah',
#    'Shārja',
#    'Szardza',
#    'Szardża',
#    'Xarja',
#    'Xarjah',
#    'alsharqt',
#    'amart alsharqt',
#    'carja',
#    'charc ah',
#    'mdynt alsharqt',
#    'saraja',
#    'sarajaha',
#    'sarja',
#    'sharja',
#    'sharjh',
#    'sharuja',
#    'syaleuja',
#    'sʼrgh',
#    'xia er jia',
#    'Ŝarĵo',
#    'Şarika',
#    'Şarja',
#    'Šardža',
#    'Šardžá',
#    'Шарджа',
#    'Шарджа куорат',
#    'Шарџа',
#    'Шарҗә',
#    'Շարժա',
#    'שארגה',
#    'إمارة الشارقة',
#    'الشارقة',
#    'شارجه',
#    'شارجہ',
#    'مدينة الشارقة',
#    'शारजा',
#    'शारजाह',
#    'ਸ਼ਾਰਜਾ',
#    'சார்ஜா',
#    'షార్జా',
#    'ಶಾರ್ಜ',
#    'ഷാർജ',
#    'ชาร์จาห์',
#    'შარჯა',
#    'シャールジャ',
#    '夏尔迦',
#    '샤르자']},
#  '292688': {'geonameid': 292688,
#   'name': 'Ar Ruways',
#   'latitude': 24.11028,
#   'longitude': 52.73056,
#   'countrycode': 'AE',
#   'population': 25000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ["Ar Ru'ays",
#    'Ar Ruways',
#    'Ar Ru’ays',
#    'Ar-Ruvais',
#    'Ruwais',
#    'alrwys',
#    'ar-Ruways',
#    'lu wa si',
#    'ruvais',
#    'Ар-Руваис',
#    'الرويس',
#    'الرویس',
#    'റുവൈസ്',
#    '魯瓦斯',
#    '鲁瓦斯']},
#  '292862': {'geonameid': 292862,
#   'name': 'Ḩattā',
#   'latitude': 24.80073,
#   'longitude': 56.12726,
#   'countrycode': 'AE',
#   'population': 15324,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Hagarein',
#    'Al Hajarayn',
#    'Al Ḥagarein',
#    'Al Ḩajarayn',
#    'Hajarain',
#    'Hajarayn',
#    'Hajrain',
#    'Hatta',
#    'hta',
#    'حتا',
#    'Ḩajarayn',
#    'Ḩattā']},
#  '292878': {'geonameid': 292878,
#   'name': 'Al Fujairah City',
#   'latitude': 25.11641,
#   'longitude': 56.34141,
#   'countrycode': 'AE',
#   'population': 118933,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Al Fujairah City',
#    'Al Fujayrah',
#    'Al-Fudjayra',
#    "Al-Fujayrah' emiraat",
#    'FJR',
#    'Fudschaira',
#    'Fudzhejra',
#    'Fujaira',
#    'Fujairah',
#    'Fujajro',
#    'Fujayrah',
#    'Fuĵajro',
#    'alfjyrt',
#    'fjyrt',
#    'fu ji la',
#    'fujaira',
#    'mdynt alfjyrt',
#    'Фуджейра',
#    'الفجيرة',
#    'فجيرة',
#    'مدينة الفجيرة',
#    'フジャイラ',
#    '富吉拉']},
#  '292913': {'geonameid': 292913,
#   'name': 'Al Ain City',
#   'latitude': 24.19167,
#   'longitude': 55.76056,
#   'countrycode': 'AE',
#   'population': 846747,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['AAN',
#    'Ainas',
#    'Al Ain',
#    'Al Ain City',
#    'Al Ajn',
#    'Al Ayn',
#    'Al `Ayn',
#    'Al Ɛayn',
#    'Al ‘Ayn',
#    'Al-Ain',
#    'Al-Ajn',
#    'Al-Ayin',
#    'Al-Ayn',
#    'Al-Aïn',
#    "Ehl'-Ajn",
#    'El Ain',
#    'El-Ajn',
#    'ai yin',
#    'al ain',
#    'al-ain',
#    'al-aini',
#    'alʿyn',
#    'ela ena',
#    'mdynt alʿyn',
#    'Ел Аин',
#    'Эль-Айн',
#    'Ալ-Ային',
#    'אל-עין',
#    'العين',
#    'العین',
#    'مدينة العين',
#    'एल एन',
#    'அல் ஐன்',
#    'അൽ ഐൻ',
#    'ალ-აინი',
#    'アル・アイン',
#    '艾因',
#    '알아인']},
#  '292932': {'geonameid': 292932,
#   'name': 'Ajman City',
#   'latitude': 25.40177,
#   'longitude': 55.47878,
#   'countrycode': 'AE',
#   'population': 490035,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Ajman',
#    'Ajman City',
#    'Al Ajman',
#    'QAJ',
#    'Ujman',
#    'mdynt ʿjman',
#    'ʿjman',
#    'عجمان',
#    'مدينة عجمان']},
#  '292953': {'geonameid': 292953,
#   'name': 'Adh Dhayd',
#   'latitude': 25.28812,
#   'longitude': 55.88157,
#   'countrycode': 'AE',
#   'population': 20165,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Adh Dhaid',
#    'Adh Dhayd',
#    'Adh Dhed',
#    'Adh Dhēd',
#    'Al Daid',
#    'Al-Dhayd',
#    'Az-Zajd',
#    'Dayd',
#    'Dhaid',
#    'Dhayd',
#    'Duhayd',
#    'Ehd-Dajd',
#    'Ihaid',
#    'Zeyd',
#    'adh-Dhayd',
#    'aldhyd',
#    'da yi de',
#    'daid',
#    'dhyd',
#    'Эд-Дайд',
#    'الذيد',
#    'ذید',
#    'ദൈദ്',
#    'Ḑayd',
#    '達伊德']},
#  '292968': {'geonameid': 292968,
#   'name': 'Abu Dhabi',
#   'latitude': 24.45118,
#   'longitude': 54.39696,
#   'countrycode': 'AE',
#   'population': 1807000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['A-pu-that-pi',
#    'AEbu Saby',
#    'AUH',
#    'Aboe Dhabi',
#    'Abou Dabi',
#    'Abu Dabi',
#    'Abu Dabis',
#    'Abu Daby',
#    'Abu Daibi',
#    'Abu Dhabi',
#    'Abu Dhabi Island and Internal Islands City',
#    'Abu Dhabi emiraat',
#    'Abu Zabi',
#    'Abu Zaby',
#    'Abu Zabye',
#    'Abu Zabyo',
#    'Abu Ḍabi',
#    'Abu Ḑabi',
#    'Abu-Dabi',
#    'Abu-Dabi khot',
#    'Abu-Dabio',
#    'Abu-Dzabi',
#    'Abú Dabí',
#    'Abú Daibí',
#    'Abú Zabí',
#    'Abû Daby',
#    'Abū Dabī',
#    'Abū Z̧aby',
#    'Abū Z̧abye',
#    'Abū Z̧abyo',
#    'Abū Z̧abī',
#    'Ampou Ntampi',
#    'Ebu Dabi',
#    'Ebu Dhabi',
#    'a bu zha bi',
#    'abu dhabi',
#    'abu-dabi',
#    'abudabi',
#    'abudhabi',
#    'abw zby',
#    'abwzby',
#    'aputapi',
#    'jzyrt abwzby wjzr dakhlyt akhry',
#    'xa bud abi',
#    'Â-pu-tha̍t-pí',
#    'Äbu Saby',
#    'Əbu-Dabi',
#    'Άμπου Ντάμπι',
#    'Αμπου Νταμπι',
#    'Αμπού Ντάμπι',
#    'Абу Даби',
#    'Абу-Даби',
#    'Абу-Даби хот',
#    'Абу-Дабі',
#    'Әбу-Даби',
#    'Աբու Դաբի',
#    'אבו דאבי',
#    'أبوظبي',
#    'ئەبووزەبی',
#    'ابو ظبى',
#    'ابوظبی',
#    'ابوظہبی',
#    'جزيرة أبوظبي وجزر داخلية اخرى',
#    'अबु धाबी',
#    'अबू धाबी',
#    'আবুধাবি',
#    'ਅਬੂ ਧਾਬੀ',
#    'ଆବୁଧାବି',
#    'அபுதாபி',
#    'ಅಬು ಧಾಬಿ',
#    'അബുദാബി',
#    'අබුඩාබි',
#    'อาบูดาบี',
#    'ཨ་པོའུ་དྷ་པེ།',
#    'အဘူဒါဘီမြို့',
#    'აბუ-დაბი',
#    'አቡ ዳቢ',
#    'アブダビ',
#    '阿布扎比',
#    '아부다비']},
#  '292991': {'geonameid': 292991,
#   'name': 'Abū Hayl',
#   'latitude': 25.28413,
#   'longitude': 55.33153,
#   'countrycode': 'AE',
#   'population': 18043,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Abu Hail', 'Hail', 'Hāil']},
#  '385024': {'geonameid': 385024,
#   'name': 'As Saţwah',
#   'latitude': 25.22192,
#   'longitude': 55.27459,
#   'countrycode': 'AE',
#   'population': 40997,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Satwa',
#    'As Satwah',
#    'As Saţwah',
#    'Satwa',
#    'alstwh',
#    'السطوه']},
#  '414901': {'geonameid': 414901,
#   'name': 'Al Ḩamīdīyah',
#   'latitude': 25.40001,
#   'longitude': 55.52925,
#   'countrycode': 'AE',
#   'population': 27000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Al Hamidiyah', 'Al Ḩamīdīyah', 'alhmydyt', 'الحميدية']},
#  '6691079': {'geonameid': 6691079,
#   'name': 'Al Waheda',
#   'latitude': 25.29173,
#   'longitude': 55.33822,
#   'countrycode': 'AE',
#   'population': 21608,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '6691091': {'geonameid': 6691091,
#   'name': 'Al Karama',
#   'latitude': 25.24004,
#   'longitude': 55.30106,
#   'countrycode': 'AE',
#   'population': 75560,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '6691113': {'geonameid': 6691113,
#   'name': 'The Palm Jumeirah',
#   'latitude': 25.11607,
#   'longitude': 55.13506,
#   'countrycode': 'AE',
#   'population': 25500,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Palm Jumeirah', 'nkhlt aljmyrt', 'نخلة الجميرة']},
#  '7289825': {'geonameid': 7289825,
#   'name': 'Bur Dubai',
#   'latitude': 25.26038,
#   'longitude': 55.29891,
#   'countrycode': 'AE',
#   'population': 18698,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['br dby', 'بر دبي']},
#  '8057551': {'geonameid': 8057551,
#   'name': 'Khalifah A City',
#   'latitude': 24.42588,
#   'longitude': 54.605,
#   'countrycode': 'AE',
#   'population': 85374,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Khalifah A City',
#    'Madinat Khalifah A',
#    'Madīnat Khalīfah A',
#    'mdynt khlyft a',
#    'mdynt khlyft a/ mtar abwzby aldwly',
#    'مدينة خليفة أ',
#    'مدينة خليفة أ/ مطار أبوظبي الدولي']},
#  '8200824': {'geonameid': 8200824,
#   'name': 'Mirdif',
#   'latitude': 25.22443,
#   'longitude': 55.41412,
#   'countrycode': 'AE',
#   'population': 60288,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Mirdif', 'mrdf', 'مردف']},
#  '8201275': {'geonameid': 8201275,
#   'name': 'Hawr al ‘Anz',
#   'latitude': 25.27744,
#   'longitude': 55.33675,
#   'countrycode': 'AE',
#   'population': 84661,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Hawr al `Anz',
#    'Hawr al ‘Anz',
#    'Hor al Anz',
#    'هور العنز']},
#  '8225407': {'geonameid': 8225407,
#   'name': 'Mankhūl',
#   'latitude': 25.24612,
#   'longitude': 55.29222,
#   'countrycode': 'AE',
#   'population': 41244,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Mankhool',
#    'Mankhool',
#    'Mankhul',
#    'Mankhūl',
#    'mnkhwl',
#    'منخول']},
#  '8226485': {'geonameid': 8226485,
#   'name': 'Nāyf',
#   'latitude': 25.27139,
#   'longitude': 55.30323,
#   'countrycode': 'AE',
#   'population': 53075,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Naif', 'Nayf', 'Nāyf', 'nayf', 'نايف']},
#  '8226590': {'geonameid': 8226590,
#   'name': 'Al Murar al Qadīm',
#   'latitude': 25.27576,
#   'longitude': 55.30738,
#   'countrycode': 'AE',
#   'population': 19831,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Murar',
#    'Al Murar al Qadeem',
#    'Al Murar al Qadim',
#    'Al Murar al Qadīm',
#    'almrr alqdym',
#    'المرر القديم']},
#  '8469658': {'geonameid': 8469658,
#   'name': 'Al Warqaa',
#   'latitude': 25.19272,
#   'longitude': 55.42013,
#   'countrycode': 'AE',
#   'population': 59111,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Warqaa']},
#  '8469668': {'geonameid': 8469668,
#   'name': 'International City',
#   'latitude': 25.16383,
#   'longitude': 55.40987,
#   'countrycode': 'AE',
#   'population': 120000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai International City', 'International City']},
#  '8469788': {'geonameid': 8469788,
#   'name': 'Dubai Marina',
#   'latitude': 25.08525,
#   'longitude': 55.14646,
#   'countrycode': 'AE',
#   'population': 120000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai Marina',
#    'Dubaj Marina',
#    'Dubaja Jakthaveno',
#    'Dubaï Marina',
#    'Marina de Dubai',
#    'Marina de Dubái',
#    'dby maryna',
#    'dobaimarina',
#    'dubai marina',
#    'mrsy dby',
#    'Дубай Марина',
#    'دبی مارینا',
#    'مرسى دبي',
#    'დუბაი მარინა',
#    'ドバイマリーナ']},
#  '8469811': {'geonameid': 8469811,
#   'name': 'Dubai Internet City',
#   'latitude': 25.09538,
#   'longitude': 55.16171,
#   'countrycode': 'AE',
#   'population': 24000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai Internet City']},
#  '8469819': {'geonameid': 8469819,
#   'name': 'Al Safa',
#   'latitude': 25.17047,
#   'longitude': 55.23336,
#   'countrycode': 'AE',
#   'population': 15672,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Safa']},
#  '8475866': {'geonameid': 8475866,
#   'name': 'Ar Rumaylah',
#   'latitude': 25.40338,
#   'longitude': 55.4334,
#   'countrycode': 'AE',
#   'population': 86000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Ar Rumaylah', 'alrmylt', 'الرميلة']},
#  '8475923': {'geonameid': 8475923,
#   'name': 'Al Jurf',
#   'latitude': 25.41814,
#   'longitude': 55.50791,
#   'countrycode': 'AE',
#   'population': 18000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Al Jurf', 'aljrf', 'الجرف']},
#  '8476509': {'geonameid': 8476509,
#   'name': 'Al Majaz',
#   'latitude': 25.32354,
#   'longitude': 55.38774,
#   'countrycode': 'AE',
#   'population': 116503,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '8541937': {'geonameid': 8541937,
#   'name': 'Dubai Festival City',
#   'latitude': 25.22177,
#   'longitude': 55.35733,
#   'countrycode': 'AE',
#   'population': 77000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '8541977': {'geonameid': 8541977,
#   'name': 'Dubai International Financial Centre',
#   'latitude': 25.2106,
#   'longitude': 55.27787,
#   'countrycode': 'AE',
#   'population': 36000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '11048853': {'geonameid': 11048853,
#   'name': 'Dubai Investments Park',
#   'latitude': 25.00827,
#   'longitude': 55.15682,
#   'countrycode': 'AE',
#   'population': 160000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '11524601': {'geonameid': 11524601,
#   'name': 'Jebel Ali',
#   'latitude': 25.00255,
#   'longitude': 55.10811,
#   'countrycode': 'AE',
#   'population': 210000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['jbl ʿly', 'جبل علي']},
#  '12042052': {'geonameid': 12042052,
#   'name': 'Bani Yas City',
#   'latitude': 24.30978,
#   'longitude': 54.62944,
#   'countrycode': 'AE',
#   'population': 80498,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Bani Yas',
#    'Bani Yas City',
#    'mdynt bny yas',
#    'مدينة بني ياس']},
#  '12042053': {'geonameid': 12042053,
#   'name': 'Musaffah',
#   'latitude': 24.35893,
#   'longitude': 54.48267,
#   'countrycode': 'AE',
#   'population': 243341,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Musaffa', 'Musaffah City', 'msfh', 'Мусаффа', 'مصفح']},
#  '12047416': {'geonameid': 12047416,
#   'name': 'Al Shamkhah City',
#   'latitude': 24.39268,
#   'longitude': 54.70779,
#   'countrycode': 'AE',
#   'population': 61710,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Al Shamkhah City', 'mdynt alshamkht', 'مدينة الشامخة']},
#  '12047417': {'geonameid': 12047417,
#   'name': 'Reef Al Fujairah City',
#   'latitude': 25.14479,
#   'longitude': 56.24764,
#   'countrycode': 'AE',
#   'population': 82310,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Reef Al Fujairah City', 'ryf alfjyrt', 'ريف الفجيرة']},
#  '13118420': {'geonameid': 13118420,
#   'name': "Al Bada'a",
#   'latitude': 25.22462,
#   'longitude': 55.26888,
#   'countrycode': 'AE',
#   'population': 18816,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['albdʿ', 'البدع']},
#  '13118421': {'geonameid': 13118421,
#   'name': 'Al Muteena',
#   'latitude': 25.27375,
#   'longitude': 55.32265,
#   'countrycode': 'AE',
#   'population': 48739,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Muteena']},
#  '13118422': {'geonameid': 13118422,
#   'name': 'Al Mizhar First',
#   'latitude': 25.24805,
#   'longitude': 55.44128,
#   'countrycode': 'AE',
#   'population': 17498,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Mizhar 1']},
#  '13118424': {'geonameid': 13118424,
#   'name': 'Dubai Silicon Oasis',
#   'latitude': 25.11985,
#   'longitude': 55.38718,
#   'countrycode': 'AE',
#   'population': 90000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Silicon Oasis']},
#  '13118431': {'geonameid': 13118431,
#   'name': 'Al Furjan',
#   'latitude': 25.02651,
#   'longitude': 55.14565,
#   'countrycode': 'AE',
#   'population': 26000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '13118432': {'geonameid': 13118432,
#   'name': 'Business Bay',
#   'latitude': 25.18544,
#   'longitude': 55.26969,
#   'countrycode': 'AE',
#   'population': 191000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '13118433': {'geonameid': 13118433,
#   'name': 'Al Qusais 1',
#   'latitude': 25.27925,
#   'longitude': 55.36995,
#   'countrycode': 'AE',
#   'population': 48378,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Qusais First']},
#  '13118437': {'geonameid': 13118437,
#   'name': 'Halwan',
#   'latitude': 25.34586,
#   'longitude': 55.42165,
#   'countrycode': 'AE',
#   'population': 19389,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '13118438': {'geonameid': 13118438,
#   'name': 'Al Sajaah',
#   'latitude': 25.31532,
#   'longitude': 55.63211,
#   'countrycode': 'AE',
#   'population': 53079,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '13118439': {'geonameid': 13118439,
#   'name': 'Lahbab',
#   'latitude': 25.03763,
#   'longitude': 55.59135,
#   'countrycode': 'AE',
#   'population': 53079,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Lehbab', 'lhbab', 'لهباب']},
#  '13118447': {'geonameid': 13118447,
#   'name': 'Mohammed Bin Zayed City',
#   'latitude': 24.34794,
#   'longitude': 54.55368,
#   'countrycode': 'AE',
#   'population': 85000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Mohammed Bin Zayed']},
#  '1120985': {'geonameid': 1120985,
#   'name': 'Zaranj',
#   'latitude': 30.95962,
#   'longitude': 61.86037,
#   'countrycode': 'AF',
#   'population': 49851,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '19',
#   'alternatenames': ['Sarandsch',
#    'ZAJ',
#    'Zaranas',
#    'Zarandj',
#    'Zarandz',
#    'Zarandzas',
#    'Zarandzh',
#    'Zarandż',
#    'Zarandžas',
#    'Zarang',
#    'Zarani',
#    'Zaranj',
#    'Zaranĝ',
#    'Zerenc',
#    'Zhazang',
#    'Zərənc',
#    'zaranja',
#    'zha lan ji',
#    'zrnj',
#    'Зарандж',
#    'Зарани',
#    'Заранҷ',
#    'زرنج',
#    'ज़रंज',
#    '扎兰季']},
#  '1121381': {'geonameid': 1121381,
#   'name': 'Bāzār-e Yakāwlang',
#   'latitude': 34.73525,
#   'longitude': 66.97379,
#   'countrycode': 'AF',
#   'population': 65000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '05',
#   'alternatenames': ['Bazar-e Yakavlang',
#    'Bazar-e Yakawlang',
#    'Bazar-e Yekawlang',
#    'Bazare Yakawlang',
#    'Bazari-Yakavlang',
#    'Bāzār-e Yakāvlang',
#    'Bāzār-e Yakāwlang',
#    'Bāzār-e Yekāwlang',
#    'Bāzāṟe Yakāwlang',
#    'Yakaulang',
#    'Yakavlang',
#    'Yakawlang',
#    'Yakāvlang',
#    'Yakāwlang',
#    'bazar ykawlng',
#    'بازار يکاولنگ']},
#  '1123004': {'geonameid': 1123004,
#   'name': 'Taloqan',
#   'latitude': 36.73605,
#   'longitude': 69.53451,
#   'countrycode': 'AF',
#   'population': 64256,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Khanabad',
#    'TQN',
#    'Taikhan',
#    'Taleqan',
#    'Talikan',
#    'Talikhan',
#    'Taliqan',
#    'Talkan',
#    'Talokan',
#    'Taloqan',
#    'Talugan',
#    'Talukan',
#    'Talukanas',
#    'Taluqan',
#    'Tologan',
#    'Tâloqân',
#    'Tāleqān',
#    'Tāloqān',
#    'Tāluqān',
#    'Tālīqān',
#    'ta lu kan',
#    'talokam',
#    'talokuvan',
#    'taloqana',
#    'talqan',
#    'Таликан',
#    'Талукан',
#    'تالقان',
#    'तालोक़ान',
#    'तालोकां',
#    'தலோகுவான்',
#    'თალიკანი',
#    '塔卢坎']},
#  '1125155': {'geonameid': 1125155,
#   'name': 'Shīnḏanḏ',
#   'latitude': 33.30294,
#   'longitude': 62.1474,
#   'countrycode': 'AF',
#   'population': 29264,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Asfazar',
#    'Asfazār',
#    'OAH',
#    'Sabzavar',
#    'Sabzavār',
#    'Sabzawar',
#    'Sabzevar',
#    'Sabzevār',
#    'Shindand',
#    'Shīndand',
#    'Shīnḏanḏ',
#    'Sindand',
#    'shyndnd',
#    'Šīndand',
#    'Шинданд',
#    'شيندند',
#    'شیندند',
#    'شینډنډ']},
#  '1125444': {'geonameid': 1125444,
#   'name': 'Shibirghān',
#   'latitude': 36.66757,
#   'longitude': 65.7529,
#   'countrycode': 'AF',
#   'population': 55641,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '31',
#   'alternatenames': ['Markaz-e Wilayat-e Shibirghan',
#    'Markaz-e Wilāyat-e Shibirghan',
#    'Seberghan',
#    'Sebeṟghān',
#    'Shahr-e Sheberghan',
#    'Shahr-e Sheberghān',
#    'Shayurgan',
#    'Shebergan',
#    'Sheberghan',
#    'Sheberghān',
#    'Sheberkhan',
#    'Shefrogan',
#    'Shibarghan',
#    'Shibarghān',
#    'Shibergan',
#    'Shibirghan',
#    'Shibirghān',
#    'mrkz wlayt shbrghan',
#    'shbrghan',
#    'shbrghn',
#    'Шеберган',
#    'شبرغان',
#    'شبرغن',
#    'مرکز ولايت شبرغان']},
#  '1125896': {'geonameid': 1125896,
#   'name': 'Shahrak',
#   'latitude': 34.10737,
#   'longitude': 64.3052,
#   'countrycode': 'AF',
#   'population': 15967,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '09',
#   'alternatenames': ['Bati Dara',
#    'Kala Shaharak',
#    'Kala Shahrak',
#    'Kala Shahārak',
#    'Markaz-e Shahrak',
#    'Qal`eh Shaharak',
#    'Qal`eh-ye Bati Darrah',
#    'Qala Bati Dara',
#    'Qala Batī Dara',
#    'Qala Shaharak',
#    'Qala Shahārak',
#    'Qala Sharak',
#    'Qal‘eh Shahārak',
#    'Qal‘eh-ye Bati Darrah',
#    'Sahrak',
#    'Shahrag',
#    'Shahrak',
#    'Shakhrak',
#    'Sharak',
#    'Shāhrag',
#    'Shāhrak',
#    'Wala Shahrak',
#    'shhrk',
#    'Šahrak',
#    'شهرک']},
#  '1127110': {'geonameid': 1127110,
#   'name': 'Sar-e Pul',
#   'latitude': 36.21544,
#   'longitude': 65.93249,
#   'countrycode': 'AF',
#   'population': 52121,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '33',
#   'alternatenames': ['Sar-e Pol',
#    'Sar-e Pul',
#    'Sar-i-Pul',
#    "Sari-Pul'",
#    'sr pl',
#    'Сари-Пуль',
#    'سر پل']},
#  '1127628': {'geonameid': 1127628,
#   'name': 'Sang-e Chārak',
#   'latitude': 35.84972,
#   'longitude': 66.43694,
#   'countrycode': 'AF',
#   'population': 15377,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '33',
#   'alternatenames': ['Sang-e Charak', 'Sang-e Chārak']},
#  '1127768': {'geonameid': 1127768,
#   'name': 'Aībak',
#   'latitude': 36.26468,
#   'longitude': 68.01551,
#   'countrycode': 'AF',
#   'population': 47823,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '32',
#   'alternatenames': ['Aibak',
#    'Aybak',
#    'Aībak',
#    'Eybak',
#    'Haibak',
#    'Samagan',
#    'Samangan',
#    'Samangān',
#    'aybk',
#    'smngan',
#    'Āybak',
#    'Саманган',
#    'آیبک',
#    'ایبک',
#    'سمنگان']},
#  '1128265': {'geonameid': 1128265,
#   'name': 'Rustāq',
#   'latitude': 37.12604,
#   'longitude': 69.83045,
#   'countrycode': 'AF',
#   'population': 25636,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Rostaq',
#    'Rostāq',
#    'Rustak',
#    'Rustaq',
#    'Rustāq',
#    'rstaq',
#    'رستاق',
#    'Ṟustāq']},
#  '1129516': {'geonameid': 1129516,
#   'name': 'Qarqīn',
#   'latitude': 37.41853,
#   'longitude': 66.04358,
#   'countrycode': 'AF',
#   'population': 15018,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '31',
#   'alternatenames': ['Karkin',
#    'Karkin Bazar',
#    'Kkhanika',
#    'Qarkin',
#    'Qarqin',
#    'Qarqīn',
#    'Quarkin',
#    'qrqyn',
#    'Кханика',
#    'قرقین']},
#  '1129648': {'geonameid': 1129648,
#   'name': 'Qarāwul',
#   'latitude': 37.21959,
#   'longitude': 68.7802,
#   'countrycode': 'AF',
#   'population': 24544,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Hazrat Imam',
#    'Hazrat Imam Saiyid',
#    'Hazrat Imām',
#    'Karaul',
#    'Qaravol',
#    'Qarawul',
#    'Qarāvol',
#    'Qarāwul',
#    'Qaṟāwul',
#    'qrawl',
#    'قراول']},
#  '1130490': {'geonameid': 1130490,
#   'name': 'Pul-e Khumrī',
#   'latitude': 35.94458,
#   'longitude': 68.71512,
#   'countrycode': 'AF',
#   'population': 56369,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Pol-e Khomri',
#    'Pol-e Khomrī',
#    'Pul-e Khumri',
#    'Pul-e Khumrī',
#    'Pul-i-Khomri',
#    'Pul-i-Khumri',
#    'Pule Khumri',
#    'Pule Khumṟi',
#    'Puli-Khumri',
#    'pl khmry',
#    'Пули-Хумри',
#    'پل خمری']},
#  '1131316': {'geonameid': 1131316,
#   'name': 'Paghmān',
#   'latitude': 34.58787,
#   'longitude': 68.95091,
#   'countrycode': 'AF',
#   'population': 49157,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '13',
#   'alternatenames': ['Paghman',
#    'Paghman Palace',
#    'Paghmān',
#    'Pagman',
#    'pghman',
#    'Пагман',
#    'پغمان']},
#  '1131833': {'geonameid': 1131833,
#   'name': 'Nīlī',
#   'latitude': 33.72178,
#   'longitude': 66.13023,
#   'countrycode': 'AF',
#   'population': 30058,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '41',
#   'alternatenames': ['Nili',
#    'Nīlī',
#    'Qaryah-e Nili',
#    'Qaryah-e Nīlī',
#    'nyly',
#    'نیلی']},
#  '1132495': {'geonameid': 1132495,
#   'name': 'Nahrīn',
#   'latitude': 36.0649,
#   'longitude': 69.13343,
#   'countrycode': 'AF',
#   'population': 22363,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Nahrin',
#    'Nahrīn',
#    'Nakhrin',
#    'Narain',
#    'Narin',
#    'Narīn',
#    'nhryn',
#    'Нахрин',
#    'نهرین']},
#  '1133453': {'geonameid': 1133453,
#   'name': 'Maymana',
#   'latitude': 35.92139,
#   'longitude': 64.78361,
#   'countrycode': 'AF',
#   'population': 75900,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '07',
#   'alternatenames': ['Daerah Maymana',
#    'MMZ',
#    'Maimana',
#    'Maimanah',
#    'Maimāna',
#    'Majmana',
#    'Maymana',
#    'Maymanah',
#    'Maïmana',
#    'Maīmanah',
#    'Meimana',
#    'Mejmene',
#    'Meymaneh',
#    'Meymene',
#    'Mimana',
#    'Quan Maymana',
#    'Quận Maymana',
#    'mai ma na',
#    'meyamana',
#    'mymnh',
#    'Меймене',
#    'ضلع میمنہ',
#    'ميمنه ولسوالۍ',
#    'میمنه',
#    'میمنہ',
#    'मेयमना',
#    '迈马纳']},
#  '1133574': {'geonameid': 1133574,
#   'name': 'Mehtar Lām',
#   'latitude': 34.67139,
#   'longitude': 70.20944,
#   'countrycode': 'AF',
#   'population': 17345,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '35',
#   'alternatenames': ['Laghman',
#    'Mehtar Lam',
#    'Mehtar Lām',
#    'Mekhtarlam',
#    'Metarlam',
#    'Mir Talam Saheb Ziarat',
#    'Mitarlam',
#    'Miterlam',
#    'Mīr Talām Şāḩeb Zīārat',
#    'Nawar Lam',
#    'Nāwar Lam',
#    'mhtr lam',
#    'Митарлам',
#    'مهتر لام']},
#  '1133616': {'geonameid': 1133616,
#   'name': 'Mazār-e Sharīf',
#   'latitude': 36.70904,
#   'longitude': 67.11087,
#   'countrycode': 'AF',
#   'population': 523300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['MZR',
#    'Masar-e Scharif',
#    'Mazar-e Sarif',
#    'Mazar-e Sharif',
#    'Mazar-e Šarif',
#    'Mazar-e-Sharif',
#    'Mazar-i Szarif',
#    'Mazar-i-Sharif',
#    'Mazare Srif',
#    'Mazari Sharif',
#    'Mazari-Sharif',
#    'Mazār-e Sharīf',
#    'Mazār-e Šarīf',
#    'Mazār-i-Sharīf',
#    'Mazāre S̄rīf',
#    'majaleu-isyalipeu',
#    'mazarisharifu',
#    'mzar shryf',
#    'Мазари-Шариф',
#    'مزار شريف',
#    'مزار شریف',
#    'マザーリシャリーフ',
#    '마자르이샤리프']},
#  '1134720': {'geonameid': 1134720,
#   'name': 'Lashkar Gāh',
#   'latitude': 31.59382,
#   'longitude': 64.37161,
#   'countrycode': 'AF',
#   'population': 43934,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['BST',
#    'Bist',
#    'Bost',
#    'Bust',
#    'Lashkar Gah',
#    'Lashkar Gāh',
#    'Lashkargah Bust',
#    'Lashkargakh',
#    'Laskargah',
#    'Las̲h̲kargāh Busṯ',
#    'Laškargāh',
#    'Nawab City',
#    'lshkr gah',
#    'Лашкаргах',
#    'لشكر گاه',
#    'لښکرگاه بسټ']},
#  '1135158': {'geonameid': 1135158,
#   'name': 'Kushk',
#   'latitude': 33.29565,
#   'longitude': 61.95221,
#   'countrycode': 'AF',
#   'population': 16952,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Kushk',
#    'Kusk',
#    'Kus̄k',
#    'Kūshk',
#    'kshk',
#    'Кушк',
#    'کشک']},
#  '1135689': {'geonameid': 1135689,
#   'name': 'Kunduz',
#   'latitude': 36.72895,
#   'longitude': 68.857,
#   'countrycode': 'AF',
#   'population': 161902,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Kondoz',
#    'Konduz',
#    'Kondôz',
#    'Kondūz',
#    'Kundus',
#    'Kunduz',
#    'Kunduz khot',
#    'Kunduzas',
#    'Kundúz',
#    'Kundūz',
#    'Kundūzas',
#    'Qonduz',
#    'Qondūz',
#    'Qunduz',
#    'Qundūz',
#    'Qunḏūz',
#    'Shahr-e Qondoz',
#    'UND',
#    'kantacu',
#    'kndwz',
#    'kndz',
#    'kuduza',
#    'kun dou shi',
#    'kundouzu',
#    'kunduja',
#    'kundujeu',
#    'kundus',
#    'kunduza',
#    'qndwz',
#    'qndz',
#    'Кундуз',
#    'Кундуз хот',
#    'قندز',
#    'قندوز',
#    'كندز',
#    'کندوز',
#    'कुंदुज़',
#    'কুন্দুজ',
#    'ਕੁੰਦੂਜ਼',
#    'கண்டசு',
#    'കുന്ദൂസ്',
#    'ყუნდუზი',
#    'クンドゥーズ',
#    '昆都士',
#    '쿤두즈']},
#  '1136469': {'geonameid': 1136469,
#   'name': 'Khōst',
#   'latitude': 33.33951,
#   'longitude': 69.92041,
#   'countrycode': 'AF',
#   'population': 96123,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '37',
#   'alternatenames': ['KHT',
#    'Khost',
#    'Khowst',
#    'Khōst',
#    'Matun',
#    'Matūn',
#    'khwst',
#    'mtwn',
#    'Хост',
#    'خوست',
#    'متون']},
#  '1136575': {'geonameid': 1136575,
#   'name': 'Khulm',
#   'latitude': 36.69736,
#   'longitude': 67.69826,
#   'countrycode': 'AF',
#   'population': 64933,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['Bazar-e Khulm',
#    'Bāzār-e Khulm',
#    'Kholm',
#    'Khulm',
#    'Tashkurgan',
#    'Tashkurghan',
#    'Tashqorghan',
#    'Tashqurghan',
#    'Tāshkurghān',
#    'Tāshqorghān',
#    'Tāshqurghān',
#    'bazar khlm',
#    'khlm',
#    'tashqrghan',
#    'Ташкурган',
#    'بازار خلم',
#    'تاشقرغان',
#    'خلم']},
#  '1136863': {'geonameid': 1136863,
#   'name': 'Khāsh',
#   'latitude': 31.52919,
#   'longitude': 62.79055,
#   'countrycode': 'AF',
#   'population': 15133,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '19',
#   'alternatenames': ['Khas', 'Khash', 'Khāsh', 'Khās̄', 'khash', 'خاش']},
#  '1137079': {'geonameid': 1137079,
#   'name': 'Khān Neshīn',
#   'latitude': 30.5488,
#   'longitude': 63.7888,
#   'countrycode': 'AF',
#   'population': 25600,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['Khan Nashim',
#    'Khan Nashin',
#    'Khan Neshin',
#    'Khan Nishin',
#    'Khanashin',
#    'Khaneshin',
#    'Khannesin',
#    'Khān Nashīn',
#    'Khān Neshīn',
#    'Khān Nishīn',
#    'Khāneshīn',
#    'Khānnešīn',
#    'khan nshyn',
#    'خان نشین']},
#  '1137168': {'geonameid': 1137168,
#   'name': 'Khanabad',
#   'latitude': 36.68304,
#   'longitude': 69.11279,
#   'countrycode': 'AF',
#   'population': 71531,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Khan Abad',
#    'Khanabad',
#    'Khān Ābād',
#    'Khānābād',
#    'khan abad',
#    'Ханабад',
#    'خان آباد']},
#  '1137807': {'geonameid': 1137807,
#   'name': 'Karukh',
#   'latitude': 34.48108,
#   'longitude': 62.5863,
#   'countrycode': 'AF',
#   'population': 17484,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Karokh', 'Karrukh', 'Karukh', 'Kaṟukh', 'krkh', 'کرخ']},
#  '1138336': {'geonameid': 1138336,
#   'name': 'Kandahār',
#   'latitude': 31.61332,
#   'longitude': 65.71013,
#   'countrycode': 'AF',
#   'population': 523300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '23',
#   'alternatenames': ['Candahar',
#    'KDH',
#    'Kandagar',
#    'Kandahar',
#    'Kandaharo',
#    'Kandahār',
#    'Kandehar',
#    'Kandhar',
#    'Qandahar',
#    'Qandahār',
#    'Qanḏahāṟ',
#    'kan da ha',
#    'kandaharu',
#    'kndhar',
#    'qndhar',
#    'qndhʼr',
#    'Кандагар',
#    'קנדהאר',
#    'قندهار',
#    'كندهار',
#    'カンダハール',
#    '坎大哈']},
#  '1138958': {'geonameid': 1138958,
#   'name': 'Kabul',
#   'latitude': 34.52813,
#   'longitude': 69.17233,
#   'countrycode': 'AF',
#   'population': 4434550,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '13',
#   'alternatenames': ['Cabool',
#    'Caboul',
#    'Cabul',
#    'Cabura',
#    'Cabúl',
#    'Caubul',
#    'KBL',
#    'Kabil',
#    'Kaboel',
#    'Kabol',
#    'Kaboul',
#    'Kabul',
#    'Kabula',
#    'Kabulas',
#    'Kabuli',
#    'Kabulo',
#    'Kabura',
#    'Kabúl',
#    'Kabûl',
#    'Kampoul',
#    'Kobul',
#    'Kubha',
#    'Kábul',
#    'Kâbil',
#    'Kābol',
#    'ka bu er',
#    'kabl',
#    'kabul',
#    'kabula',
#    'kabuli',
#    'kaburu',
#    'kabwl',
#    'kapul',
#    'ke bu er',
#    'khabul',
#    'Καμπούλ',
#    'Кабул',
#    'Кобул',
#    'Քաբուլ',
#    'קאבול',
#    'كابل',
#    'كابۇل',
#    'کابل',
#    'کابول',
#    'काबुल',
#    'কাবুল',
#    'ਕਾਬੁਲ',
#    'କାବୁଲ',
#    'காபூல்',
#    'ಕಾಬುಲ್',
#    'കാബൂൾ',
#    'කාබුල්',
#    'คาบูล',
#    'ཁ་པལ།',
#    'ཁ་པུལ།',
#    'ქაბული',
#    'ካቡል',
#    'ទីក្រុងកាបូល',
#    'カブール',
#    'カーブル',
#    '喀布尔',
#    '喀布爾',
#    '카불']},
#  '1139715': {'geonameid': 1139715,
#   'name': 'Jalālābād',
#   'latitude': 34.42647,
#   'longitude': 70.45153,
#   'countrycode': 'AF',
#   'population': 271900,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '18',
#   'alternatenames': ['Djelalabad',
#    'Dschalalabad',
#    'Dzalalabad',
#    'Dzhelalabad',
#    'Dżalalabad',
#    'JAA',
#    'Jalakot',
#    'Jalal-Kut',
#    'Jalalabad',
#    'Jalalkoat',
#    'Jalalkot',
#    'Jalālkot',
#    'Jalālābād',
#    'Jelalabad',
#    'Tarun City',
#    'jalalabada',
#    'jlal abad',
#    'Джелалабад',
#    'جلال آباد',
#    'جلال\u200cآباد',
#    'জালালাবাদ']},
#  '1139807': {'geonameid': 1139807,
#   'name': 'Jabal os Saraj',
#   'latitude': 35.11833,
#   'longitude': 69.23778,
#   'countrycode': 'AF',
#   'population': 15032,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '40',
#   'alternatenames': ['Djabal-ul-Seradj',
#    "Dzhabal'-Ussaradzh",
#    'Dzhabal’-Ussaradzh',
#    'Jabal Saraj',
#    'Jabal os Saraj',
#    'Jabal os Sarāj',
#    'Jabal us Siraj',
#    'Jabal us Sirāj',
#    'Jabal-us-Sirai',
#    'Jabalussaraj',
#    'Jabalussaṟāj',
#    'Jabl-us-Seraj',
#    'Jabl-us-Siraj',
#    'Jabul Saraj',
#    'Jibal-as-Seraj',
#    'Parwan',
#    'jbl alsraj',
#    'جبل السراج']},
#  '1140026': {'geonameid': 1140026,
#   'name': 'Herāt',
#   'latitude': 34.34817,
#   'longitude': 62.19967,
#   'countrycode': 'AF',
#   'population': 574300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Gerat',
#    'HEA',
#    'Herat',
#    'Herāt',
#    'Hérat',
#    'Kherat',
#    'Shahr-e Herat',
#    'Shahr-e Herāt',
#    'he la te',
#    'herato',
#    'hrat',
#    'Герат',
#    'Херат',
#    'هراة',
#    'هرات',
#    'ヘラート',
#    '赫拉特']},
#  '1141089': {'geonameid': 1141089,
#   'name': 'Ghormach',
#   'latitude': 35.73062,
#   'longitude': 63.78264,
#   'countrycode': 'AF',
#   'population': 30000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '02',
#   'alternatenames': ['Garmak',
#    'Ghormac',
#    'Ghormach',
#    'Ghormāch',
#    'Ghowrmach',
#    'Ghowrmāch',
#    'Ghōrmāc',
#    'Ghōrmāch',
#    'ghwrmach',
#    'ghwrmch',
#    'غورماچ',
#    'غورمچ']},
#  '1141269': {'geonameid': 1141269,
#   'name': 'Ghazni',
#   'latitude': 33.55391,
#   'longitude': 68.42096,
#   'countrycode': 'AF',
#   'population': 141000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '08',
#   'alternatenames': ['GZI',
#    'Gazni',
#    'Ghazni',
#    'Ghaznī',
#    'Shahr-e Ghazni',
#    'Shahr-e Ghaznī',
#    'gazni',
#    'gazuni',
#    'ghznt',
#    'ghzny',
#    'ghznyn',
#    'Газни',
#    'غزنة',
#    'غزنی',
#    'غزنین',
#    'ガズニー']},
#  '1141540': {'geonameid': 1141540,
#   'name': 'Gereshk',
#   'latitude': 31.82089,
#   'longitude': 64.57005,
#   'countrycode': 'AF',
#   'population': 43588,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['Gereshk',
#    'Geresk',
#    'Gerešk',
#    'Girishk',
#    'Nahr-e Saraj',
#    'Nahr-e Sarāj',
#    'grshk',
#    'Герешк',
#    'گرشک']},
#  '1141857': {'geonameid': 1141857,
#   'name': 'Gardez',
#   'latitude': 33.59744,
#   'longitude': 69.22592,
#   'countrycode': 'AF',
#   'population': 103601,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '36',
#   'alternatenames': ['GRG',
#    'Gardeyz',
#    'Gardez',
#    'Gardiz',
#    'Gardêz',
#    'Gardēz',
#    'Gardīz',
#    'Gaṟḏēz',
#    'grdyz',
#    'Гардез',
#    'گرديز']},
#  '1142170': {'geonameid': 1142170,
#   'name': 'Fayzabad',
#   'latitude': 37.11664,
#   'longitude': 70.58002,
#   'countrycode': 'AF',
#   'population': 44421,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '01',
#   'alternatenames': ['FBD',
#    'Faizabad',
#    'Faizābād',
#    'Fajzabad',
#    'Faydz Abad',
#    'Fayzabad',
#    'Fayḏẕ Ābāḏ',
#    'Fazelabad',
#    'Faīẕābād',
#    'Feyzabad',
#    'Feyẕābād',
#    'fyd abad',
#    'Файзабад',
#    'فیض آباد']},
#  '1142264': {'geonameid': 1142264,
#   'name': 'Farah',
#   'latitude': 32.37451,
#   'longitude': 62.11638,
#   'countrycode': 'AF',
#   'population': 43561,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '06',
#   'alternatenames': ['FAH',
#    'Farah',
#    'Farahas',
#    'Farakh',
#    'Farâh',
#    'Farāh',
#    'Ferah',
#    'fa la',
#    'faraha',
#    'frah',
#    'pala',
#    'para',
#    'Фарах',
#    'فراه',
#    'فراہ',
#    'फ़राह',
#    'பாரா',
#    '法拉',
#    '파라']},
#  '1142404': {'geonameid': 1142404,
#   'name': 'Eslam Qaleh',
#   'latitude': 34.66667,
#   'longitude': 61.06667,
#   'countrycode': 'AF',
#   'population': 18086,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Eslam Qal`eh',
#    'Eslamqal`a',
#    'Eslamqal‘a',
#    'Eslām Qal‘eh',
#    'Islam Kala',
#    'Islam Killa',
#    'Islam Qal`ah',
#    'Islam Qala',
#    'Islām Kala',
#    'Islām Qala',
#    'Islām Qal‘ah',
#    'Kafar Qal`eh',
#    'Kafir Kala',
#    'Kafir Qala',
#    'Kāfar Qal‘eh']},
#  '1145352': {'geonameid': 1145352,
#   'name': 'Charikar',
#   'latitude': 35.01361,
#   'longitude': 69.17139,
#   'countrycode': 'AF',
#   'population': 53676,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '40',
#   'alternatenames': ['Caharikar',
#    'Carikar',
#    'Carikaras',
#    'Chaharikar',
#    'Chahārīkār',
#    'Chairkar',
#    'Charekar',
#    'Charikar',
#    'Chāirkār',
#    'Chārīkār',
#    'Czarikar',
#    'Cāṟikāṟ',
#    'Tscharikar',
#    'carikar',
#    'carikara',
#    'charikari',
#    'charykar',
#    'qia li ka er',
#    'Çarikar',
#    'Ĉarikar',
#    'Čahārikār',
#    'Čarikaras',
#    'Чарикар',
#    'چاريكار',
#    'چاریکار',
#    'चारीकार',
#    'চরিকর',
#    'சாரிகார்',
#    'ჩარიქარი',
#    '恰里卡尔']},
#  '1147066': {'geonameid': 1147066,
#   'name': 'Baraki Barak',
#   'latitude': 33.96744,
#   'longitude': 68.9492,
#   'countrycode': 'AF',
#   'population': 22305,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '17',
#   'alternatenames': ['Barah Ki Barak',
#    'Barah Kī Barak',
#    'Baraki Barak',
#    'Baraki Burak',
#    'Barakibarak',
#    'Barakī Barak',
#    'Barqi Barq',
#    'OAA',
#    'brh ky brk',
#    'brky brk',
#    'بره کی برک',
#    'برکی برک']},
#  '1147242': {'geonameid': 1147242,
#   'name': 'Bāmyān',
#   'latitude': 34.82156,
#   'longitude': 67.82734,
#   'countrycode': 'AF',
#   'population': 61863,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '05',
#   'alternatenames': ['BIN',
#    'Bamian',
#    'Bamiyan',
#    'Bamyan',
#    'Bāmyān',
#    'Bāmīān',
#    'Kala Sarkari',
#    'Qal`a Sarkarit',
#    'Qala Sarkari',
#    'Qala Sarkāri',
#    'Qal‘a Sarkārit',
#    'bamyan',
#    'باميان']},
#  '1147290': {'geonameid': 1147290,
#   'name': 'Balkh',
#   'latitude': 36.75635,
#   'longitude': 66.8972,
#   'countrycode': 'AF',
#   'population': 114883,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['Bactra',
#    'Bactresh',
#    'Bakhtar',
#    'Balch',
#    'Balchas',
#    'Balh',
#    'Balhika',
#    'Balho',
#    'Balj',
#    'Balkh',
#    'Balx',
#    'Balĥo',
#    'Bamik',
#    'Bazirabad',
#    'Belh',
#    'Belx',
#    'Bkahdi',
#    'Bākhtar',
#    'Daerah Balkh',
#    'Quan Balkh',
#    'Quận Balkh',
#    'Vazirabad',
#    'ba er he',
#    'balheu',
#    'barufu',
#    'blk',
#    'blkh',
#    'Μπαλχ',
#    'Балх',
#    'Вазирабад',
#    'Բալխ',
#    'בלך',
#    'بلخ',
#    'বাল্\u200cখ',
#    'ബൽഖ്',
#    'バルフ',
#    '巴尔赫',
#    '발흐']},
#  '1147540': {'geonameid': 1147540,
#   'name': 'Baghlān',
#   'latitude': 36.13068,
#   'longitude': 68.70829,
#   'countrycode': 'AF',
#   'population': 108449,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Baghlan',
#    'Baghlan - bghlan',
#    'Baghlan-e Jadid',
#    'Baghlin',
#    'Baghlān',
#    'Baghlān-e Jadīd',
#    'Baglan',
#    'Bagolaggo',
#    'Sana `Ati',
#    'Sana`ati',
#    'bghlan',
#    'bghlan jdyd',
#    'Şanā ‘Ati',
#    'Şanā‘atī',
#    'Баглан',
#    'بغلان',
#    'بغلان جديد',
#    'صناعتی']},
#  '1148106': {'geonameid': 1148106,
#   'name': 'Ārt Khwājah',
#   'latitude': 37.08571,
#   'longitude': 69.47958,
#   'countrycode': 'AF',
#   'population': 18623,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Art Khvajeh (1)',
#    'Art Khwajah',
#    'At Khvajeh',
#    'At Khwaja',
#    'art khwajh',
#    'Ārt Khwājah',
#    'Āt Khvājeh',
#    'Āt Khwāja',
#    'Āṟt Khvājeh (1)',
#    'آرت خواجه']},
#  '1148205': {'geonameid': 1148205,
#   'name': 'Āsmār',
#   'latitude': 35.03333,
#   'longitude': 71.35809,
#   'countrycode': 'AF',
#   'population': 15708,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '34',
#   'alternatenames': ['Asma',
#    'Asmar',
#    'Asmār',
#    'asmar',
#    'Āsmā',
#    'Āsmār',
#    'آسمار',
#    'اسمار']},
#  '1148311': {'geonameid': 1148311,
#   'name': 'Asadābād',
#   'latitude': 34.87311,
#   'longitude': 71.14697,
#   'countrycode': 'AF',
#   'population': 48400,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '34',
#   'alternatenames': ['Asadabad',
#    'Asadābād',
#    'Assad-Abad',
#    'Caghasaray',
#    'Chagha Serai',
#    'Chagha-Sari',
#    'Chaghah Saray',
#    'Chaghah Sarāy',
#    'Chaghasarai',
#    'Chaghasaray',
#    'Chaghasarāy',
#    'Chagsarai',
#    'Chegheh Saray',
#    'Chegheh Sarāy',
#    'Chigha Sarai',
#    'Chigha Sarāi',
#    'Chigha Serai',
#    'Chigkhasaray',
#    'asd abad',
#    'chghh sray',
#    'Čaghasarāy',
#    'Асадабад',
#    'اسد آباد',
#    'چغه سرای']},
#  '1148658': {'geonameid': 1148658,
#   'name': 'Andkhōy',
#   'latitude': 36.95293,
#   'longitude': 65.12376,
#   'countrycode': 'AF',
#   'population': 29208,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '07',
#   'alternatenames': ['Andkhoi',
#    'Andkhoy',
#    'Andkhui',
#    'Andkhvoy',
#    'Andkhōy',
#    'Andkhōī',
#    'Andkhūi',
#    'Ankhoi',
#    'andkhwy',
#    'اندخوی']},
#  '1429434': {'geonameid': 1429434,
#   'name': 'Bāzārak',
#   'latitude': 35.31292,
#   'longitude': 69.51519,
#   'countrycode': 'AF',
#   'population': 65000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '42',
#   'alternatenames': ['Bazarak',
#    'Bāzārak',
#    'bazark',
#    'Базарак',
#    'بازارك',
#    'بازارک']},
#  '1469706': {'geonameid': 1469706,
#   'name': 'Markaz-e Woluswalī-ye Āchīn',
#   'latitude': 34.12583,
#   'longitude': 70.70778,
#   'countrycode': 'AF',
#   'population': 15098,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '18',
# ...
#    'silles',
#    'sylht',
#    'sylt',
#    'xi er he te shi',
#    'Силхет',
#    'Сілет',
#    'سلہٹ',
#    'سيلهت',
#    'سیلت',
#    'सिलहट',
#    'সিলেট',
#    'சில்ஹெட்',
#    'സിൽഹെറ്റ്',
#    'シレット',
#    '錫爾赫特市',
#    '실렛']},
#  '1185100': {'geonameid': 1185100,
#   'name': 'Dohār',
#   'latitude': 23.59311,
#   'longitude': 90.14251,
#   'countrycode': 'BD',
#   'population': 45543,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Dohai',
#    'Dohar',
#    'Dohāi',
#    'Dohār',
#    'Sutarpara',
#    'Sutārpara']},
#  '1185105': {'geonameid': 1185105,
#   'name': 'Sunāmganj',
#   'latitude': 25.06889,
#   'longitude': 91.40243,
#   'countrycode': 'BD',
#   'population': 74570,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Sonamganj', 'Sunamganj', 'Sunāmganj']},
#  '1185106': {'geonameid': 1185106,
#   'name': 'Jamālpur',
#   'latitude': 24.91965,
#   'longitude': 89.94812,
#   'countrycode': 'BD',
#   'population': 167900,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Jamaipur',
#    'Jamalpur',
#    'Jamālpur',
#    'Singhjani',
#    'Singhjāni']},
#  '1185107': {'geonameid': 1185107,
#   'name': 'Shibganj',
#   'latitude': 25.00146,
#   'longitude': 89.32266,
#   'countrycode': 'BD',
#   'population': 378701,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Shibgandzh', 'Shibganj', 'Sibganj', 'Шибгандж']},
#  '1185108': {'geonameid': 1185108,
#   'name': 'Shibganj',
#   'latitude': 24.68501,
#   'longitude': 88.15638,
#   'countrycode': 'BD',
#   'population': 35961,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Shibganj', 'Sibganj']},
#  '1185111': {'geonameid': 1185111,
#   'name': 'Sātkhira',
#   'latitude': 22.70817,
#   'longitude': 89.07185,
#   'countrycode': 'BD',
#   'population': 128918,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Satkhira', 'Shatkhira', 'Sātkhira']},
#  '1185115': {'geonameid': 1185115,
#   'name': 'Sirajganj',
#   'latitude': 24.45771,
#   'longitude': 89.70802,
#   'countrycode': 'BD',
#   'population': 127481,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['SAJ',
#    'Serajganj Municipality',
#    'Siradzhgandzh',
#    'Sirajganj',
#    'Siranganj',
#    'Sirājganj',
#    'sirajaganja',
#    'Сираджгандж',
#    'সিরাজগঞ্জ']},
#  '1185116': {'geonameid': 1185116,
#   'name': 'Netrakona',
#   'latitude': 24.88352,
#   'longitude': 90.72898,
#   'countrycode': 'BD',
#   'population': 79016,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Netrakona', 'Satpai', 'Sātpāi']},
#  '1185117': {'geonameid': 1185117,
#   'name': 'Narsingdi',
#   'latitude': 23.92298,
#   'longitude': 90.71768,
#   'countrycode': 'BD',
#   'population': 281080,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Narsingdi', 'Narsinghdi', 'Satirpara', 'Satirpāra']},
#  '1185120': {'geonameid': 1185120,
#   'name': 'Sandwīp',
#   'latitude': 22.51409,
#   'longitude': 91.45491,
#   'countrycode': 'BD',
#   'population': 52152,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Sandvip', 'Sandwip', 'Sandwīp', 'Сандвип']},
#  '1185121': {'geonameid': 1185121,
#   'name': 'Shāhzādpur',
#   'latitude': 24.17687,
#   'longitude': 89.5988,
#   'countrycode': 'BD',
#   'population': 102420,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Sahzadpur', 'Shahzadpur', 'Shāhzādpur']},
#  '1185127': {'geonameid': 1185127,
#   'name': 'Rāmganj',
#   'latitude': 23.1006,
#   'longitude': 90.84989,
#   'countrycode': 'BD',
#   'population': 55241,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Ramganj', 'Ratanpur', 'Rāmganj']},
#  '1185128': {'geonameid': 1185128,
#   'name': 'Rajshahi',
#   'latitude': 24.374,
#   'longitude': 88.60114,
#   'countrycode': 'BD',
#   'population': 763580,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['RJH',
#    'Radzhshakhi',
#    'Rajshahi',
#    'Rampur Baolia',
#    'Rampur Bauleah',
#    'Rampur Boalia',
#    'Rājshāhi',
#    'rajasahi',
#    'Раджшахи',
#    'রাজশাহী']},
#  '1185138': {'geonameid': 1185138,
#   'name': 'Pirojpur',
#   'latitude': 22.57965,
#   'longitude': 89.97521,
#   'countrycode': 'BD',
#   'population': 54418,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Perijpur', 'Perojpur Municipality', 'Pirojpur']},
#  '1185141': {'geonameid': 1185141,
#   'name': 'Panchagarh',
#   'latitude': 26.33338,
#   'longitude': 88.55777,
#   'countrycode': 'BD',
#   'population': 48531,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Pachagar', 'Pachagarh', 'Pachāgarh', 'Panchagarh']},
#  '1185148': {'geonameid': 1185148,
#   'name': 'Patiya',
#   'latitude': 22.29543,
#   'longitude': 91.979,
#   'countrycode': 'BD',
#   'population': 51360,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Patia', 'Patiya']},
#  '1185149': {'geonameid': 1185149,
#   'name': 'Parbatipur',
#   'latitude': 25.66369,
#   'longitude': 88.93093,
#   'countrycode': 'BD',
#   'population': 48020,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Parbatipur', 'Parvatipur', 'Pārvatīpur']},
#  '1185155': {'geonameid': 1185155,
#   'name': 'Nārāyanganj',
#   'latitude': 23.61352,
#   'longitude': 90.50298,
#   'countrycode': 'BD',
#   'population': 223622,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Narajanganj', 'Narayanganj', 'Nārāyanganj']},
#  '1185156': {'geonameid': 1185156,
#   'name': 'Nālchiti',
#   'latitude': 22.63696,
#   'longitude': 90.27195,
#   'countrycode': 'BD',
#   'population': 38703,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Nalchhiti', 'Nalchiti', 'Nālchiti']},
#  '1185159': {'geonameid': 1185159,
#   'name': 'Nāgarpur',
#   'latitude': 24.05783,
#   'longitude': 89.87696,
#   'countrycode': 'BD',
#   'population': 238422,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Nagarpur', 'Nagurpoor', 'Nāgarpur']},
#  '1185160': {'geonameid': 1185160,
#   'name': 'Nageswari',
#   'latitude': 25.96817,
#   'longitude': 89.69153,
#   'countrycode': 'BD',
#   'population': 49425,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Nagasewari',
#    'Nageshawari',
#    'Nageshwari',
#    'Nageswari',
#    'Nagheswari',
#    'Nāgeshwari',
#    'Paschim Nageswari']},
#  '1185162': {'geonameid': 1185162,
#   'name': 'Mymensingh',
#   'latitude': 24.75636,
#   'longitude': 90.40646,
#   'countrycode': 'BD',
#   'population': 225126,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Majmensingkh',
#    'Mymensing',
#    'Mymensingh',
#    'Nasirabad',
#    'Nasirābād',
#    'mayamanasinha',
#    'Майменсингх',
#    'ময়মনসিংহ']},
#  '1185164': {'geonameid': 1185164,
#   'name': 'Muktāgācha',
#   'latitude': 24.76484,
#   'longitude': 90.25698,
#   'countrycode': 'BD',
#   'population': 24684,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Muktagacha', 'Muktagachha', 'Muktāgācha']},
#  '1185165': {'geonameid': 1185165,
#   'name': 'Mirzāpur',
#   'latitude': 24.10287,
#   'longitude': 90.09841,
#   'countrycode': 'BD',
#   'population': 41137,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Mirzapur', 'Mirzāpur', 'Mrizapur', 'Мирзапур']},
#  '1185166': {'geonameid': 1185166,
#   'name': 'Maulavi Bāzār',
#   'latitude': 24.48888,
#   'longitude': 91.77075,
#   'countrycode': 'BD',
#   'population': 57441,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Maulavi Bazar',
#    'Maulavi Bāzār',
#    'Maulvi Bazar',
#    'Maulvi Bāzār',
#    'Moulvi Bazar',
#    'Moulvi Bazar Municipality',
#    'Moulvi Bāzār',
#    'Moulvibazar']},
#  '1185167': {'geonameid': 1185167,
#   'name': 'Morrelgonj',
#   'latitude': 22.45566,
#   'longitude': 89.85584,
#   'countrycode': 'BD',
#   'population': 31647,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Fakirertakia',
#    'Fakirertākia',
#    'Morrelganj',
#    'Morrelgonj',
#    'Morrellganj']},
#  '1185171': {'geonameid': 1185171,
#   'name': 'Mehendiganj',
#   'latitude': 22.82257,
#   'longitude': 90.52859,
#   'countrycode': 'BD',
#   'population': 39424,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Mehdigunj', 'Mehendiganj', 'mhndyganj', 'مهندیگانج']},
#  '1185173': {'geonameid': 1185173,
#   'name': 'Mathba',
#   'latitude': 22.28616,
#   'longitude': 89.95883,
#   'countrycode': 'BD',
#   'population': 29760,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Matbari',
#    'Matbaria',
#    'Matbāri',
#    'Mathba',
#    'Mathbari',
#    'Mathbaria',
#    'Sankibhanga']},
#  '1185181': {'geonameid': 1185181,
#   'name': 'Lalmonirhat',
#   'latitude': 25.91719,
#   'longitude': 89.44595,
#   'countrycode': 'BD',
#   'population': 65127,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['LLJ',
#    'Lalmanir Hat',
#    'Lalmanirat',
#    'Lalmanirhat',
#    'Lalmonirhat',
#    'Lālmanir Hāt']},
#  '1185183': {'geonameid': 1185183,
#   'name': 'Lākshām',
#   'latitude': 23.24018,
#   'longitude': 91.12143,
#   'countrycode': 'BD',
#   'population': 82290,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Laksam', 'Laksham', 'Lākshām']},
#  '1185186': {'geonameid': 1185186,
#   'name': 'Comilla',
#   'latitude': 23.46186,
#   'longitude': 91.18503,
#   'countrycode': 'BD',
#   'population': 1030000,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['CLA',
#    'Comilla',
#    'Komila',
#    'Komilla',
#    'Komille',
#    'Kumilla',
#    'Kumillā',
#    'khu mi l la',
#    'komilla',
#    'kumilla',
#    'kumirra',
#    'kwmyla',
#    'Комилла',
#    'Комилле',
#    'کومیلا',
#    'कोमिल्ला',
#    'কুমিল্লা',
#    'คูมิลลา',
#    'クミッラ']},
#  '1185188': {'geonameid': 1185188,
#   'name': 'Rangpur',
#   'latitude': 25.74664,
#   'longitude': 89.25166,
#   'countrycode': 'BD',
#   'population': 1031388,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Kotwali',
#    'Kotwāli',
#    'Mosque Rangpur',
#    'RAU',
#    'Rangpur',
#    'Rangpur City',
#    'Rangpuras',
#    'Rongpur',
#    'lang bu er shi',
#    'langpuleu',
#    'rampura',
#    'ranpuru',
#    'Рангпур',
#    'رنگپور شہر',
#    'রংপুর',
#    'ランプル',
#    '朗布尔市',
#    '랑푸르']},
#  '1185191': {'geonameid': 1185191,
#   'name': 'Kushtia',
#   'latitude': 23.9028,
#   'longitude': 89.11943,
#   'countrycode': 'BD',
#   'population': 135724,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Khustia', 'Kushtia']},
#  '1185199': {'geonameid': 1185199,
#   'name': 'Kālīganj',
#   'latitude': 23.40964,
#   'longitude': 89.13801,
#   'countrycode': 'BD',
#   'population': 45631,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Aliganj', 'Kaliganj', 'Kaliganja', 'Kālīganj']},
#  '1185204': {'geonameid': 1185204,
#   'name': 'Jhingergācha',
#   'latitude': 23.11134,
#   'longitude': 89.09061,
#   'countrycode': 'BD',
#   'population': 41957,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Jhikargacha',
#    'Jhikargachha',
#    'Jhikargāchha',
#    'Jhikergacha',
#    'Jhingergacha',
#    'Jhingergācha',
#    'Jhinkargacha']},
#  '1185206': {'geonameid': 1185206,
#   'name': 'Joypur Hāt',
#   'latitude': 25.10147,
#   'longitude': 89.02734,
#   'countrycode': 'BD',
#   'population': 73068,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Jaipur Hat',
#    'Jaipur Hāt',
#    'Jaypur Hat',
#    'Joypur Hat',
#    'Joypur Hāt',
#    'Joypurhat']},
#  '1185207': {'geonameid': 1185207,
#   'name': 'Ishwardi',
#   'latitude': 24.12858,
#   'longitude': 89.06573,
#   'countrycode': 'BD',
#   'population': 81995,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['IRD', 'Ishwardi', 'isbaradi', 'ঈশ্বরদী']},
#  '1185209': {'geonameid': 1185209,
#   'name': 'Habiganj',
#   'latitude': 24.38044,
#   'longitude': 91.41299,
#   'countrycode': 'BD',
#   'population': 88760,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Habiganj',
#    'Habiganj Bazar',
#    'Habiganj Sadar',
#    'Hobiganj',
#    'Khabigandzh',
#    'habiganja',
#    'hby gnj',
#    'hbyganj',
#    'hbyghnj',
#    'hbyjnj',
#    'Хабигандж',
#    'حبيجنج',
#    'حبيغنج',
#    'حبی گنج',
#    'حبیگانج',
#    'হবিগঞ্জ']},
#  '1185210': {'geonameid': 1185210,
#   'name': 'Gaurnadi',
#   'latitude': 22.97372,
#   'longitude': 90.22376,
#   'countrycode': 'BD',
#   'population': 40519,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Gaurnadi', 'Gournadi']},
#  '1185218': {'geonameid': 1185218,
#   'name': 'Gafargaon',
#   'latitude': 24.432,
#   'longitude': 90.5585,
#   'countrycode': 'BD',
#   'population': 34177,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Gafargaon', 'Gaffargaon', 'Ghafargaon']},
#  '1185224': {'geonameid': 1185224,
#   'name': 'Feni',
#   'latitude': 23.0144,
#   'longitude': 91.3966,
#   'countrycode': 'BD',
#   'population': 84028,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Feni',
#    'Feni  Bangladesh',
#    'Fenny',
#    'feni',
#    'fyny',
#    'peni',
#    'pheni',
#    'Φένι',
#    'Фени',
#    'فئنی',
#    'فيني',
#    'فینی، بنگلہ دیش',
#    'ফেনী',
#    'பெனி',
#    'フェニ']},
#  '1185236': {'geonameid': 1185236,
#   'name': 'Rāipur',
#   'latitude': 23.0391,
#   'longitude': 90.76808,
#   'countrycode': 'BD',
#   'population': 64652,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Deyanatpur',
#    'Deyānatpur',
#    'Raipur',
#    'Rajpur',
#    'Raypur',
#    'Rāipur',
#    'Райпур']},
#  '1185239': {'geonameid': 1185239,
#   'name': 'Sarankhola',
#   'latitude': 22.31006,
#   'longitude': 89.79113,
#   'countrycode': 'BD',
#   'population': 36470,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Dakshin Rajapur', 'Dakshin Rājāpur', 'Sarankhola']},
#  '1185240': {'geonameid': 1185240,
#   'name': 'Ramna Maidan',
#   'latitude': 23.73333,
#   'longitude': 90.4,
#   'countrycode': 'BD',
#   'population': 143677,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Dacca Ramna', 'Ramna', 'Ramna Maidan']},
#  '1185241': {'geonameid': 1185241,
#   'name': 'Dhaka',
#   'latitude': 23.7104,
#   'longitude': 90.40744,
#   'countrycode': 'BD',
#   'population': 10356500,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['DAC',
#    'Daaka',
#    'Daca',
#    'Dacca',
#    'Daka',
#    'Dakah',
#    'Dakk',
#    'Dakka',
#    'Dakkae',
#    'Dakke',
#    'Dako',
#    'Deka',
#    'Dgaka',
#    'Dhaka',
#    'Dháka',
#    'Dhâkâ',
#    'Dəkkə',
#    'Mujib City',
#    'Ntaka',
#    'Ntakka',
#    'da ka',
#    'daka',
#    'dakka',
#    'dhaka',
#    'dhakka',
#    'dka',
#    'takka',
#    'thaka',
#    'Ντάκα',
#    'Ντάκκα',
#    'Даака',
#    'Дака',
#    'Даккæ',
#    'Дакка',
#    'Дакке',
#    'Дгака',
#    'Դաքքա',
#    'דאקא',
#    'דאקה',
#    'داكا',
#    'داکا',
#    'دكا',
#    'ڈھاکہ',
#    'ޑާކާ',
#    'ढाका',
#    'ঢাকা',
#    'ਢਾਕਾ',
#    'ઢાકા',
#    'ଢାକା',
#    'டாக்கா',
#    'ఢాకా',
#    'ಢಾಕಾ',
#    'ഢാക്ക',
#    'ඩකා',
#    'ธากา',
#    'དྷ་ཁ།',
#    'ဒါကာမြို့',
#    'დაკა',
#    'ዳካ',
#    'ダッカ',
#    '达卡',
#    '達卡',
#    '다카']},
#  '1185247': {'geonameid': 1185247,
#   'name': 'Chilmāri',
#   'latitude': 25.55613,
#   'longitude': 89.67097,
#   'countrycode': 'BD',
#   'population': 49736,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Chillmari', 'Chilmari', 'Chilmāri']},
#  '1185249': {'geonameid': 1185249,
#   'name': 'Chhāgalnāiya',
#   'latitude': 23.02475,
#   'longitude': 91.51091,
#   'countrycode': 'BD',
#   'population': 39335,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Chhagainaya',
#    'Chhagalnaia',
#    'Chhagalnaiya',
#    'Chhagalnaya',
#    'Chhāgalnāiya',
#    'Paschim Chhagalnaiya',
#    'Paschim Chhāgalnāiya',
#    'West Chhagal Naiya',
#    'West Chhagalnaia']},
#  '1185251': {'geonameid': 1185251,
#   'name': 'Lālmohan',
#   'latitude': 22.33774,
#   'longitude': 90.73708,
#   'countrycode': 'BD',
#   'population': 42220,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Char Lalmohan',
#    'Char Lalmohun',
#    'Char Lālmohan',
#    'Dhar Lalmohan',
#    'Lalmohan',
#    'Lālmohan']},
#  '1185252': {'geonameid': 1185252,
#   'name': 'Khagrachhari',
#   'latitude': 23.10787,
#   'longitude': 91.97007,
#   'countrycode': 'BD',
#   'population': 50364,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Changrachhari',
#    'Khabangpari',
#    'Khagrachari',
#    'Khagrachhari',
#    'Khagrāchari',
#    'Khagrāchhari',
#    'Kkhagrachari',
#    'Кхаграчари']},
#  ...}

# %%
try:
    COUNTRY_LOOKUP = {}
    for c in pycountry.countries:
        COUNTRY_LOOKUP[c.name.lower()] = c.alpha_2
        if hasattr(c, "official_name"):
            COUNTRY_LOOKUP[c.official_name.lower()] = c.alpha_2
    # Common aliases
    COUNTRY_LOOKUP.update({
        "uk": "GB", "u.k.": "GB", "united kingdom": "GB", "great britain": "GB", "britain": "GB",
        "usa": "US", "u.s.a.": "US", "u.s.": "US", "united states": "US", "united states of america": "US",
        "russia": "RU", "south korea": "KR", "korea": "KR", "north korea": "KP",
        "iran": "IR", "viet nam": "VN",
        "taiwan": "TW",  # pycountry has Taiwan as "Taiwan, Province of China" in some datasets
    })
except Exception:
    COUNTRY_LOOKUP = {
        "united kingdom": "GB", "uk": "GB", "britain": "GB",
        "united states": "US", "usa": "US",
        "canada": "CA", "france": "FR", "germany": "DE",
        "china": "CN", "japan": "JP", "india": "IN",
        "australia": "AU", "spain": "ES", "italy": "IT",
    }

# %%
US_STATE_TO_US = {
    "al","ak","az","ar","ca","co","ct","de","fl","ga","hi","ia","id","il","in","ks","ky","la","ma","md",
    "me","mi","mn","mo","ms","mt","nc","nd","ne","nh","nj","nm","nv","ny","oh","ok","or","pa","ri","sc",
    "sd","tn","tx","ut","va","vt","wa","wi","wv","wy","dc"
}

CA_PROV_TO_CA = {"on","qc","bc","ab","mb","sk","ns","nb","nl","pe","nt","nu","yt"}

US_STATE_NAMES = {
    "alabama",
    "alaska",
    "arizona",
    "arkansas",
    "california",
    "colorado",
    "connecticut",
    "delaware",
    "florida",
    "georgia",
    "hawaii",
    "idaho",
    "illinois",
    "indiana",
    "iowa",
    "kansas",
    "kentucky",
    "louisiana",
    "maine",
    "maryland",
    "massachusetts",
    "michigan",
    "minnesota",
    "mississippi",
    "missouri",
    "montana",
    "nebraska",
    "nevada",
    "new hampshire",
    "new jersey",
    "new mexico",
    "new york",
    "north carolina",
    "north dakota",
    "ohio",
    "oklahoma",
    "oregon",
    "pennsylvania",
    "rhode island",
    "south carolina",
    "south dakota",
    "tennessee",
    "texas",
    "utah",
    "vermont",
    "virginia",
    "washington",
    "west virginia",
    "wisconsin",
    "wyoming",
    "district of columbia"
}

CA_PROV_NAMES = {    
    "alberta",
    "british columbia",
    "manitoba",
    "new brunswick",
    "newfoundland and labrador",
    "nova scotia",
    "ontario",
    "prince edward island",
    "quebec",
    "saskatchewan",
    "northwest territories",
    "nunavut",
    "yukon"
}

# %%
def city_to_country_safe(city_name, city_index):
    """
    city_index: dict[str, set[str]]
        e.g. {"berlin": {"DE"}, "paris": {"FR", "US"}}
    """
    city = city_name.lower().strip()

    for country_id in city_index:
        if city in country_id['alternatenames']:
            name = country_id['name']

    if not countries:
        return None            # not found
    if len(countries) == 1:
        return next(iter(countries))
    return None                # ambiguous → drop

# %%
g = gc.get_countries_by_names()
g
# Out:
# {'Andorra': {'geonameid': 3041565,
#   'name': 'Andorra',
#   'iso': 'AD',
#   'iso3': 'AND',
#   'isonumeric': 20,
#   'fips': 'AN',
#   'continentcode': 'EU',
#   'capital': 'Andorra la Vella',
#   'areakm2': 468,
#   'population': 77006,
#   'tld': '.ad',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '376',
#   'postalcoderegex': '^(?:AD)*(\\d{3})$',
#   'languages': 'ca',
#   'neighbours': 'ES,FR'},
#  'United Arab Emirates': {'geonameid': 290557,
#   'name': 'United Arab Emirates',
#   'iso': 'AE',
#   'iso3': 'ARE',
#   'isonumeric': 784,
#   'fips': 'AE',
#   'continentcode': 'AS',
#   'capital': 'Abu Dhabi',
#   'areakm2': 82880,
#   'population': 9630959,
#   'tld': '.ae',
#   'currencycode': 'AED',
#   'currencyname': 'Dirham',
#   'phone': '971',
#   'postalcoderegex': '^\\d{5}-\\d{5}$',
#   'languages': 'ar-AE,fa,en,hi,ur',
#   'neighbours': 'SA,OM'},
#  'Afghanistan': {'geonameid': 1149361,
#   'name': 'Afghanistan',
#   'iso': 'AF',
#   'iso3': 'AFG',
#   'isonumeric': 4,
#   'fips': 'AF',
#   'continentcode': 'AS',
#   'capital': 'Kabul',
#   'areakm2': 647500,
#   'population': 37172386,
#   'tld': '.af',
#   'currencycode': 'AFN',
#   'currencyname': 'Afghani',
#   'phone': '93',
#   'postalcoderegex': '',
#   'languages': 'fa-AF,ps,uz-AF,tk',
#   'neighbours': 'TM,CN,IR,TJ,PK,UZ'},
#  'Antigua and Barbuda': {'geonameid': 3576396,
#   'name': 'Antigua and Barbuda',
#   'iso': 'AG',
#   'iso3': 'ATG',
#   'isonumeric': 28,
#   'fips': 'AC',
#   'continentcode': 'NA',
#   'capital': "St. John's",
#   'areakm2': 443,
#   'population': 96286,
#   'tld': '.ag',
#   'currencycode': 'XCD',
#   'currencyname': 'Dollar',
#   'phone': '+1-268',
#   'postalcoderegex': '',
#   'languages': 'en-AG',
#   'neighbours': ''},
#  'Anguilla': {'geonameid': 3573511,
#   'name': 'Anguilla',
#   'iso': 'AI',
#   'iso3': 'AIA',
#   'isonumeric': 660,
#   'fips': 'AV',
#   'continentcode': 'NA',
#   'capital': 'The Valley',
#   'areakm2': 102,
#   'population': 13254,
#   'tld': '.ai',
#   'currencycode': 'XCD',
#   'currencyname': 'Dollar',
#   'phone': '+1-264',
#   'postalcoderegex': '^(?:AZ)*(\\d{4})$',
#   'languages': 'en-AI',
#   'neighbours': ''},
#  'Albania': {'geonameid': 783754,
#   'name': 'Albania',
#   'iso': 'AL',
#   'iso3': 'ALB',
#   'isonumeric': 8,
#   'fips': 'AL',
#   'continentcode': 'EU',
#   'capital': 'Tirana',
#   'areakm2': 28748,
#   'population': 2866376,
#   'tld': '.al',
#   'currencycode': 'ALL',
#   'currencyname': 'Lek',
#   'phone': '355',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'sq,el',
#   'neighbours': 'MK,GR,ME,RS,XK'},
#  'Armenia': {'geonameid': 174982,
#   'name': 'Armenia',
#   'iso': 'AM',
#   'iso3': 'ARM',
#   'isonumeric': 51,
#   'fips': 'AM',
#   'continentcode': 'AS',
#   'capital': 'Yerevan',
#   'areakm2': 29800,
#   'population': 3076200,
#   'tld': '.am',
#   'currencycode': 'AMD',
#   'currencyname': 'Dram',
#   'phone': '374',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'hy',
#   'neighbours': 'GE,IR,AZ,TR'},
#  'Angola': {'geonameid': 3351879,
#   'name': 'Angola',
#   'iso': 'AO',
#   'iso3': 'AGO',
#   'isonumeric': 24,
#   'fips': 'AO',
#   'continentcode': 'AF',
#   'capital': 'Luanda',
#   'areakm2': 1246700,
#   'population': 30809762,
#   'tld': '.ao',
#   'currencycode': 'AOA',
#   'currencyname': 'Kwanza',
#   'phone': '244',
#   'postalcoderegex': '',
#   'languages': 'pt-AO',
#   'neighbours': 'CD,NA,ZM,CG'},
#  'Antarctica': {'geonameid': 6697173,
#   'name': 'Antarctica',
#   'iso': 'AQ',
#   'iso3': 'ATA',
#   'isonumeric': 10,
#   'fips': 'AY',
#   'continentcode': 'AN',
#   'capital': '',
#   'areakm2': 14000000,
#   'population': 0,
#   'tld': '.aq',
#   'currencycode': '',
#   'currencyname': '',
#   'phone': '',
#   'postalcoderegex': '',
#   'languages': '',
#   'neighbours': ''},
#  'Argentina': {'geonameid': 3865483,
#   'name': 'Argentina',
#   'iso': 'AR',
#   'iso3': 'ARG',
#   'isonumeric': 32,
#   'fips': 'AR',
#   'continentcode': 'SA',
#   'capital': 'Buenos Aires',
#   'areakm2': 2766890,
#   'population': 44494502,
#   'tld': '.ar',
#   'currencycode': 'ARS',
#   'currencyname': 'Peso',
#   'phone': '54',
#   'postalcoderegex': '^[A-Z]?\\d{4}[A-Z]{0,3}$',
#   'languages': 'es-AR,en,it,de,fr,gn',
#   'neighbours': 'CL,BO,UY,PY,BR'},
#  'American Samoa': {'geonameid': 5880801,
#   'name': 'American Samoa',
#   'iso': 'AS',
#   'iso3': 'ASM',
#   'isonumeric': 16,
#   'fips': 'AQ',
#   'continentcode': 'OC',
#   'capital': 'Pago Pago',
#   'areakm2': 199,
#   'population': 55465,
#   'tld': '.as',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '+1-684',
#   'postalcoderegex': '96799',
#   'languages': 'en-AS,sm,to',
#   'neighbours': ''},
#  'Austria': {'geonameid': 2782113,
#   'name': 'Austria',
#   'iso': 'AT',
#   'iso3': 'AUT',
#   'isonumeric': 40,
#   'fips': 'AU',
#   'continentcode': 'EU',
#   'capital': 'Vienna',
#   'areakm2': 83858,
#   'population': 8847037,
#   'tld': '.at',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '43',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'de-AT,hr,hu,sl',
#   'neighbours': 'CH,DE,HU,SK,CZ,IT,SI,LI'},
#  'Australia': {'geonameid': 2077456,
#   'name': 'Australia',
#   'iso': 'AU',
#   'iso3': 'AUS',
#   'isonumeric': 36,
#   'fips': 'AS',
#   'continentcode': 'OC',
#   'capital': 'Canberra',
#   'areakm2': 7686850,
#   'population': 24992369,
#   'tld': '.au',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': '61',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'en-AU',
#   'neighbours': ''},
#  'Aruba': {'geonameid': 3577279,
#   'name': 'Aruba',
#   'iso': 'AW',
#   'iso3': 'ABW',
#   'isonumeric': 533,
#   'fips': 'AA',
#   'continentcode': 'NA',
#   'capital': 'Oranjestad',
#   'areakm2': 193,
#   'population': 105845,
#   'tld': '.aw',
#   'currencycode': 'AWG',
#   'currencyname': 'Guilder',
#   'phone': '297',
#   'postalcoderegex': '',
#   'languages': 'nl-AW,pap,es,en',
#   'neighbours': ''},
#  'Aland Islands': {'geonameid': 661882,
#   'name': 'Aland Islands',
#   'iso': 'AX',
#   'iso3': 'ALA',
#   'isonumeric': 248,
#   'fips': '',
#   'continentcode': 'EU',
#   'capital': 'Mariehamn',
#   'areakm2': 1580,
#   'population': 26711,
#   'tld': '.ax',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '+358-18',
#   'postalcoderegex': '^(?:FI)*(\\d{5})$',
#   'languages': 'sv-AX',
#   'neighbours': ''},
#  'Azerbaijan': {'geonameid': 587116,
#   'name': 'Azerbaijan',
#   'iso': 'AZ',
#   'iso3': 'AZE',
#   'isonumeric': 31,
#   'fips': 'AJ',
#   'continentcode': 'AS',
#   'capital': 'Baku',
#   'areakm2': 86600,
#   'population': 9942334,
#   'tld': '.az',
#   'currencycode': 'AZN',
#   'currencyname': 'Manat',
#   'phone': '994',
#   'postalcoderegex': '^(?:AZ )*(\\d{4})$',
#   'languages': 'az,ru,hy',
#   'neighbours': 'GE,IR,AM,TR,RU'},
#  'Bosnia and Herzegovina': {'geonameid': 3277605,
#   'name': 'Bosnia and Herzegovina',
#   'iso': 'BA',
#   'iso3': 'BIH',
#   'isonumeric': 70,
#   'fips': 'BK',
#   'continentcode': 'EU',
#   'capital': 'Sarajevo',
#   'areakm2': 51129,
#   'population': 3323929,
#   'tld': '.ba',
#   'currencycode': 'BAM',
#   'currencyname': 'Marka',
#   'phone': '387',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'bs,hr-BA,sr-BA',
#   'neighbours': 'HR,ME,RS'},
#  'Barbados': {'geonameid': 3374084,
#   'name': 'Barbados',
#   'iso': 'BB',
#   'iso3': 'BRB',
#   'isonumeric': 52,
#   'fips': 'BB',
#   'continentcode': 'NA',
#   'capital': 'Bridgetown',
#   'areakm2': 431,
#   'population': 286641,
#   'tld': '.bb',
#   'currencycode': 'BBD',
#   'currencyname': 'Dollar',
#   'phone': '+1-246',
#   'postalcoderegex': '^(?:BB)*(\\d{5})$',
#   'languages': 'en-BB',
#   'neighbours': ''},
#  'Bangladesh': {'geonameid': 1210997,
#   'name': 'Bangladesh',
#   'iso': 'BD',
#   'iso3': 'BGD',
#   'isonumeric': 50,
#   'fips': 'BG',
#   'continentcode': 'AS',
#   'capital': 'Dhaka',
#   'areakm2': 144000,
#   'population': 161356039,
#   'tld': '.bd',
#   'currencycode': 'BDT',
#   'currencyname': 'Taka',
#   'phone': '880',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'bn-BD,en',
#   'neighbours': 'MM,IN'},
#  'Belgium': {'geonameid': 2802361,
#   'name': 'Belgium',
#   'iso': 'BE',
#   'iso3': 'BEL',
#   'isonumeric': 56,
#   'fips': 'BE',
#   'continentcode': 'EU',
#   'capital': 'Brussels',
#   'areakm2': 30510,
#   'population': 11422068,
#   'tld': '.be',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '32',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'nl-BE,fr-BE,de-BE',
#   'neighbours': 'DE,NL,LU,FR'},
#  'Burkina Faso': {'geonameid': 2361809,
#   'name': 'Burkina Faso',
#   'iso': 'BF',
#   'iso3': 'BFA',
#   'isonumeric': 854,
#   'fips': 'UV',
#   'continentcode': 'AF',
#   'capital': 'Ouagadougou',
#   'areakm2': 274200,
#   'population': 19751535,
#   'tld': '.bf',
#   'currencycode': 'XOF',
#   'currencyname': 'Franc',
#   'phone': '226',
#   'postalcoderegex': '',
#   'languages': 'fr-BF,mos',
#   'neighbours': 'NE,BJ,GH,CI,TG,ML'},
#  'Bulgaria': {'geonameid': 732800,
#   'name': 'Bulgaria',
#   'iso': 'BG',
#   'iso3': 'BGR',
#   'isonumeric': 100,
#   'fips': 'BU',
#   'continentcode': 'EU',
#   'capital': 'Sofia',
#   'areakm2': 110910,
#   'population': 7000039,
#   'tld': '.bg',
#   'currencycode': 'BGN',
#   'currencyname': 'Lev',
#   'phone': '359',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'bg,tr-BG,rom',
#   'neighbours': 'MK,GR,RO,TR,RS'},
#  'Bahrain': {'geonameid': 290291,
#   'name': 'Bahrain',
#   'iso': 'BH',
#   'iso3': 'BHR',
#   'isonumeric': 48,
#   'fips': 'BA',
#   'continentcode': 'AS',
#   'capital': 'Manama',
#   'areakm2': 665,
#   'population': 1569439,
#   'tld': '.bh',
#   'currencycode': 'BHD',
#   'currencyname': 'Dinar',
#   'phone': '973',
#   'postalcoderegex': '^(\\d{3}\\d?)$',
#   'languages': 'ar-BH,en,fa,ur',
#   'neighbours': ''},
#  'Burundi': {'geonameid': 433561,
#   'name': 'Burundi',
#   'iso': 'BI',
#   'iso3': 'BDI',
#   'isonumeric': 108,
#   'fips': 'BY',
#   'continentcode': 'AF',
#   'capital': 'Gitega',
#   'areakm2': 27830,
#   'population': 11175378,
#   'tld': '.bi',
#   'currencycode': 'BIF',
#   'currencyname': 'Franc',
#   'phone': '257',
#   'postalcoderegex': '',
#   'languages': 'fr-BI,rn',
#   'neighbours': 'TZ,CD,RW'},
#  'Benin': {'geonameid': 2395170,
#   'name': 'Benin',
#   'iso': 'BJ',
#   'iso3': 'BEN',
#   'isonumeric': 204,
#   'fips': 'BN',
#   'continentcode': 'AF',
#   'capital': 'Porto-Novo',
#   'areakm2': 112620,
#   'population': 11485048,
#   'tld': '.bj',
#   'currencycode': 'XOF',
#   'currencyname': 'Franc',
#   'phone': '229',
#   'postalcoderegex': '',
#   'languages': 'fr-BJ',
#   'neighbours': 'NE,TG,BF,NG'},
#  'Saint Barthelemy': {'geonameid': 3578476,
#   'name': 'Saint Barthelemy',
#   'iso': 'BL',
#   'iso3': 'BLM',
#   'isonumeric': 652,
#   'fips': 'TB',
#   'continentcode': 'NA',
#   'capital': 'Gustavia',
#   'areakm2': 21,
#   'population': 8450,
#   'tld': '.gp',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '590',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'fr',
#   'neighbours': ''},
#  'Bermuda': {'geonameid': 3573345,
#   'name': 'Bermuda',
#   'iso': 'BM',
#   'iso3': 'BMU',
#   'isonumeric': 60,
#   'fips': 'BD',
#   'continentcode': 'NA',
#   'capital': 'Hamilton',
#   'areakm2': 53,
#   'population': 63968,
#   'tld': '.bm',
#   'currencycode': 'BMD',
#   'currencyname': 'Dollar',
#   'phone': '+1-441',
#   'postalcoderegex': '^([A-Z]{2}\\d{2})$',
#   'languages': 'en-BM,pt',
#   'neighbours': ''},
#  'Brunei': {'geonameid': 1820814,
#   'name': 'Brunei',
#   'iso': 'BN',
#   'iso3': 'BRN',
#   'isonumeric': 96,
#   'fips': 'BX',
#   'continentcode': 'AS',
#   'capital': 'Bandar Seri Begawan',
#   'areakm2': 5770,
#   'population': 428962,
#   'tld': '.bn',
#   'currencycode': 'BND',
#   'currencyname': 'Dollar',
#   'phone': '673',
#   'postalcoderegex': '^([A-Z]{2}\\d{4})$',
#   'languages': 'ms-BN,en-BN',
#   'neighbours': 'MY'},
#  'Bolivia': {'geonameid': 3923057,
#   'name': 'Bolivia',
#   'iso': 'BO',
#   'iso3': 'BOL',
#   'isonumeric': 68,
#   'fips': 'BL',
#   'continentcode': 'SA',
#   'capital': 'Sucre',
#   'areakm2': 1098580,
#   'population': 11353142,
#   'tld': '.bo',
#   'currencycode': 'BOB',
#   'currencyname': 'Boliviano',
#   'phone': '591',
#   'postalcoderegex': '',
#   'languages': 'es-BO,qu,ay',
#   'neighbours': 'PE,CL,PY,BR,AR'},
#  'Bonaire, Saint Eustatius and Saba ': {'geonameid': 7626844,
#   'name': 'Bonaire, Saint Eustatius and Saba ',
#   'iso': 'BQ',
#   'iso3': 'BES',
#   'isonumeric': 535,
#   'fips': '',
#   'continentcode': 'NA',
#   'capital': '',
#   'areakm2': 328,
#   'population': 18012,
#   'tld': '.bq',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '599',
#   'postalcoderegex': '',
#   'languages': 'nl,pap,en',
#   'neighbours': ''},
#  'Brazil': {'geonameid': 3469034,
#   'name': 'Brazil',
#   'iso': 'BR',
#   'iso3': 'BRA',
#   'isonumeric': 76,
#   'fips': 'BR',
#   'continentcode': 'SA',
#   'capital': 'Brasilia',
#   'areakm2': 8511965,
#   'population': 209469333,
#   'tld': '.br',
#   'currencycode': 'BRL',
#   'currencyname': 'Real',
#   'phone': '55',
#   'postalcoderegex': '^\\d{5}-\\d{3}$',
#   'languages': 'pt-BR,es,en,fr',
#   'neighbours': 'SR,PE,BO,UY,GY,PY,GF,VE,CO,AR'},
#  'Bahamas': {'geonameid': 3572887,
#   'name': 'Bahamas',
#   'iso': 'BS',
#   'iso3': 'BHS',
#   'isonumeric': 44,
#   'fips': 'BF',
#   'continentcode': 'NA',
#   'capital': 'Nassau',
#   'areakm2': 13940,
#   'population': 385640,
#   'tld': '.bs',
#   'currencycode': 'BSD',
#   'currencyname': 'Dollar',
#   'phone': '+1-242',
#   'postalcoderegex': '',
#   'languages': 'en-BS',
#   'neighbours': ''},
#  'Bhutan': {'geonameid': 1252634,
#   'name': 'Bhutan',
#   'iso': 'BT',
#   'iso3': 'BTN',
#   'isonumeric': 64,
#   'fips': 'BT',
#   'continentcode': 'AS',
#   'capital': 'Thimphu',
#   'areakm2': 47000,
#   'population': 754394,
#   'tld': '.bt',
#   'currencycode': 'BTN',
#   'currencyname': 'Ngultrum',
#   'phone': '975',
#   'postalcoderegex': '',
#   'languages': 'dz',
#   'neighbours': 'CN,IN'},
#  'Bouvet Island': {'geonameid': 3371123,
#   'name': 'Bouvet Island',
#   'iso': 'BV',
#   'iso3': 'BVT',
#   'isonumeric': 74,
#   'fips': 'BV',
#   'continentcode': 'AN',
#   'capital': '',
#   'areakm2': 49,
#   'population': 0,
#   'tld': '.bv',
#   'currencycode': 'NOK',
#   'currencyname': 'Krone',
#   'phone': '',
#   'postalcoderegex': '',
#   'languages': '',
#   'neighbours': ''},
#  'Botswana': {'geonameid': 933860,
#   'name': 'Botswana',
#   'iso': 'BW',
#   'iso3': 'BWA',
#   'isonumeric': 72,
#   'fips': 'BC',
#   'continentcode': 'AF',
#   'capital': 'Gaborone',
#   'areakm2': 600370,
#   'population': 2254126,
#   'tld': '.bw',
#   'currencycode': 'BWP',
#   'currencyname': 'Pula',
#   'phone': '267',
#   'postalcoderegex': '',
#   'languages': 'en-BW,tn-BW',
#   'neighbours': 'ZW,ZA,NA'},
#  'Belarus': {'geonameid': 630336,
#   'name': 'Belarus',
#   'iso': 'BY',
#   'iso3': 'BLR',
#   'isonumeric': 112,
#   'fips': 'BO',
#   'continentcode': 'EU',
#   'capital': 'Minsk',
#   'areakm2': 207600,
#   'population': 9485386,
#   'tld': '.by',
#   'currencycode': 'BYN',
#   'currencyname': 'Belarusian ruble',
#   'phone': '375',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'be,ru',
#   'neighbours': 'PL,LT,UA,RU,LV'},
#  'Belize': {'geonameid': 3582678,
#   'name': 'Belize',
#   'iso': 'BZ',
#   'iso3': 'BLZ',
#   'isonumeric': 84,
#   'fips': 'BH',
#   'continentcode': 'NA',
#   'capital': 'Belmopan',
#   'areakm2': 22966,
#   'population': 383071,
#   'tld': '.bz',
#   'currencycode': 'BZD',
#   'currencyname': 'Dollar',
#   'phone': '501',
#   'postalcoderegex': '',
#   'languages': 'en-BZ,es',
#   'neighbours': 'GT,MX'},
#  'Canada': {'geonameid': 6251999,
#   'name': 'Canada',
#   'iso': 'CA',
#   'iso3': 'CAN',
#   'isonumeric': 124,
#   'fips': 'CA',
#   'continentcode': 'NA',
#   'capital': 'Ottawa',
#   'areakm2': 9984670,
#   'population': 37058856,
#   'tld': '.ca',
#   'currencycode': 'CAD',
#   'currencyname': 'Dollar',
#   'phone': '1',
#   'postalcoderegex': '^([ABCEGHJKLMNPRSTVXY]\\d[ABCEGHJKLMNPRSTVWXYZ]) ?(\\d[ABCEGHJKLMNPRSTVWXYZ]\\d)$ ',
#   'languages': 'en-CA,fr-CA,iu',
#   'neighbours': 'US'},
#  'Cocos Islands': {'geonameid': 1547376,
#   'name': 'Cocos Islands',
#   'iso': 'CC',
#   'iso3': 'CCK',
#   'isonumeric': 166,
#   'fips': 'CK',
#   'continentcode': 'AS',
#   'capital': 'West Island',
#   'areakm2': 14,
#   'population': 628,
#   'tld': '.cc',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': '61',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'ms-CC,en',
#   'neighbours': ''},
#  'Democratic Republic of the Congo': {'geonameid': 203312,
#   'name': 'Democratic Republic of the Congo',
#   'iso': 'CD',
#   'iso3': 'COD',
#   'isonumeric': 180,
#   'fips': 'CG',
#   'continentcode': 'AF',
#   'capital': 'Kinshasa',
#   'areakm2': 2345410,
#   'population': 84068091,
#   'tld': '.cd',
#   'currencycode': 'CDF',
#   'currencyname': 'Franc',
#   'phone': '243',
#   'postalcoderegex': '',
#   'languages': 'fr-CD,ln,ktu,kg,sw,lua',
#   'neighbours': 'TZ,CF,SS,RW,ZM,BI,UG,CG,AO'},
#  'Central African Republic': {'geonameid': 239880,
#   'name': 'Central African Republic',
#   'iso': 'CF',
#   'iso3': 'CAF',
#   'isonumeric': 140,
#   'fips': 'CT',
#   'continentcode': 'AF',
#   'capital': 'Bangui',
#   'areakm2': 622984,
#   'population': 4666377,
#   'tld': '.cf',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '236',
#   'postalcoderegex': '',
#   'languages': 'fr-CF,sg,ln,kg',
#   'neighbours': 'TD,SD,CD,SS,CM,CG'},
#  'Republic of the Congo': {'geonameid': 2260494,
#   'name': 'Republic of the Congo',
#   'iso': 'CG',
#   'iso3': 'COG',
#   'isonumeric': 178,
#   'fips': 'CF',
#   'continentcode': 'AF',
#   'capital': 'Brazzaville',
#   'areakm2': 342000,
#   'population': 5244363,
#   'tld': '.cg',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '242',
#   'postalcoderegex': '',
#   'languages': 'fr-CG,kg,ln-CG',
#   'neighbours': 'CF,GA,CD,CM,AO'},
#  'Switzerland': {'geonameid': 2658434,
#   'name': 'Switzerland',
#   'iso': 'CH',
#   'iso3': 'CHE',
#   'isonumeric': 756,
#   'fips': 'SZ',
#   'continentcode': 'EU',
#   'capital': 'Bern',
#   'areakm2': 41290,
#   'population': 8516543,
#   'tld': '.ch',
#   'currencycode': 'CHF',
#   'currencyname': 'Franc',
#   'phone': '41',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'de-CH,fr-CH,it-CH,rm',
#   'neighbours': 'DE,IT,LI,FR,AT'},
#  'Ivory Coast': {'geonameid': 2287781,
#   'name': 'Ivory Coast',
#   'iso': 'CI',
#   'iso3': 'CIV',
#   'isonumeric': 384,
#   'fips': 'IV',
#   'continentcode': 'AF',
#   'capital': 'Yamoussoukro',
#   'areakm2': 322460,
#   'population': 25069229,
#   'tld': '.ci',
#   'currencycode': 'XOF',
#   'currencyname': 'Franc',
#   'phone': '225',
#   'postalcoderegex': '',
#   'languages': 'fr-CI',
#   'neighbours': 'LR,GH,GN,BF,ML'},
#  'Cook Islands': {'geonameid': 1899402,
#   'name': 'Cook Islands',
#   'iso': 'CK',
#   'iso3': 'COK',
#   'isonumeric': 184,
#   'fips': 'CW',
#   'continentcode': 'OC',
#   'capital': 'Avarua',
#   'areakm2': 240,
#   'population': 21388,
#   'tld': '.ck',
#   'currencycode': 'NZD',
#   'currencyname': 'Dollar',
#   'phone': '682',
#   'postalcoderegex': '',
#   'languages': 'en-CK,mi',
#   'neighbours': ''},
#  'Chile': {'geonameid': 3895114,
#   'name': 'Chile',
#   'iso': 'CL',
#   'iso3': 'CHL',
#   'isonumeric': 152,
#   'fips': 'CI',
#   'continentcode': 'SA',
#   'capital': 'Santiago',
#   'areakm2': 756950,
#   'population': 18729160,
#   'tld': '.cl',
#   'currencycode': 'CLP',
#   'currencyname': 'Peso',
#   'phone': '56',
#   'postalcoderegex': '^(\\d{7})$',
#   'languages': 'es-CL',
#   'neighbours': 'PE,BO,AR'},
#  'Cameroon': {'geonameid': 2233387,
#   'name': 'Cameroon',
#   'iso': 'CM',
#   'iso3': 'CMR',
#   'isonumeric': 120,
#   'fips': 'CM',
#   'continentcode': 'AF',
#   'capital': 'Yaounde',
#   'areakm2': 475440,
#   'population': 25216237,
#   'tld': '.cm',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '237',
#   'postalcoderegex': '',
#   'languages': 'en-CM,fr-CM',
#   'neighbours': 'TD,CF,GA,GQ,CG,NG'},
#  'China': {'geonameid': 1814991,
#   'name': 'China',
#   'iso': 'CN',
#   'iso3': 'CHN',
#   'isonumeric': 156,
#   'fips': 'CH',
#   'continentcode': 'AS',
#   'capital': 'Beijing',
#   'areakm2': 9596960,
#   'population': 1411778724,
#   'tld': '.cn',
#   'currencycode': 'CNY',
#   'currencyname': 'Yuan Renminbi',
#   'phone': '86',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'zh-CN,yue,wuu,dta,ug,za',
#   'neighbours': 'LA,BT,TJ,KZ,MN,AF,NP,MM,KG,PK,KP,RU,VN,IN'},
#  'Colombia': {'geonameid': 3686110,
#   'name': 'Colombia',
#   'iso': 'CO',
#   'iso3': 'COL',
#   'isonumeric': 170,
#   'fips': 'CO',
#   'continentcode': 'SA',
#   'capital': 'Bogota',
#   'areakm2': 1138910,
#   'population': 49648685,
#   'tld': '.co',
#   'currencycode': 'COP',
#   'currencyname': 'Peso',
#   'phone': '57',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'es-CO',
#   'neighbours': 'EC,PE,PA,BR,VE'},
#  'Costa Rica': {'geonameid': 3624060,
#   'name': 'Costa Rica',
#   'iso': 'CR',
#   'iso3': 'CRI',
#   'isonumeric': 188,
#   'fips': 'CS',
#   'continentcode': 'NA',
#   'capital': 'San Jose',
#   'areakm2': 51100,
#   'population': 4999441,
#   'tld': '.cr',
#   'currencycode': 'CRC',
#   'currencyname': 'Colon',
#   'phone': '506',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'es-CR,en',
#   'neighbours': 'PA,NI'},
#  'Cuba': {'geonameid': 3562981,
#   'name': 'Cuba',
#   'iso': 'CU',
#   'iso3': 'CUB',
#   'isonumeric': 192,
#   'fips': 'CU',
#   'continentcode': 'NA',
#   'capital': 'Havana',
#   'areakm2': 110860,
#   'population': 11338138,
#   'tld': '.cu',
#   'currencycode': 'CUP',
#   'currencyname': 'Peso',
#   'phone': '53',
#   'postalcoderegex': '^(?:CP)*(\\d{5})$',
#   'languages': 'es-CU,pap',
#   'neighbours': 'US'},
#  'Cabo Verde': {'geonameid': 3374766,
#   'name': 'Cabo Verde',
#   'iso': 'CV',
#   'iso3': 'CPV',
#   'isonumeric': 132,
#   'fips': 'CV',
#   'continentcode': 'AF',
#   'capital': 'Praia',
#   'areakm2': 4033,
#   'population': 543767,
#   'tld': '.cv',
#   'currencycode': 'CVE',
#   'currencyname': 'Escudo',
#   'phone': '238',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'pt-CV',
#   'neighbours': ''},
#  'Curacao': {'geonameid': 7626836,
#   'name': 'Curacao',
#   'iso': 'CW',
#   'iso3': 'CUW',
#   'isonumeric': 531,
#   'fips': 'UC',
#   'continentcode': 'NA',
#   'capital': ' Willemstad',
#   'areakm2': 444,
#   'population': 159849,
#   'tld': '.cw',
#   'currencycode': 'ANG',
#   'currencyname': 'Guilder',
#   'phone': '599',
#   'postalcoderegex': '',
#   'languages': 'nl,pap',
#   'neighbours': ''},
#  'Christmas Island': {'geonameid': 2078138,
#   'name': 'Christmas Island',
#   'iso': 'CX',
#   'iso3': 'CXR',
#   'isonumeric': 162,
#   'fips': 'KT',
#   'continentcode': 'OC',
#   'capital': 'Flying Fish Cove',
#   'areakm2': 135,
#   'population': 1500,
#   'tld': '.cx',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': '61',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'en,zh,ms-CX',
#   'neighbours': ''},
#  'Cyprus': {'geonameid': 146669,
#   'name': 'Cyprus',
#   'iso': 'CY',
#   'iso3': 'CYP',
#   'isonumeric': 196,
#   'fips': 'CY',
#   'continentcode': 'EU',
#   'capital': 'Nicosia',
#   'areakm2': 9250,
#   'population': 1189265,
#   'tld': '.cy',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '357',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'el-CY,tr-CY,en',
#   'neighbours': ''},
#  'Czechia': {'geonameid': 3077311,
#   'name': 'Czechia',
#   'iso': 'CZ',
#   'iso3': 'CZE',
#   'isonumeric': 203,
#   'fips': 'EZ',
#   'continentcode': 'EU',
#   'capital': 'Prague',
#   'areakm2': 78866,
#   'population': 10625695,
#   'tld': '.cz',
#   'currencycode': 'CZK',
#   'currencyname': 'Koruna',
#   'phone': '420',
#   'postalcoderegex': '^\\d{3}\\s?\\d{2}$',
#   'languages': 'cs,sk',
#   'neighbours': 'PL,DE,SK,AT'},
#  'Germany': {'geonameid': 2921044,
#   'name': 'Germany',
#   'iso': 'DE',
#   'iso3': 'DEU',
#   'isonumeric': 276,
#   'fips': 'GM',
#   'continentcode': 'EU',
#   'capital': 'Berlin',
#   'areakm2': 357021,
#   'population': 82927922,
#   'tld': '.de',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '49',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'de',
#   'neighbours': 'CH,PL,NL,DK,BE,CZ,LU,FR,AT'},
#  'Djibouti': {'geonameid': 223816,
#   'name': 'Djibouti',
#   'iso': 'DJ',
#   'iso3': 'DJI',
#   'isonumeric': 262,
#   'fips': 'DJ',
#   'continentcode': 'AF',
#   'capital': 'Djibouti',
#   'areakm2': 23000,
#   'population': 958920,
#   'tld': '.dj',
#   'currencycode': 'DJF',
#   'currencyname': 'Franc',
#   'phone': '253',
#   'postalcoderegex': '',
#   'languages': 'fr-DJ,ar,so-DJ,aa',
#   'neighbours': 'ER,ET,SO'},
#  'Denmark': {'geonameid': 2623032,
#   'name': 'Denmark',
#   'iso': 'DK',
#   'iso3': 'DNK',
#   'isonumeric': 208,
#   'fips': 'DA',
#   'continentcode': 'EU',
#   'capital': 'Copenhagen',
#   'areakm2': 43094,
#   'population': 5797446,
#   'tld': '.dk',
#   'currencycode': 'DKK',
#   'currencyname': 'Krone',
#   'phone': '45',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'da-DK,en,fo,de-DK',
#   'neighbours': 'DE'},
#  'Dominica': {'geonameid': 3575830,
#   'name': 'Dominica',
#   'iso': 'DM',
#   'iso3': 'DMA',
#   'isonumeric': 212,
#   'fips': 'DO',
#   'continentcode': 'NA',
#   'capital': 'Roseau',
#   'areakm2': 754,
#   'population': 71625,
#   'tld': '.dm',
#   'currencycode': 'XCD',
#   'currencyname': 'Dollar',
#   'phone': '+1-767',
#   'postalcoderegex': '',
#   'languages': 'en-DM',
#   'neighbours': ''},
#  'Dominican Republic': {'geonameid': 3508796,
#   'name': 'Dominican Republic',
#   'iso': 'DO',
#   'iso3': 'DOM',
#   'isonumeric': 214,
#   'fips': 'DR',
#   'continentcode': 'NA',
#   'capital': 'Santo Domingo',
#   'areakm2': 48730,
#   'population': 10627165,
#   'tld': '.do',
#   'currencycode': 'DOP',
#   'currencyname': 'Peso',
#   'phone': '+1-809 and 1-829',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'es-DO',
#   'neighbours': 'HT'},
#  'Algeria': {'geonameid': 2589581,
#   'name': 'Algeria',
#   'iso': 'DZ',
#   'iso3': 'DZA',
#   'isonumeric': 12,
#   'fips': 'AG',
#   'continentcode': 'AF',
#   'capital': 'Algiers',
#   'areakm2': 2381740,
#   'population': 42228429,
#   'tld': '.dz',
#   'currencycode': 'DZD',
#   'currencyname': 'Dinar',
#   'phone': '213',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'ar-DZ',
#   'neighbours': 'NE,EH,LY,MR,TN,MA,ML'},
#  'Ecuador': {'geonameid': 3658394,
#   'name': 'Ecuador',
#   'iso': 'EC',
#   'iso3': 'ECU',
#   'isonumeric': 218,
#   'fips': 'EC',
#   'continentcode': 'SA',
#   'capital': 'Quito',
#   'areakm2': 283560,
#   'population': 17084357,
#   'tld': '.ec',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '593',
#   'postalcoderegex': '^([a-zA-Z]\\d{4}[a-zA-Z])$',
#   'languages': 'es-EC',
#   'neighbours': 'PE,CO'},
#  'Estonia': {'geonameid': 453733,
#   'name': 'Estonia',
#   'iso': 'EE',
#   'iso3': 'EST',
#   'isonumeric': 233,
#   'fips': 'EN',
#   'continentcode': 'EU',
#   'capital': 'Tallinn',
#   'areakm2': 45226,
#   'population': 1320884,
#   'tld': '.ee',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '372',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'et,ru',
#   'neighbours': 'RU,LV'},
#  'Egypt': {'geonameid': 357994,
#   'name': 'Egypt',
#   'iso': 'EG',
#   'iso3': 'EGY',
#   'isonumeric': 818,
#   'fips': 'EG',
#   'continentcode': 'AF',
#   'capital': 'Cairo',
#   'areakm2': 1001450,
#   'population': 98423595,
#   'tld': '.eg',
#   'currencycode': 'EGP',
#   'currencyname': 'Pound',
#   'phone': '20',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'ar-EG,en,fr',
#   'neighbours': 'LY,SD,IL,PS'},
#  'Western Sahara': {'geonameid': 2461445,
#   'name': 'Western Sahara',
#   'iso': 'EH',
#   'iso3': 'ESH',
#   'isonumeric': 732,
#   'fips': 'WI',
#   'continentcode': 'AF',
#   'capital': 'El-Aaiun',
#   'areakm2': 266000,
#   'population': 273008,
#   'tld': '.eh',
#   'currencycode': 'MAD',
#   'currencyname': 'Dirham',
#   'phone': '212',
#   'postalcoderegex': '',
#   'languages': 'ar,mey',
#   'neighbours': 'DZ,MR,MA'},
#  'Eritrea': {'geonameid': 338010,
#   'name': 'Eritrea',
#   'iso': 'ER',
#   'iso3': 'ERI',
#   'isonumeric': 232,
#   'fips': 'ER',
#   'continentcode': 'AF',
#   'capital': 'Asmara',
#   'areakm2': 121320,
#   'population': 6209262,
#   'tld': '.er',
#   'currencycode': 'ERN',
#   'currencyname': 'Nakfa',
#   'phone': '291',
#   'postalcoderegex': '',
#   'languages': 'aa-ER,ar,tig,kun,ti-ER',
#   'neighbours': 'ET,SD,DJ'},
#  'Spain': {'geonameid': 2510769,
#   'name': 'Spain',
#   'iso': 'ES',
#   'iso3': 'ESP',
#   'isonumeric': 724,
#   'fips': 'SP',
#   'continentcode': 'EU',
#   'capital': 'Madrid',
#   'areakm2': 504782,
#   'population': 46723749,
#   'tld': '.es',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '34',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'es-ES,ca,gl,eu,oc',
#   'neighbours': 'AD,PT,GI,FR,MA'},
#  'Ethiopia': {'geonameid': 337996,
#   'name': 'Ethiopia',
#   'iso': 'ET',
#   'iso3': 'ETH',
#   'isonumeric': 231,
#   'fips': 'ET',
#   'continentcode': 'AF',
#   'capital': 'Addis Ababa',
#   'areakm2': 1127127,
#   'population': 109224559,
#   'tld': '.et',
#   'currencycode': 'ETB',
#   'currencyname': 'Birr',
#   'phone': '251',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'am,en-ET,om-ET,ti-ET,so-ET,sid',
#   'neighbours': 'ER,KE,SD,SS,SO,DJ'},
#  'Finland': {'geonameid': 660013,
#   'name': 'Finland',
#   'iso': 'FI',
#   'iso3': 'FIN',
#   'isonumeric': 246,
#   'fips': 'FI',
#   'continentcode': 'EU',
#   'capital': 'Helsinki',
#   'areakm2': 337030,
#   'population': 5518050,
#   'tld': '.fi',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '358',
#   'postalcoderegex': '^(?:FI)*(\\d{5})$',
#   'languages': 'fi-FI,sv-FI,smn',
#   'neighbours': 'NO,RU,SE'},
#  'Fiji': {'geonameid': 2205218,
#   'name': 'Fiji',
#   'iso': 'FJ',
#   'iso3': 'FJI',
#   'isonumeric': 242,
#   'fips': 'FJ',
#   'continentcode': 'OC',
#   'capital': 'Suva',
#   'areakm2': 18270,
#   'population': 883483,
#   'tld': '.fj',
#   'currencycode': 'FJD',
#   'currencyname': 'Dollar',
#   'phone': '679',
#   'postalcoderegex': '',
#   'languages': 'en-FJ,fj',
#   'neighbours': ''},
#  'Falkland Islands': {'geonameid': 3474414,
#   'name': 'Falkland Islands',
#   'iso': 'FK',
#   'iso3': 'FLK',
#   'isonumeric': 238,
#   'fips': 'FK',
#   'continentcode': 'SA',
#   'capital': 'Stanley',
#   'areakm2': 12173,
#   'population': 2638,
#   'tld': '.fk',
#   'currencycode': 'FKP',
#   'currencyname': 'Pound',
#   'phone': '500',
#   'postalcoderegex': 'FIQQ 1ZZ',
#   'languages': 'en-FK',
#   'neighbours': ''},
#  'Micronesia': {'geonameid': 2081918,
#   'name': 'Micronesia',
#   'iso': 'FM',
#   'iso3': 'FSM',
#   'isonumeric': 583,
#   'fips': 'FM',
#   'continentcode': 'OC',
#   'capital': 'Palikir',
#   'areakm2': 702,
#   'population': 112640,
#   'tld': '.fm',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '691',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'en-FM,chk,pon,yap,kos,uli,woe,nkr,kpg',
#   'neighbours': ''},
#  'Faroe Islands': {'geonameid': 2622320,
#   'name': 'Faroe Islands',
#   'iso': 'FO',
#   'iso3': 'FRO',
#   'isonumeric': 234,
#   'fips': 'FO',
#   'continentcode': 'EU',
#   'capital': 'Torshavn',
#   'areakm2': 1399,
#   'population': 48497,
#   'tld': '.fo',
#   'currencycode': 'DKK',
#   'currencyname': 'Krone',
#   'phone': '298',
#   'postalcoderegex': '^(?:FO)*(\\d{3})$',
#   'languages': 'fo,da-FO',
#   'neighbours': ''},
#  'France': {'geonameid': 3017382,
#   'name': 'France',
#   'iso': 'FR',
#   'iso3': 'FRA',
#   'isonumeric': 250,
#   'fips': 'FR',
#   'continentcode': 'EU',
#   'capital': 'Paris',
#   'areakm2': 547030,
#   'population': 66987244,
#   'tld': '.fr',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '33',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'fr-FR,frp,br,co,ca,eu,oc',
#   'neighbours': 'CH,DE,BE,LU,IT,AD,MC,ES'},
#  'Gabon': {'geonameid': 2400553,
#   'name': 'Gabon',
#   'iso': 'GA',
#   'iso3': 'GAB',
#   'isonumeric': 266,
#   'fips': 'GB',
#   'continentcode': 'AF',
#   'capital': 'Libreville',
#   'areakm2': 267667,
#   'population': 2119275,
#   'tld': '.ga',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '241',
#   'postalcoderegex': '',
#   'languages': 'fr-GA',
#   'neighbours': 'CM,GQ,CG'},
#  'United Kingdom': {'geonameid': 2635167,
#   'name': 'United Kingdom',
#   'iso': 'GB',
#   'iso3': 'GBR',
#   'isonumeric': 826,
#   'fips': 'UK',
#   'continentcode': 'EU',
#   'capital': 'London',
#   'areakm2': 244820,
#   'population': 66488991,
#   'tld': '.uk',
#   'currencycode': 'GBP',
#   'currencyname': 'Pound',
#   'phone': '44',
#   'postalcoderegex': '^([Gg][Ii][Rr]\\s?0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9]?[A-Za-z]))))\\s?[0-9][A-Za-z]{2})$',
#   'languages': 'en-GB,cy-GB,gd',
#   'neighbours': 'IE'},
#  'Grenada': {'geonameid': 3580239,
#   'name': 'Grenada',
#   'iso': 'GD',
#   'iso3': 'GRD',
#   'isonumeric': 308,
#   'fips': 'GJ',
#   'continentcode': 'NA',
#   'capital': "St. George's",
#   'areakm2': 344,
#   'population': 111454,
#   'tld': '.gd',
#   'currencycode': 'XCD',
#   'currencyname': 'Dollar',
#   'phone': '+1-473',
#   'postalcoderegex': '',
#   'languages': 'en-GD',
#   'neighbours': ''},
#  'Georgia': {'geonameid': 614540,
#   'name': 'Georgia',
#   'iso': 'GE',
#   'iso3': 'GEO',
#   'isonumeric': 268,
#   'fips': 'GG',
#   'continentcode': 'AS',
#   'capital': 'Tbilisi',
#   'areakm2': 69700,
#   'population': 3731000,
#   'tld': '.ge',
#   'currencycode': 'GEL',
#   'currencyname': 'Lari',
#   'phone': '995',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'ka,ru,hy,az',
#   'neighbours': 'AM,AZ,TR,RU'},
#  'French Guiana': {'geonameid': 3381670,
#   'name': 'French Guiana',
#   'iso': 'GF',
#   'iso3': 'GUF',
#   'isonumeric': 254,
#   'fips': 'FG',
#   'continentcode': 'SA',
#   'capital': 'Cayenne',
#   'areakm2': 91000,
#   'population': 195506,
#   'tld': '.gf',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '594',
#   'postalcoderegex': '^((97|98)3\\d{2})$',
#   'languages': 'fr-GF',
#   'neighbours': 'SR,BR'},
#  'Guernsey': {'geonameid': 3042362,
#   'name': 'Guernsey',
#   'iso': 'GG',
#   'iso3': 'GGY',
#   'isonumeric': 831,
#   'fips': 'GK',
#   'continentcode': 'EU',
#   'capital': 'St Peter Port',
#   'areakm2': 78,
#   'population': 65228,
#   'tld': '.gg',
#   'currencycode': 'GBP',
#   'currencyname': 'Pound',
#   'phone': '+44-1481',
#   'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$',
#   'languages': 'en,nrf',
#   'neighbours': ''},
#  'Ghana': {'geonameid': 2300660,
#   'name': 'Ghana',
#   'iso': 'GH',
#   'iso3': 'GHA',
#   'isonumeric': 288,
#   'fips': 'GH',
#   'continentcode': 'AF',
#   'capital': 'Accra',
#   'areakm2': 239460,
#   'population': 29767108,
#   'tld': '.gh',
#   'currencycode': 'GHS',
#   'currencyname': 'Cedi',
#   'phone': '233',
#   'postalcoderegex': '',
#   'languages': 'en-GH,ak,ee,tw',
#   'neighbours': 'CI,TG,BF'},
#  'Gibraltar': {'geonameid': 2411586,
#   'name': 'Gibraltar',
#   'iso': 'GI',
#   'iso3': 'GIB',
#   'isonumeric': 292,
#   'fips': 'GI',
#   'continentcode': 'EU',
#   'capital': 'Gibraltar',
#   'areakm2': 6,
#   'population': 33718,
#   'tld': '.gi',
#   'currencycode': 'GIP',
#   'currencyname': 'Pound',
#   'phone': '350',
#   'postalcoderegex': 'GX11 1AA',
#   'languages': 'en-GI,es,it,pt',
#   'neighbours': 'ES'},
#  'Greenland': {'geonameid': 3425505,
#   'name': 'Greenland',
#   'iso': 'GL',
#   'iso3': 'GRL',
#   'isonumeric': 304,
#   'fips': 'GL',
#   'continentcode': 'NA',
#   'capital': 'Nuuk',
#   'areakm2': 2166086,
#   'population': 56025,
#   'tld': '.gl',
#   'currencycode': 'DKK',
#   'currencyname': 'Krone',
#   'phone': '299',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'kl,da-GL,en',
#   'neighbours': ''},
#  'Gambia': {'geonameid': 2413451,
#   'name': 'Gambia',
#   'iso': 'GM',
#   'iso3': 'GMB',
#   'isonumeric': 270,
#   'fips': 'GA',
#   'continentcode': 'AF',
#   'capital': 'Banjul',
#   'areakm2': 11300,
#   'population': 2280102,
#   'tld': '.gm',
#   'currencycode': 'GMD',
#   'currencyname': 'Dalasi',
#   'phone': '220',
#   'postalcoderegex': '',
#   'languages': 'en-GM,mnk,wof,wo,ff',
#   'neighbours': 'SN'},
#  'Guinea': {'geonameid': 2420477,
#   'name': 'Guinea',
#   'iso': 'GN',
#   'iso3': 'GIN',
#   'isonumeric': 324,
#   'fips': 'GV',
#   'continentcode': 'AF',
#   'capital': 'Conakry',
#   'areakm2': 245857,
#   'population': 12414318,
#   'tld': '.gn',
#   'currencycode': 'GNF',
#   'currencyname': 'Franc',
#   'phone': '224',
#   'postalcoderegex': '',
#   'languages': 'fr-GN',
#   'neighbours': 'LR,SN,SL,CI,GW,ML'},
#  'Guadeloupe': {'geonameid': 3579143,
#   'name': 'Guadeloupe',
#   'iso': 'GP',
#   'iso3': 'GLP',
#   'isonumeric': 312,
#   'fips': 'GP',
#   'continentcode': 'NA',
#   'capital': 'Basse-Terre',
#   'areakm2': 1780,
#   'population': 443000,
#   'tld': '.gp',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '590',
#   'postalcoderegex': '^((97|98)\\d{3})$',
#   'languages': 'fr-GP',
#   'neighbours': ''},
#  'Equatorial Guinea': {'geonameid': 2309096,
#   'name': 'Equatorial Guinea',
#   'iso': 'GQ',
#   'iso3': 'GNQ',
#   'isonumeric': 226,
#   'fips': 'EK',
#   'continentcode': 'AF',
#   'capital': 'Malabo',
#   'areakm2': 28051,
#   'population': 1308974,
#   'tld': '.gq',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '240',
#   'postalcoderegex': '',
#   'languages': 'es-GQ,fr,pt',
#   'neighbours': 'GA,CM'},
#  'Greece': {'geonameid': 390903,
#   'name': 'Greece',
#   'iso': 'GR',
#   'iso3': 'GRC',
#   'isonumeric': 300,
#   'fips': 'GR',
#   'continentcode': 'EU',
#   'capital': 'Athens',
#   'areakm2': 131940,
#   'population': 10727668,
#   'tld': '.gr',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '30',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'el-GR,en,fr',
#   'neighbours': 'AL,MK,TR,BG'},
#  'South Georgia and the South Sandwich Islands': {'geonameid': 3474415,
#   'name': 'South Georgia and the South Sandwich Islands',
#   'iso': 'GS',
#   'iso3': 'SGS',
#   'isonumeric': 239,
#   'fips': 'SX',
#   'continentcode': 'AN',
#   'capital': 'Grytviken',
#   'areakm2': 3903,
#   'population': 30,
#   'tld': '.gs',
#   'currencycode': 'GBP',
#   'currencyname': 'Pound',
#   'phone': '',
#   'postalcoderegex': 'SIQQ 1ZZ',
#   'languages': 'en',
#   'neighbours': ''},
#  'Guatemala': {'geonameid': 3595528,
#   'name': 'Guatemala',
#   'iso': 'GT',
#   'iso3': 'GTM',
#   'isonumeric': 320,
#   'fips': 'GT',
#   'continentcode': 'NA',
#   'capital': 'Guatemala City',
#   'areakm2': 108890,
#   'population': 17247807,
#   'tld': '.gt',
#   'currencycode': 'GTQ',
#   'currencyname': 'Quetzal',
#   'phone': '502',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'es-GT',
#   'neighbours': 'MX,HN,BZ,SV'},
#  'Guam': {'geonameid': 4043988,
#   'name': 'Guam',
#   'iso': 'GU',
#   'iso3': 'GUM',
#   'isonumeric': 316,
#   'fips': 'GQ',
#   'continentcode': 'OC',
#   'capital': 'Hagatna',
#   'areakm2': 549,
#   'population': 165768,
#   'tld': '.gu',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '+1-671',
#   'postalcoderegex': '^(969\\d{2})$',
#   'languages': 'en-GU,ch-GU',
#   'neighbours': ''},
#  'Guinea-Bissau': {'geonameid': 2372248,
#   'name': 'Guinea-Bissau',
#   'iso': 'GW',
#   'iso3': 'GNB',
#   'isonumeric': 624,
#   'fips': 'PU',
#   'continentcode': 'AF',
#   'capital': 'Bissau',
#   'areakm2': 36120,
#   'population': 1874309,
#   'tld': '.gw',
#   'currencycode': 'XOF',
#   'currencyname': 'Franc',
#   'phone': '245',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'pt-GW,pov',
#   'neighbours': 'SN,GN'},
#  'Guyana': {'geonameid': 3378535,
#   'name': 'Guyana',
#   'iso': 'GY',
#   'iso3': 'GUY',
#   'isonumeric': 328,
#   'fips': 'GY',
#   'continentcode': 'SA',
#   'capital': 'Georgetown',
#   'areakm2': 214970,
#   'population': 779004,
#   'tld': '.gy',
#   'currencycode': 'GYD',
#   'currencyname': 'Dollar',
#   'phone': '592',
#   'postalcoderegex': '',
#   'languages': 'en-GY',
#   'neighbours': 'SR,BR,VE'},
#  'Hong Kong': {'geonameid': 1819730,
#   'name': 'Hong Kong',
#   'iso': 'HK',
#   'iso3': 'HKG',
#   'isonumeric': 344,
#   'fips': 'HK',
#   'continentcode': 'AS',
#   'capital': 'Hong Kong',
#   'areakm2': 1092,
#   'population': 7396076,
#   'tld': '.hk',
#   'currencycode': 'HKD',
#   'currencyname': 'Dollar',
#   'phone': '852',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'zh-HK,yue,zh,en',
#   'neighbours': ''},
#  'Heard Island and McDonald Islands': {'geonameid': 1547314,
#   'name': 'Heard Island and McDonald Islands',
#   'iso': 'HM',
#   'iso3': 'HMD',
#   'isonumeric': 334,
#   'fips': 'HM',
#   'continentcode': 'AN',
#   'capital': '',
#   'areakm2': 412,
#   'population': 0,
#   'tld': '.hm',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': ' ',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': '',
#   'neighbours': ''},
#  'Honduras': {'geonameid': 3608932,
#   'name': 'Honduras',
#   'iso': 'HN',
#   'iso3': 'HND',
#   'isonumeric': 340,
#   'fips': 'HO',
#   'continentcode': 'NA',
#   'capital': 'Tegucigalpa',
#   'areakm2': 112090,
#   'population': 9587522,
#   'tld': '.hn',
#   'currencycode': 'HNL',
#   'currencyname': 'Lempira',
#   'phone': '504',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'es-HN,cab,miq',
#   'neighbours': 'GT,NI,SV'},
#  'Croatia': {'geonameid': 3202326,
#   'name': 'Croatia',
#   'iso': 'HR',
#   'iso3': 'HRV',
#   'isonumeric': 191,
#   'fips': 'HR',
#   'continentcode': 'EU',
#   'capital': 'Zagreb',
#   'areakm2': 56542,
#   'population': 3871833,
#   'tld': '.hr',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '385',
#   'postalcoderegex': '^(?:HR)*(\\d{5})$',
#   'languages': 'hr-HR,sr',
#   'neighbours': 'HU,SI,BA,ME,RS'},
#  'Haiti': {'geonameid': 3723988,
#   'name': 'Haiti',
#   'iso': 'HT',
#   'iso3': 'HTI',
#   'isonumeric': 332,
#   'fips': 'HA',
#   'continentcode': 'NA',
#   'capital': 'Port-au-Prince',
#   'areakm2': 27750,
#   'population': 11123176,
#   'tld': '.ht',
#   'currencycode': 'HTG',
#   'currencyname': 'Gourde',
#   'phone': '509',
#   'postalcoderegex': '^(?:HT)*(\\d{4})$',
#   'languages': 'ht,fr-HT',
#   'neighbours': 'DO'},
#  'Hungary': {'geonameid': 719819,
#   'name': 'Hungary',
#   'iso': 'HU',
#   'iso3': 'HUN',
#   'isonumeric': 348,
#   'fips': 'HU',
#   'continentcode': 'EU',
#   'capital': 'Budapest',
#   'areakm2': 93030,
#   'population': 9768785,
#   'tld': '.hu',
#   'currencycode': 'HUF',
#   'currencyname': 'Forint',
#   'phone': '36',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'hu-HU',
#   'neighbours': 'SK,SI,RO,UA,HR,AT,RS'},
#  'Indonesia': {'geonameid': 1643084,
#   'name': 'Indonesia',
#   'iso': 'ID',
#   'iso3': 'IDN',
#   'isonumeric': 360,
#   'fips': 'ID',
#   'continentcode': 'AS',
#   'capital': 'Jakarta',
#   'areakm2': 1919440,
#   'population': 267663435,
#   'tld': '.id',
#   'currencycode': 'IDR',
#   'currencyname': 'Rupiah',
#   'phone': '62',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'id,en,nl,jv',
#   'neighbours': 'PG,TL,MY'},
#  'Ireland': {'geonameid': 2963597,
#   'name': 'Ireland',
#   'iso': 'IE',
#   'iso3': 'IRL',
#   'isonumeric': 372,
#   'fips': 'EI',
#   'continentcode': 'EU',
#   'capital': 'Dublin',
#   'areakm2': 70280,
#   'population': 4853506,
#   'tld': '.ie',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '353',
#   'postalcoderegex': '^(D6W|[AC-FHKNPRTV-Y][0-9]{2})\\s?([AC-FHKNPRTV-Y0-9]{4})',
#   'languages': 'en-IE,ga-IE',
#   'neighbours': 'GB'},
#  'Israel': {'geonameid': 294640,
#   'name': 'Israel',
#   'iso': 'IL',
#   'iso3': 'ISR',
#   'isonumeric': 376,
#   'fips': 'IS',
#   'continentcode': 'AS',
#   'capital': 'Jerusalem',
#   'areakm2': 20770,
#   'population': 8883800,
#   'tld': '.il',
#   'currencycode': 'ILS',
#   'currencyname': 'Shekel',
#   'phone': '972',
#   'postalcoderegex': '^(\\d{7}|\\d{5})$',
#   'languages': 'he,ar-IL,en-IL,',
#   'neighbours': 'SY,JO,LB,EG,PS'},
#  'Isle of Man': {'geonameid': 3042225,
#   'name': 'Isle of Man',
#   'iso': 'IM',
#   'iso3': 'IMN',
#   'isonumeric': 833,
#   'fips': 'IM',
#   'continentcode': 'EU',
#   'capital': 'Douglas',
#   'areakm2': 572,
#   'population': 84077,
#   'tld': '.im',
#   'currencycode': 'GBP',
#   'currencyname': 'Pound',
#   'phone': '+44-1624',
#   'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$',
#   'languages': 'en,gv',
#   'neighbours': ''},
#  'India': {'geonameid': 1269750,
#   'name': 'India',
#   'iso': 'IN',
#   'iso3': 'IND',
#   'isonumeric': 356,
#   'fips': 'IN',
#   'continentcode': 'AS',
#   'capital': 'New Delhi',
#   'areakm2': 3287590,
#   'population': 1352617328,
#   'tld': '.in',
#   'currencycode': 'INR',
#   'currencyname': 'Rupee',
#   'phone': '91',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#   'neighbours': 'CN,NP,MM,BT,PK,BD'},
#  'British Indian Ocean Territory': {'geonameid': 1282588,
#   'name': 'British Indian Ocean Territory',
#   'iso': 'IO',
#   'iso3': 'IOT',
#   'isonumeric': 86,
#   'fips': 'IO',
#   'continentcode': 'AS',
#   'capital': 'Diego Garcia',
#   'areakm2': 60,
#   'population': 4000,
#   'tld': '.io',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '246',
#   'postalcoderegex': 'BBND 1ZZ',
#   'languages': 'en-IO',
#   'neighbours': ''},
#  'Iraq': {'geonameid': 99237,
#   'name': 'Iraq',
#   'iso': 'IQ',
#   'iso3': 'IRQ',
#   'isonumeric': 368,
#   'fips': 'IZ',
#   'continentcode': 'AS',
#   'capital': 'Baghdad',
#   'areakm2': 437072,
#   'population': 38433600,
#   'tld': '.iq',
#   'currencycode': 'IQD',
#   'currencyname': 'Dinar',
#   'phone': '964',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'ar-IQ,ku,hy',
#   'neighbours': 'SY,SA,IR,JO,TR,KW'},
#  'Iran': {'geonameid': 130758,
#   'name': 'Iran',
#   'iso': 'IR',
#   'iso3': 'IRN',
#   'isonumeric': 364,
#   'fips': 'IR',
#   'continentcode': 'AS',
#   'capital': 'Tehran',
#   'areakm2': 1648000,
#   'population': 81800269,
#   'tld': '.ir',
#   'currencycode': 'IRR',
#   'currencyname': 'Rial',
#   'phone': '98',
#   'postalcoderegex': '^(\\d{10})$',
#   'languages': 'fa-IR,ku',
#   'neighbours': 'TM,AF,IQ,AM,PK,AZ,TR'},
#  'Iceland': {'geonameid': 2629691,
#   'name': 'Iceland',
#   'iso': 'IS',
#   'iso3': 'ISL',
#   'isonumeric': 352,
#   'fips': 'IC',
#   'continentcode': 'EU',
#   'capital': 'Reykjavik',
#   'areakm2': 103000,
#   'population': 353574,
#   'tld': '.is',
#   'currencycode': 'ISK',
#   'currencyname': 'Krona',
#   'phone': '354',
#   'postalcoderegex': '^(\\d{3})$',
#   'languages': 'is,en,de,da,sv,no',
#   'neighbours': ''},
#  'Italy': {'geonameid': 3175395,
#   'name': 'Italy',
#   'iso': 'IT',
#   'iso3': 'ITA',
#   'isonumeric': 380,
#   'fips': 'IT',
#   'continentcode': 'EU',
#   'capital': 'Rome',
#   'areakm2': 301230,
#   'population': 60431283,
#   'tld': '.it',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '39',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'it-IT,de-IT,fr-IT,sc,ca,co,sl',
#   'neighbours': 'CH,VA,SI,SM,FR,AT'},
#  'Jersey': {'geonameid': 3042142,
#   'name': 'Jersey',
#   'iso': 'JE',
#   'iso3': 'JEY',
#   'isonumeric': 832,
#   'fips': 'JE',
#   'continentcode': 'EU',
#   'capital': 'Saint Helier',
#   'areakm2': 116,
#   'population': 90812,
#   'tld': '.je',
#   'currencycode': 'GBP',
#   'currencyname': 'Pound',
#   'phone': '+44-1534',
#   'postalcoderegex': '^((?:(?:[A-PR-UWYZ][A-HK-Y]\\d[ABEHMNPRV-Y0-9]|[A-PR-UWYZ]\\d[A-HJKPS-UW0-9])\\s\\d[ABD-HJLNP-UW-Z]{2})|GIR\\s?0AA)$',
#   'languages': 'en,fr,nrf',
#   'neighbours': ''},
#  'Jamaica': {'geonameid': 3489940,
#   'name': 'Jamaica',
#   'iso': 'JM',
#   'iso3': 'JAM',
#   'isonumeric': 388,
#   'fips': 'JM',
#   'continentcode': 'NA',
#   'capital': 'Kingston',
#   'areakm2': 10991,
#   'population': 2934855,
#   'tld': '.jm',
#   'currencycode': 'JMD',
#   'currencyname': 'Dollar',
#   'phone': '+1-876',
#   'postalcoderegex': '',
#   'languages': 'en-JM',
#   'neighbours': ''},
#  'Jordan': {'geonameid': 248816,
#   'name': 'Jordan',
#   'iso': 'JO',
#   'iso3': 'JOR',
#   'isonumeric': 400,
#   'fips': 'JO',
#   'continentcode': 'AS',
#   'capital': 'Amman',
#   'areakm2': 92300,
#   'population': 9956011,
#   'tld': '.jo',
#   'currencycode': 'JOD',
#   'currencyname': 'Dinar',
#   'phone': '962',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'ar-JO,en',
#   'neighbours': 'SY,SA,IQ,IL,PS'},
#  'Japan': {'geonameid': 1861060,
#   'name': 'Japan',
#   'iso': 'JP',
#   'iso3': 'JPN',
#   'isonumeric': 392,
#   'fips': 'JA',
#   'continentcode': 'AS',
#   'capital': 'Tokyo',
#   'areakm2': 377835,
#   'population': 126529100,
#   'tld': '.jp',
#   'currencycode': 'JPY',
#   'currencyname': 'Yen',
#   'phone': '81',
#   'postalcoderegex': '^\\d{3}-\\d{4}$',
#   'languages': 'ja',
#   'neighbours': ''},
#  'Kenya': {'geonameid': 192950,
#   'name': 'Kenya',
#   'iso': 'KE',
#   'iso3': 'KEN',
#   'isonumeric': 404,
#   'fips': 'KE',
#   'continentcode': 'AF',
#   'capital': 'Nairobi',
#   'areakm2': 582650,
#   'population': 51393010,
#   'tld': '.ke',
#   'currencycode': 'KES',
#   'currencyname': 'Shilling',
#   'phone': '254',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'en-KE,sw-KE',
#   'neighbours': 'ET,TZ,SS,SO,UG'},
#  'Kyrgyzstan': {'geonameid': 1527747,
#   'name': 'Kyrgyzstan',
#   'iso': 'KG',
#   'iso3': 'KGZ',
#   'isonumeric': 417,
#   'fips': 'KG',
#   'continentcode': 'AS',
#   'capital': 'Bishkek',
#   'areakm2': 198500,
#   'population': 6315800,
#   'tld': '.kg',
#   'currencycode': 'KGS',
#   'currencyname': 'Som',
#   'phone': '996',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'ky,uz,ru',
#   'neighbours': 'CN,TJ,UZ,KZ'},
#  'Cambodia': {'geonameid': 1831722,
#   'name': 'Cambodia',
#   'iso': 'KH',
#   'iso3': 'KHM',
#   'isonumeric': 116,
#   'fips': 'CB',
#   'continentcode': 'AS',
#   'capital': 'Phnom Penh',
#   'areakm2': 181040,
#   'population': 16249798,
#   'tld': '.kh',
#   'currencycode': 'KHR',
#   'currencyname': 'Riels',
#   'phone': '855',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'km,fr,en',
#   'neighbours': 'LA,TH,VN'},
#  'Kiribati': {'geonameid': 4030945,
#   'name': 'Kiribati',
#   'iso': 'KI',
#   'iso3': 'KIR',
#   'isonumeric': 296,
#   'fips': 'KR',
#   'continentcode': 'OC',
#   'capital': 'Tarawa',
#   'areakm2': 811,
#   'population': 115847,
#   'tld': '.ki',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': '686',
# ...
#   'tld': '.sy',
#   'currencycode': 'SYP',
#   'currencyname': 'Pound',
#   'phone': '963',
#   'postalcoderegex': '',
#   'languages': 'ar-SY,ku,hy,arc,fr,en',
#   'neighbours': 'IQ,JO,IL,TR,LB'},
#  'Eswatini': {'geonameid': 934841,
#   'name': 'Eswatini',
#   'iso': 'SZ',
#   'iso3': 'SWZ',
#   'isonumeric': 748,
#   'fips': 'WZ',
#   'continentcode': 'AF',
#   'capital': 'Mbabane',
#   'areakm2': 17363,
#   'population': 1136191,
#   'tld': '.sz',
#   'currencycode': 'SZL',
#   'currencyname': 'Lilangeni',
#   'phone': '268',
#   'postalcoderegex': '^([A-Z]\\d{3})$',
#   'languages': 'en-SZ,ss-SZ',
#   'neighbours': 'ZA,MZ'},
#  'Turks and Caicos Islands': {'geonameid': 3576916,
#   'name': 'Turks and Caicos Islands',
#   'iso': 'TC',
#   'iso3': 'TCA',
#   'isonumeric': 796,
#   'fips': 'TK',
#   'continentcode': 'NA',
#   'capital': 'Cockburn Town',
#   'areakm2': 430,
#   'population': 37665,
#   'tld': '.tc',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '+1-649',
#   'postalcoderegex': '^(TKCA 1ZZ)$',
#   'languages': 'en-TC',
#   'neighbours': ''},
#  'Chad': {'geonameid': 2434508,
#   'name': 'Chad',
#   'iso': 'TD',
#   'iso3': 'TCD',
#   'isonumeric': 148,
#   'fips': 'CD',
#   'continentcode': 'AF',
#   'capital': "N'Djamena",
#   'areakm2': 1284000,
#   'population': 15477751,
#   'tld': '.td',
#   'currencycode': 'XAF',
#   'currencyname': 'Franc',
#   'phone': '235',
#   'postalcoderegex': '^(TKCA 1ZZ)$',
#   'languages': 'fr-TD,ar-TD,sre',
#   'neighbours': 'NE,LY,CF,SD,CM,NG'},
#  'French Southern Territories': {'geonameid': 1546748,
#   'name': 'French Southern Territories',
#   'iso': 'TF',
#   'iso3': 'ATF',
#   'isonumeric': 260,
#   'fips': 'FS',
#   'continentcode': 'AN',
#   'capital': 'Port-aux-Francais',
#   'areakm2': 7829,
#   'population': 140,
#   'tld': '.tf',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '',
#   'postalcoderegex': '',
#   'languages': 'fr',
#   'neighbours': ''},
#  'Togo': {'geonameid': 2363686,
#   'name': 'Togo',
#   'iso': 'TG',
#   'iso3': 'TGO',
#   'isonumeric': 768,
#   'fips': 'TO',
#   'continentcode': 'AF',
#   'capital': 'Lome',
#   'areakm2': 56785,
#   'population': 7889094,
#   'tld': '.tg',
#   'currencycode': 'XOF',
#   'currencyname': 'Franc',
#   'phone': '228',
#   'postalcoderegex': '',
#   'languages': 'fr-TG,ee,hna,kbp,dag,ha',
#   'neighbours': 'BJ,GH,BF'},
#  'Thailand': {'geonameid': 1605651,
#   'name': 'Thailand',
#   'iso': 'TH',
#   'iso3': 'THA',
#   'isonumeric': 764,
#   'fips': 'TH',
#   'continentcode': 'AS',
#   'capital': 'Bangkok',
#   'areakm2': 514000,
#   'population': 69428524,
#   'tld': '.th',
#   'currencycode': 'THB',
#   'currencyname': 'Baht',
#   'phone': '66',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'th,en',
#   'neighbours': 'LA,MM,KH,MY'},
#  'Tajikistan': {'geonameid': 1220409,
#   'name': 'Tajikistan',
#   'iso': 'TJ',
#   'iso3': 'TJK',
#   'isonumeric': 762,
#   'fips': 'TI',
#   'continentcode': 'AS',
#   'capital': 'Dushanbe',
#   'areakm2': 143100,
#   'population': 9100837,
#   'tld': '.tj',
#   'currencycode': 'TJS',
#   'currencyname': 'Somoni',
#   'phone': '992',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'tg,ru',
#   'neighbours': 'CN,AF,KG,UZ'},
#  'Tokelau': {'geonameid': 4031074,
#   'name': 'Tokelau',
#   'iso': 'TK',
#   'iso3': 'TKL',
#   'isonumeric': 772,
#   'fips': 'TL',
#   'continentcode': 'OC',
#   'capital': '',
#   'areakm2': 10,
#   'population': 1466,
#   'tld': '.tk',
#   'currencycode': 'NZD',
#   'currencyname': 'Dollar',
#   'phone': '690',
#   'postalcoderegex': '',
#   'languages': 'tkl,en-TK',
#   'neighbours': ''},
#  'Timor Leste': {'geonameid': 1966436,
#   'name': 'Timor Leste',
#   'iso': 'TL',
#   'iso3': 'TLS',
#   'isonumeric': 626,
#   'fips': 'TT',
#   'continentcode': 'OC',
#   'capital': 'Dili',
#   'areakm2': 15007,
#   'population': 1267972,
#   'tld': '.tl',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '670',
#   'postalcoderegex': '',
#   'languages': 'tet,pt-TL,id,en',
#   'neighbours': 'ID'},
#  'Turkmenistan': {'geonameid': 1218197,
#   'name': 'Turkmenistan',
#   'iso': 'TM',
#   'iso3': 'TKM',
#   'isonumeric': 795,
#   'fips': 'TX',
#   'continentcode': 'AS',
#   'capital': 'Ashgabat',
#   'areakm2': 488100,
#   'population': 5850908,
#   'tld': '.tm',
#   'currencycode': 'TMT',
#   'currencyname': 'Manat',
#   'phone': '993',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'tk,ru,uz',
#   'neighbours': 'AF,IR,UZ,KZ'},
#  'Tunisia': {'geonameid': 2464461,
#   'name': 'Tunisia',
#   'iso': 'TN',
#   'iso3': 'TUN',
#   'isonumeric': 788,
#   'fips': 'TS',
#   'continentcode': 'AF',
#   'capital': 'Tunis',
#   'areakm2': 163610,
#   'population': 11565204,
#   'tld': '.tn',
#   'currencycode': 'TND',
#   'currencyname': 'Dinar',
#   'phone': '216',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'ar-TN,fr',
#   'neighbours': 'DZ,LY'},
#  'Tonga': {'geonameid': 4032283,
#   'name': 'Tonga',
#   'iso': 'TO',
#   'iso3': 'TON',
#   'isonumeric': 776,
#   'fips': 'TN',
#   'continentcode': 'OC',
#   'capital': "Nuku'alofa",
#   'areakm2': 748,
#   'population': 103197,
#   'tld': '.to',
#   'currencycode': 'TOP',
#   'currencyname': "Pa'anga",
#   'phone': '676',
#   'postalcoderegex': '',
#   'languages': 'to,en-TO',
#   'neighbours': ''},
#  'Turkey': {'geonameid': 298795,
#   'name': 'Turkey',
#   'iso': 'TR',
#   'iso3': 'TUR',
#   'isonumeric': 792,
#   'fips': 'TU',
#   'continentcode': 'AS',
#   'capital': 'Ankara',
#   'areakm2': 780580,
#   'population': 82319724,
#   'tld': '.tr',
#   'currencycode': 'TRY',
#   'currencyname': 'Lira',
#   'phone': '90',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'tr-TR,ku,diq,az,av',
#   'neighbours': 'SY,GE,IQ,IR,GR,AM,AZ,BG'},
#  'Trinidad and Tobago': {'geonameid': 3573591,
#   'name': 'Trinidad and Tobago',
#   'iso': 'TT',
#   'iso3': 'TTO',
#   'isonumeric': 780,
#   'fips': 'TD',
#   'continentcode': 'NA',
#   'capital': 'Port of Spain',
#   'areakm2': 5128,
#   'population': 1389858,
#   'tld': '.tt',
#   'currencycode': 'TTD',
#   'currencyname': 'Dollar',
#   'phone': '+1-868',
#   'postalcoderegex': '',
#   'languages': 'en-TT,hns,fr,es,zh',
#   'neighbours': ''},
#  'Tuvalu': {'geonameid': 2110297,
#   'name': 'Tuvalu',
#   'iso': 'TV',
#   'iso3': 'TUV',
#   'isonumeric': 798,
#   'fips': 'TV',
#   'continentcode': 'OC',
#   'capital': 'Funafuti',
#   'areakm2': 26,
#   'population': 11508,
#   'tld': '.tv',
#   'currencycode': 'AUD',
#   'currencyname': 'Dollar',
#   'phone': '688',
#   'postalcoderegex': '',
#   'languages': 'tvl,en,sm,gil',
#   'neighbours': ''},
#  'Taiwan': {'geonameid': 1668284,
#   'name': 'Taiwan',
#   'iso': 'TW',
#   'iso3': 'TWN',
#   'isonumeric': 158,
#   'fips': 'TW',
#   'continentcode': 'AS',
#   'capital': 'Taipei',
#   'areakm2': 35980,
#   'population': 23451837,
#   'tld': '.tw',
#   'currencycode': 'TWD',
#   'currencyname': 'Dollar',
#   'phone': '886',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'zh-TW,zh,nan,hak',
#   'neighbours': ''},
#  'Tanzania': {'geonameid': 149590,
#   'name': 'Tanzania',
#   'iso': 'TZ',
#   'iso3': 'TZA',
#   'isonumeric': 834,
#   'fips': 'TZ',
#   'continentcode': 'AF',
#   'capital': 'Dodoma',
#   'areakm2': 945087,
#   'population': 56318348,
#   'tld': '.tz',
#   'currencycode': 'TZS',
#   'currencyname': 'Shilling',
#   'phone': '255',
#   'postalcoderegex': '',
#   'languages': 'sw-TZ,en,ar',
#   'neighbours': 'MZ,KE,CD,RW,ZM,BI,UG,MW'},
#  'Ukraine': {'geonameid': 690791,
#   'name': 'Ukraine',
#   'iso': 'UA',
#   'iso3': 'UKR',
#   'isonumeric': 804,
#   'fips': 'UP',
#   'continentcode': 'EU',
#   'capital': 'Kyiv',
#   'areakm2': 603700,
#   'population': 44622516,
#   'tld': '.ua',
#   'currencycode': 'UAH',
#   'currencyname': 'Hryvnia',
#   'phone': '380',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'uk,ru-UA,rom,pl,hu',
#   'neighbours': 'PL,MD,HU,SK,BY,RO,RU'},
#  'Uganda': {'geonameid': 226074,
#   'name': 'Uganda',
#   'iso': 'UG',
#   'iso3': 'UGA',
#   'isonumeric': 800,
#   'fips': 'UG',
#   'continentcode': 'AF',
#   'capital': 'Kampala',
#   'areakm2': 236040,
#   'population': 42723139,
#   'tld': '.ug',
#   'currencycode': 'UGX',
#   'currencyname': 'Shilling',
#   'phone': '256',
#   'postalcoderegex': '',
#   'languages': 'en-UG,lg,sw,ar',
#   'neighbours': 'TZ,KE,SS,CD,RW'},
#  'United States Minor Outlying Islands': {'geonameid': 5854968,
#   'name': 'United States Minor Outlying Islands',
#   'iso': 'UM',
#   'iso3': 'UMI',
#   'isonumeric': 581,
#   'fips': '',
#   'continentcode': 'OC',
#   'capital': '',
#   'areakm2': 0,
#   'population': 0,
#   'tld': '.um',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '1',
#   'postalcoderegex': '',
#   'languages': 'en-UM',
#   'neighbours': ''},
#  'United States': {'geonameid': 6252001,
#   'name': 'United States',
#   'iso': 'US',
#   'iso3': 'USA',
#   'isonumeric': 840,
#   'fips': 'US',
#   'continentcode': 'NA',
#   'capital': 'Washington',
#   'areakm2': 9629091,
#   'population': 327167434,
#   'tld': '.us',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '1',
#   'postalcoderegex': '^\\d{5}(-\\d{4})?$',
#   'languages': 'en-US,es-US,haw,fr',
#   'neighbours': 'CA,MX,CU'},
#  'Uruguay': {'geonameid': 3439705,
#   'name': 'Uruguay',
#   'iso': 'UY',
#   'iso3': 'URY',
#   'isonumeric': 858,
#   'fips': 'UY',
#   'continentcode': 'SA',
#   'capital': 'Montevideo',
#   'areakm2': 176220,
#   'population': 3449299,
#   'tld': '.uy',
#   'currencycode': 'UYU',
#   'currencyname': 'Peso',
#   'phone': '598',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'es-UY',
#   'neighbours': 'BR,AR'},
#  'Uzbekistan': {'geonameid': 1512440,
#   'name': 'Uzbekistan',
#   'iso': 'UZ',
#   'iso3': 'UZB',
#   'isonumeric': 860,
#   'fips': 'UZ',
#   'continentcode': 'AS',
#   'capital': 'Tashkent',
#   'areakm2': 447400,
#   'population': 32955400,
#   'tld': '.uz',
#   'currencycode': 'UZS',
#   'currencyname': 'Som',
#   'phone': '998',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'uz,ru,tg',
#   'neighbours': 'TM,AF,KG,TJ,KZ'},
#  'Vatican': {'geonameid': 3164670,
#   'name': 'Vatican',
#   'iso': 'VA',
#   'iso3': 'VAT',
#   'isonumeric': 336,
#   'fips': 'VT',
#   'continentcode': 'EU',
#   'capital': 'Vatican City',
#   'areakm2': 0,
#   'population': 921,
#   'tld': '.va',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '379',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'la,it,fr',
#   'neighbours': 'IT'},
#  'Saint Vincent and the Grenadines': {'geonameid': 3577815,
#   'name': 'Saint Vincent and the Grenadines',
#   'iso': 'VC',
#   'iso3': 'VCT',
#   'isonumeric': 670,
#   'fips': 'VC',
#   'continentcode': 'NA',
#   'capital': 'Kingstown',
#   'areakm2': 389,
#   'population': 110211,
#   'tld': '.vc',
#   'currencycode': 'XCD',
#   'currencyname': 'Dollar',
#   'phone': '+1-784',
#   'postalcoderegex': '',
#   'languages': 'en-VC,fr',
#   'neighbours': ''},
#  'Venezuela': {'geonameid': 3625428,
#   'name': 'Venezuela',
#   'iso': 'VE',
#   'iso3': 'VEN',
#   'isonumeric': 862,
#   'fips': 'VE',
#   'continentcode': 'SA',
#   'capital': 'Caracas',
#   'areakm2': 912050,
#   'population': 28870195,
#   'tld': '.ve',
#   'currencycode': 'VES',
#   'currencyname': 'Bolivar Soberano',
#   'phone': '58',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'es-VE',
#   'neighbours': 'GY,BR,CO'},
#  'British Virgin Islands': {'geonameid': 3577718,
#   'name': 'British Virgin Islands',
#   'iso': 'VG',
#   'iso3': 'VGB',
#   'isonumeric': 92,
#   'fips': 'VI',
#   'continentcode': 'NA',
#   'capital': 'Road Town',
#   'areakm2': 153,
#   'population': 29802,
#   'tld': '.vg',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '+1-284',
#   'postalcoderegex': '',
#   'languages': 'en-VG',
#   'neighbours': ''},
#  'U.S. Virgin Islands': {'geonameid': 4796775,
#   'name': 'U.S. Virgin Islands',
#   'iso': 'VI',
#   'iso3': 'VIR',
#   'isonumeric': 850,
#   'fips': 'VQ',
#   'continentcode': 'NA',
#   'capital': 'Charlotte Amalie',
#   'areakm2': 352,
#   'population': 106977,
#   'tld': '.vi',
#   'currencycode': 'USD',
#   'currencyname': 'Dollar',
#   'phone': '+1-340',
#   'postalcoderegex': '^008\\d{2}(?:-\\d{4})?$',
#   'languages': 'en-VI',
#   'neighbours': ''},
#  'Vietnam': {'geonameid': 1562822,
#   'name': 'Vietnam',
#   'iso': 'VN',
#   'iso3': 'VNM',
#   'isonumeric': 704,
#   'fips': 'VM',
#   'continentcode': 'AS',
#   'capital': 'Hanoi',
#   'areakm2': 329560,
#   'population': 95540395,
#   'tld': '.vn',
#   'currencycode': 'VND',
#   'currencyname': 'Dong',
#   'phone': '84',
#   'postalcoderegex': '^(\\d{6})$',
#   'languages': 'vi,en,fr,zh,km',
#   'neighbours': 'CN,LA,KH'},
#  'Vanuatu': {'geonameid': 2134431,
#   'name': 'Vanuatu',
#   'iso': 'VU',
#   'iso3': 'VUT',
#   'isonumeric': 548,
#   'fips': 'NH',
#   'continentcode': 'OC',
#   'capital': 'Port Vila',
#   'areakm2': 12200,
#   'population': 292680,
#   'tld': '.vu',
#   'currencycode': 'VUV',
#   'currencyname': 'Vatu',
#   'phone': '678',
#   'postalcoderegex': '',
#   'languages': 'bi,en-VU,fr-VU',
#   'neighbours': ''},
#  'Wallis and Futuna': {'geonameid': 4034749,
#   'name': 'Wallis and Futuna',
#   'iso': 'WF',
#   'iso3': 'WLF',
#   'isonumeric': 876,
#   'fips': 'WF',
#   'continentcode': 'OC',
#   'capital': 'Mata Utu',
#   'areakm2': 274,
#   'population': 16025,
#   'tld': '.wf',
#   'currencycode': 'XPF',
#   'currencyname': 'Franc',
#   'phone': '681',
#   'postalcoderegex': '^(986\\d{2})$',
#   'languages': 'wls,fud,fr-WF',
#   'neighbours': ''},
#  'Samoa': {'geonameid': 4034894,
#   'name': 'Samoa',
#   'iso': 'WS',
#   'iso3': 'WSM',
#   'isonumeric': 882,
#   'fips': 'WS',
#   'continentcode': 'OC',
#   'capital': 'Apia',
#   'areakm2': 2944,
#   'population': 196130,
#   'tld': '.ws',
#   'currencycode': 'WST',
#   'currencyname': 'Tala',
#   'phone': '685',
#   'postalcoderegex': 'AS 96799',
#   'languages': 'sm,en-WS',
#   'neighbours': ''},
#  'Yemen': {'geonameid': 69543,
#   'name': 'Yemen',
#   'iso': 'YE',
#   'iso3': 'YEM',
#   'isonumeric': 887,
#   'fips': 'YM',
#   'continentcode': 'AS',
#   'capital': 'Sanaa',
#   'areakm2': 527970,
#   'population': 28498687,
#   'tld': '.ye',
#   'currencycode': 'YER',
#   'currencyname': 'Rial',
#   'phone': '967',
#   'postalcoderegex': '',
#   'languages': 'ar-YE',
#   'neighbours': 'SA,OM'},
#  'Mayotte': {'geonameid': 1024031,
#   'name': 'Mayotte',
#   'iso': 'YT',
#   'iso3': 'MYT',
#   'isonumeric': 175,
#   'fips': 'MF',
#   'continentcode': 'AF',
#   'capital': 'Mamoudzou',
#   'areakm2': 374,
#   'population': 279471,
#   'tld': '.yt',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '262',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'fr-YT',
#   'neighbours': ''},
#  'South Africa': {'geonameid': 953987,
#   'name': 'South Africa',
#   'iso': 'ZA',
#   'iso3': 'ZAF',
#   'isonumeric': 710,
#   'fips': 'SF',
#   'continentcode': 'AF',
#   'capital': 'Pretoria',
#   'areakm2': 1219912,
#   'population': 57779622,
#   'tld': '.za',
#   'currencycode': 'ZAR',
#   'currencyname': 'Rand',
#   'phone': '27',
#   'postalcoderegex': '^(\\d{4})$',
#   'languages': 'zu,xh,af,nso,en-ZA,tn,st,ts,ss,ve,nr',
#   'neighbours': 'ZW,SZ,MZ,BW,NA,LS'},
#  'Zambia': {'geonameid': 895949,
#   'name': 'Zambia',
#   'iso': 'ZM',
#   'iso3': 'ZMB',
#   'isonumeric': 894,
#   'fips': 'ZA',
#   'continentcode': 'AF',
#   'capital': 'Lusaka',
#   'areakm2': 752614,
#   'population': 17351822,
#   'tld': '.zm',
#   'currencycode': 'ZMW',
#   'currencyname': 'Kwacha',
#   'phone': '260',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'en-ZM,bem,loz,lun,lue,ny,toi',
#   'neighbours': 'ZW,TZ,MZ,CD,NA,MW,AO'},
#  'Zimbabwe': {'geonameid': 878675,
#   'name': 'Zimbabwe',
#   'iso': 'ZW',
#   'iso3': 'ZWE',
#   'isonumeric': 716,
#   'fips': 'ZI',
#   'continentcode': 'AF',
#   'capital': 'Harare',
#   'areakm2': 390580,
#   'population': 16868409,
#   'tld': '.zw',
#   'currencycode': 'ZWG',
#   'currencyname': 'Zimbabwe Gold',
#   'phone': '263',
#   'postalcoderegex': '',
#   'languages': 'en-ZW,sn,nr,nd',
#   'neighbours': 'ZA,MZ,BW,ZM'},
#  'Serbia and Montenegro': {'geonameid': 8505033,
#   'name': 'Serbia and Montenegro',
#   'iso': 'CS',
#   'iso3': 'SCG',
#   'isonumeric': 891,
#   'fips': 'YI',
#   'continentcode': 'EU',
#   'capital': 'Belgrade',
#   'areakm2': 102350,
#   'population': 10829175,
#   'tld': '.cs',
#   'currencycode': 'RSD',
#   'currencyname': 'Dinar',
#   'phone': '381',
#   'postalcoderegex': '^(\\d{5})$',
#   'languages': 'cu,hu,sq,sr',
#   'neighbours': 'AL,HU,MK,RO,HR,BA,BG'},
#  'Netherlands Antilles': {'geonameid': 8505032,
#   'name': 'Netherlands Antilles',
#   'iso': 'AN',
#   'iso3': 'ANT',
#   'isonumeric': 530,
#   'fips': 'NT',
#   'continentcode': 'NA',
#   'capital': 'Willemstad',
#   'areakm2': 960,
#   'population': 300000,
#   'tld': '.an',
#   'currencycode': 'ANG',
#   'currencyname': 'Guilder',
#   'phone': '599',
#   'postalcoderegex': '',
#   'languages': 'nl-AN,en,es',
#   'neighbours': 'GP'}}

# %%
def infer_country_from_tokens(tokens):
    for token in tokens:
        token = token.strip().lower()
        if token in COUNTRY_LOOKUP:
            return COUNTRY_LOOKUP[token]
        if token in US_STATE_TO_US or token in US_STATE_NAMES:
            return "US"
        if token in CA_PROV_TO_CA or token in CA_PROV_NAMES:
            return "CA"
    return None

# %%
COMMA_SPLIT_RE = re.compile(r"\s*,\s*")

def extract_country_code(loc: str):
    if not loc:
        return None

    s = loc.lower().strip()

    # quick wins: check full string against lookup
    if s in COUNTRY_LOOKUP:
        return COUNTRY_LOOKUP[s]

    # check comma-separated parts
    parts = [p.strip() for p in COMMA_SPLIT_RE.split(s) if p.strip()]
    if not parts:
        return None

    # try last part as country
    last = parts[-1]
    if last in COUNTRY_LOOKUP:
        return COUNTRY_LOOKUP[last]

    # try any part as country (handles "toulouse - france" after your separator cleanup)
    for p in parts:
        if p in COUNTRY_LOOKUP:
            return COUNTRY_LOOKUP[p]

    # US state / CA province inference from last token
    # Example: "san francisco, ca" => US
    tokens = []
    for part in parts:
        tokens.extend(part.split())

    return infer_country_from_tokens(tokens)

df["country_code"] = None
mask = df["location_status"].eq("candidate")
df.loc[mask, "country_code"] = df.loc[mask, "location_norm"].map(extract_country_code)

# %%
# If we got a country_code, it's valid
df.loc[mask & df["country_code"].notna(), "location_status"] = "valid"

# If candidate but still no country_code, ambiguous (not necessarily junk)
df.loc[mask & df["country_code"].isna(), "location_status"] = "ambiguous"

# Optional: map code back to country name (if pycountry available)
def code_to_name(code):
    try:
        import pycountry
        c = pycountry.countries.get(alpha_2=code)
        return c.name if c else None
    except Exception:
        return None

df["country"] = df["country_code"].map(code_to_name)

# %%
df.head()
# Out:
#          location    location_raw   location_norm location_status  \
# 0  China.Shanghai  China.Shanghai  china.shanghai       ambiguous
# 1   Pangyo, Korea   Pangyo, Korea   pangyo, korea           valid
# 2        Tel Aviv        Tel Aviv        tel aviv       ambiguous
# 3              WH              WH              wh       ambiguous
# 4    Live Oak, FL    Live Oak, FL    live oak, fl           valid
#
#   country_code             country
# 0         None                None
# 1           KR  Korea, Republic of
# 2         None                None
# 3         None                None
# 4           US       United States

# %%
df.to_csv('/home/chef/src/DAT6003/data/processed/author_locations_processed.csv', index=False)

# %%
(int(df['country'].isna().sum()) / len(df)) * 100
# Out:
# 41.7910447761194

# %% [markdown]
# ~42% of the given locations in the data cannot be mapped to countries with certainty. a lot of ambiguitiy makes fuzzy matching a possibility to increase this value.

# %%
# Re-get nodes, collecting location from author data now

nodes = []

for issue in issues_data:
    if issue['author'] == {} or issue['author'] is None:
        continue
    else:
        nodes.append((issue['author']['login'], issue['author'].get('location')))

    if "comments" in issue and len(issue["comments"]["nodes"]) > 0:
        for comment in issue["comments"]["nodes"]:
            if comment['author'] == {}:
                continue
            author = comment.get('author')
            if author and 'login' in author:
                nodes.append((author['login'], author.get('location')))

nodes = set(nodes)
len(nodes)
nodes
# Out:
# {('LianaN', 'Spain (Barcelona)'),
#  ('aclifton314', None),
#  ('HuangZhenyang', None),
#  ('shijie-wu', 'Bethesda, MD'),
#  ('wasiahmad', 'Santa Clara, CA, USA'),
#  ('LostBenjamin', None),
#  ('shenkev', None),
#  ('punshriv', None),
#  ('Sun-SunQian', None),
#  ('Wingie', None),
#  ('LincLabUCCS', None),
#  ('RitaRan', 'Durham, NC'),
#  ('thies1006', None),
#  ('diego6662', 'Pereira - Colombia'),
#  ('alessandrobessi', 'Firenze, ITALY'),
#  ('Somabhadra', 'Bangalore'),
#  ('ciwang', 'Brooklyn'),
#  ('Apoorvgarg-creator', None),
#  ('wholebuzz', 'Santa Cruz, CA'),
#  ('soocheolnoh', None),
#  ('aiwarrior-23', None),
#  ('seanbenhur', None),
#  ('mosheliv', None),
#  ('delip', None),
#  ('StephennFernandes', 'Goa , INDIA'),
#  ('tonyhqanguyen', 'Vancouver, BC'),
#  ('ninjalu', None),
#  ('pglock', None),
#  ('hscspring', None),
#  ('jcw521', None),
#  ('jamalex', 'San Diego'),
#  ('christophschuhmann', 'Hamburg, Germany'),
#  ('tospirits', None),
#  ('tbaggu', None),
#  ('Eric-Wallace', None),
#  ('hackyon', 'New York'),
#  ('MyBruso', None),
#  ('MSMOON', None),
#  ('alej-90', None),
#  ('cedspam', None),
#  ('ankushbhatia2', 'Bengaluru, Karnataka'),
#  ('pbabvey', None),
#  ('shiv6891', 'Darmstadt'),
#  ('insomnia1996', None),
#  ('valmetisrinivas', None),
#  ('nateraw', None),
#  ('petertjmills', None),
#  ('JingqingZ', 'London, UK'),
#  ('redthing1', 'California'),
#  ('sayakpaul', 'India'),
#  ('riacheruvu', None),
#  ('DavidHarrison', 'Seattle, WA'),
#  ('LeonardoGracioS', None),
#  ('victormaricato', None),
#  ('BenjaminLAZARD', 'Paris, France'),
#  ('Jasonsey', 'Xiamen'),
#  ('fulsi', None),
#  ('surbhi498', 'US'),
#  ('gaps013', None),
#  ('dongyups', 'Seoul, South Korea'),
#  ('Ninja16180', None),
#  ('ShoubhikBanerjee', 'India'),
#  ('SahanaRamnath', 'Los Angeles, USA'),
#  ('TidesCheng', None),
#  ('takahiro971', None),
#  ('Guillem96', 'Lleida'),
#  ('ZhuBaohe', 'Shanghai'),
#  ('workworkwc3', None),
#  ('bingo789', None),
#  ('product-copy', None),
#  ('peterwolf-smarsh', 'Boston area'),
#  ('nehasrikn', 'College Park, MD'),
#  ('mkumar10', None),
#  ('krfricke', None),
#  ('ChaooMa', None),
#  ('yuanmingchen', 'Harbin, China'),
#  ('brendan-AI', 'Ireland'),
#  ('fatmelon', 'Beijing'),
#  ('Crabzmatic', 'Bratislava, Slovakia'),
#  ('Zhenzi-Weng', None),
#  ('yuchenlin', 'Palo Alto, CA'),
#  ('dr-aheydari', 'San Francisco'),
#  ('1gst', None),
#  ('IamSparky', None),
#  ('HaoboGu', 'Hangzhou'),
#  ('HebaGamalElDin', 'Cairo, Egypt'),
#  ('fdalvi', None),
#  ('preciousakpan', None),
#  ('aixuedegege', None),
#  ('PrudhviRaj12', 'New York, NY'),
#  ('waring92', 'Seoul, South Korea'),
#  ('lethienhoa', 'Grenoble, France'),
#  ('rohansheelvant', 'India'),
#  ('noise-field', None),
#  ('xiaoda99', None),
#  ('kargarisaac', 'Finland'),
#  ('europeanplaice', 'Japan'),
#  ('metahgva', None),
#  ('praeducer', 'Atlanta'),
#  ('p-null', 'Toronto, Canada'),
#  ('hsm207', 'Everywhere'),
#  ('rion-o', None),
#  ('Fredrum', 'Vancouver'),
#  ('jianwolf', 'Seattle, WA'),
#  ('tejaravi675', None),
#  ('vkorf', None),
#  ('experiencor', 'Singapore'),
#  ('dsuess', 'Sydney'),
#  ('junxu-ai', 'Singapore'),
#  ('moqingyan', None),
#  ('vickyliin', 'Taipei, Taiwan'),
#  ('TianHongZXY', 'Charlottesville, VA'),
#  ('ikuyamada', 'Tokyo'),
#  ('OllieBroadhurst', None),
#  ('MatthewCYM', None),
#  ('kingxiaotian', 'China.Shanghai'),
#  ('llidev', None),
#  ('GerardBurnside', None),
#  ('Mse709', None),
#  ('lachlancahill', None),
#  ('xmcs111', None),
#  ('abs51295', 'Los Angeles, CA'),
#  ('hassanzadeh', None),
#  ('dineshggaonkar', None),
#  ('BordiaS', 'New York City'),
#  ('LiZongyue', 'Munich'),
#  ('federicoruggeri', None),
#  ('chijames', None),
#  ('wilcoln', 'London, UK'),
#  ('asymmetric-supernova', 'Austria'),
#  ('kseh92', 'London, UK'),
#  ('jungwhank', 'Seoul'),
#  ('EikanWang', 'Shanghai, China'),
#  ('timothybrooks', None),
#  ('Avditvs', 'Paris, France'),
#  ('vinejain', 'London, UK'),
#  ('apurvaasf', 'Massachusetts'),
#  ('bagustris', 'Somewhere on earth'),
#  ('QtRoS', 'Россия'),
#  ('earlyr1', None),
#  ('louismartin', None),
#  ('lepus2', None),
#  ('nogur9', None),
#  ('Vstay97', 'Shenzhen'),
#  ('ClementRomac', 'Bordeaux, France'),
#  ('viethoang303', None),
#  ('meryemmhamdi1', 'Los Angeles, USA'),
#  ('jack-gits', None),
#  ('ZHM-Sesame', None),
#  ('sadanyh', None),
#  ('jannenev', 'Helsinki, Finland'),
#  ('ttpro1995', None),
#  ('vkrishnamurthy11', None),
#  ('dzorlu', None),
#  ('mirekphd', 'EU'),
#  ('tornikeo', 'Switzerland, Lugano'),
#  ('solatis', 'Driebergen-Rijsenburg, The Netherlands'),
#  ('shyrma', 'Ukraine'),
#  ('vikas-baghel', 'Varanasi, India'),
#  ('Xargonus', None),
#  ('FrancisYu2020', 'Urbana, IL'),
#  ('sashank06', 'Charlotte, NC'),
#  ('abiolaTresor', 'Paris'),
#  ('anjandash', None),
#  ('MastafaF', 'Seattle'),
#  ('jayachaturvedi', 'London'),
#  ('jensdebruijn', 'Amsterdam'),
#  ('omarwbassam', 'jordan'),
#  ('jxmorris12', 'New York, NY'),
#  ('Phill-at-GE', None),
#  ('lalimili6', None),
#  ('xiadingZ', 'Wuhan, China'),
#  ('jordiae', 'London'),
#  ('dharm033075', None),
#  ('antleypk', None),
#  ('dyxohjl666', None),
#  ('suyuzhang', None),
#  ('David-Levinthal', None),
#  ('Sagar1094', None),
#  ('kpich', None),
#  ('abhijith-athreya', None),
#  ('wangcongcong123', 'Dublin, Ireland'),
#  ('sreeharsha225', None),
#  ('jk-jung', None),
#  ('kolk', None),
#  ('Nikita-Shrma', None),
#  ('Wernstrong67', None),
#  ('varunSabnis', None),
#  ('markblee', None),
#  ('abelriboulot', 'New Haven'),
#  ('miteigi-nemoto', None),
#  ('SinclairSchneider', None),
#  ('siwei-li', 'Seattle, WA'),
#  ('Tolga28A', 'Raleigh, NC'),
#  ('astakara48', None),
#  ('borgr', None),
#  ('wonyoungseo', 'Seoul, South Korea'),
#  ('AlexUmnov', 'Amsterdam'),
#  ('Sea-Snell', 'Berkeley, CA'),
#  ('itsrajatrai', 'Bharat | India'),
#  ('vjagannath786', None),
#  ('azayz', 'Berlin, Germany'),
#  ('gchanan', None),
#  ('firefly34', None),
#  ('alexiycv', None),
#  ('VikasOjha666', 'Greater Noida,Uttar Pradesh,India'),
#  ('siwarBM', 'Tunisie'),
#  ('shreyajain4', None),
#  ('JaeDukSeo', None),
#  ('chatzich', 'Nea Efessos,Pieria,Greece'),
#  ('SkyZX', None),
#  ('xjw-star', None),
#  ('mahdirezaey', None),
#  ('JerryPan2718', 'Palo Alto, California'),
#  ('alexandrabenamar', 'France, Paris'),
#  ('KnightZhang625', 'Glasgow'),
#  ('yongzx', None),
#  ('ddobokki', 'Republic of Korea'),
#  ('galshachaf', None),
#  ('SeanBannister', 'Sunshine Coast, Australia'),
#  ('waalge', None),
#  ('geffy', 'Moscow'),
#  ('agombert', None),
#  ('GRIGORR', None),
#  ('HamidMoghaddam', None),
#  ('nouranali', 'Cairo, Egypt'),
#  ('azizcu', None),
#  ('nguyenvulebinh', None),
#  ('maxvonhippel', 'Boston'),
#  ('Hansyvea', None),
#  ('mariaBio', None),
#  ('LFruth', None),
#  ('ArvinZhuang', 'Brisbane'),
#  ('qixintechnology', 'Guangzhou, China'),
#  ('sameerreddy13', None),
#  ('sunyangfu', None),
#  ('shabie', None),
#  ('zhuwensi', None),
#  ('snoop2head', 'Pittsburgh, USA'),
#  ('aranciokov', None),
#  ('kruthikakr', 'Bangalore'),
#  ('yezhengli-Mr9', 'Philadelphia'),
#  ('Limtle', None),
#  ('xinliweiyuan', None),
#  ('Smolky', 'Spain'),
#  ('hrsht-neur', None),
#  ('vilmarzti', 'Zurich'),
#  ('hasansalimkanmaz', None),
#  ('vsuarezpaniagua', None),
#  ('alwayscurious', None),
#  ('anishthite', 'sf'),
#  ('baeseongsu', None),
#  ('dsadulla', 'Bangalore, India'),
#  ('CarolLi', None),
#  ('rnyak', None),
#  ('tanujjain', 'Germany'),
#  ('luyug', 'Pittsburgh'),
#  ('jianliu-ml', None),
#  ('alromb', None),
#  ('thinksoso', 'CHINA'),
#  ('small-cold-hands', 'Russia'),
#  ('RayLei', None),
#  ('nishprabhu', None),
#  ('timwillhack', None),
#  ('kolakows', None),
#  ('saekomdalkom', None),
#  ('saippuakauppias', None),
#  ('arthurodriguesbatista', 'Maringá, Paraná, Brazil.'),
#  ('hzhwcmhf', 'Beijing, China'),
#  ('baradl', 'München, Germany'),
#  ('ANarayan', None),
#  ('pramitchoudhary', 'Mountain View/LA'),
#  ('gauravgund', None),
#  ('semsevens', None),
#  ('kushagrabhushan', None),
#  ('blueprintparadise', None),
#  ('ALUKErnel', None),
#  ('christianversloot', 'Nijmegen area, NL'),
#  ('howlinghuffy', None),
#  ('dr-smgad', 'United States'),
#  ('TrentBrick', 'San Francisco'),
#  ('AMF777', None),
#  ('JingyaHuang', 'Paris, FR'),
#  ('PeterAJansen', None),
#  ('geblanco', 'Madrid, Spain'),
#  ('hari-chalise', None),
#  ('krishnadurai', 'Burlingame, USA'),
#  ('avinashsai', 'Santa Clara'),
#  ('williamFalcon', 'New York City, NY'),
#  ('rohan-varma', 'NYC'),
#  ('albarji', 'Madrid, Spain'),
#  ('BryanWBear', None),
#  ('CSuperlei', 'Beijing'),
#  ('clefourrier', 'France'),
#  ('0xsimulacra', 'France'),
#  ('rabbitwayne', None),
#  ('reichenbch', 'Bengaluru'),
#  ('Enumaris', None),
#  ('yupei9', None),
#  ('zazke', None),
#  ('xloem', '(future - past).src'),
#  ('MarkJGx', None),
#  ('mmbejani', 'IRAN'),
#  ('kgarg8', 'Chicago, IL'),
#  ('Buguemar', 'Germany'),
#  ('MishaLaskin', 'New York City'),
#  ('yanan1116', 'Toronto, Canada'),
#  ('pasDamola', 'Abuja, Nigeria'),
#  ('coder-duibai', 'Tsinghua University'),
#  ('hadi-abdine', 'Paris - France'),
#  ('briancleland', None),
#  ('4kasha', 'Japan'),
#  ('foton263', 'Athens, Greece'),
#  ('ZZy979', 'Beijing, China'),
#  ('ChenxinAn-fdu', 'Hong Kong'),
#  ('normster', 'CA'),
#  ('deklanw', 'Austin, TX'),
#  ('anamtaamin', 'Allahabad, Uttar Pradesh, India'),
#  ('elephantomkk', None),
#  ('raspuchin', 'San Jose'),
#  ('poedator', None),
#  ('Darktex', 'Menlo Park, CA'),
#  ('WangHexie', None),
#  ('free2ride19', 'NIGERIA'),
#  ('gameveloster', None),
#  ('BrainSlugs83', None),
#  ('Pydataman', 'China'),
#  ('ryangawei', 'Vancouver'),
#  ('Ch-rode', None),
#  ('anilkumarKanasani', None),
#  ('slimaneaymen', None),
#  ('nimahm2020', None),
#  ('viantirreau', 'Chile'),
#  ('MarvinMogab', None),
#  ('IvanoLauriola', None),
#  ('Imaginny', None),
#  ('ricarsch', 'Taipei, Taiwan'),
#  ('urialon', None),
#  ('marekninja', 'Bratislava, Slovakia'),
#  ('pascalhuszar', None),
#  ('light8lee', 'HITSZ'),
#  ('nt-sumit', None),
#  ('marcalt94', None),
#  ('insublee', None),
#  ('kamalkraj', 'Kochi, india'),
#  ('zhangbaoxin123', None),
#  ('pathikchamaria', None),
#  ('tqnwhz', None),
#  ('kgulpinar', 'Ankara, Turkey'),
#  ('karndeb', 'Bengaluru, India'),
#  ('culcomp', None),
#  ('bgoldenboy', None),
#  ('i404788', None),
#  ('vinaygeorgeroy', None),
#  ('StephenQuirolgico', None),
#  ('crmuhsin', 'Dhaka'),
#  ('limuyun99', None),
#  ('Ontopic', None),
#  ('MowanHu', 'BeiJing'),
#  ('orenpapers', None),
#  ('Aniruddha-JU', None),
#  ('ajesujoba', 'Germany'),
#  ('dclong', 'Seattle, WA'),
#  ('jackfeinmann5', None),
#  ('mgreenbe', 'Calgary, Canada'),
#  ('kangqiyue', None),
#  ('falakchhaya', 'India'),
#  ('Michael95-m', 'Yangon, Myanmar'),
#  ('BOUALILILila', 'Paris'),
#  ('Wangpeiyi9979', 'ChengDu,SiChuan,China'),
#  ('MichalPleban', None),
#  ('chmccreery', None),
#  ('DataDaveH', None),
#  ('ptrblck', None),
#  ('Riccorl', 'Rome, Italy'),
#  ('polplop', None),
#  ('evertonaleixo', 'Goiania, Brazil'),
#  ('bhacquin', None),
#  ('fajri91', 'Abu Dhabi'),
#  ('AndDoIt', None),
#  ('snova-rodrigom', None),
#  ('ramdeepak100', None),
#  ('jessdaubner', 'Austin, TX'),
#  ('sersoage', None),
#  ('gopal354', 'Gananvaram'),
#  ('JunhyunB', 'Daegu, South Korea'),
#  ('siheming', None),
#  ('tsuyoshi-fukuzawa', None),
#  ('qinyuenlp', 'China.Liuzhou'),
#  ('tholor', 'Berlin, Germany'),
#  ('cthoyt', 'Bonn, Germany'),
#  ('blagav', None),
#  ('mary-design-testing', None),
#  ('n-a-sz', None),
#  ('xvr-hlt', None),
#  ('eduOS', 'https://vocabulary-journal.com'),
#  ('MJimitater', None),
#  ('SilSever', 'Rome'),
#  ('ramscodehub', None),
#  ('kash203', None),
#  ('johnwu0604', None),
#  ('zyddora', 'Beijing, China'),
#  ('rabrabrab', None),
#  ('melancholicwang', None),
#  ('edwardcqian', 'Toronto, ON'),
#  ('paramansh', 'Kanpur, India'),
#  ('mitramir55', None),
#  ('fortunechen', 'Beijing'),
#  ('beyhangl', 'Turkey'),
#  ('lishengfever', None),
#  ('Green-li', 'Suzhou,Jiangsu Province, China'),
#  ('hamishdickson', 'London'),
#  ('junkgear', 'Pune'),
#  ('jokebroker', 'Sydney, Australia'),
#  ('mckunkel', 'Hartford, CT'),
#  ('aloka2209', None),
#  ('jasmine400', None),
#  ('APJansen', 'Utrecht, Netherlands'),
#  ('avianion', None),
#  ('Alexander-Jin', None),
#  ('cliffordkleinsr', 'Nairobi'),
#  ('chutaklee', None),
#  ('nasib-ullah', 'Espoo, Finland'),
#  ('mmaslankowska-neurosys', 'Rybacka 7/I floor, 53-656 Wrocław'),
#  ('LIUYANZHI88', 'china'),
#  ('liamcli', None),
#  ('hoangphuc1998', 'HCM City'),
#  ('lorinaandr', None),
#  ('dwhdai-ada', None),
#  ('barton-wa', None),
#  ('jerrypcl', None),
#  ('samer-noureddine', None),
#  ('Saltsmart', None),
#  ('daquarti', None),
#  ('guhur', 'Paris, France'),
#  ('Katherine536', None),
#  ('27182812', None),
#  ('hasakikiki', None),
#  ('daraksha-shirin', None),
#  ('OOF-dura', None),
#  ('alberto-hong', None),
#  ('jordaniac89', None),
#  ('akedjouadj', None),
#  ('DUT-Tjy', 'Dalian'),
#  ('mksenzov', 'Ottawa, ON, Canada'),
#  ('watkinsm', 'Helsinki, Finland'),
#  ('Pushkinue', None),
#  ('dwaydwaydway', None),
#  ('gyuwankim', 'Santa Barbara, CA, United States'),
#  ('kswamy15', None),
#  ('itsnamgyu', 'Seoul, Korea'),
#  ('tianleiwu', None),
#  ('dhpollack', 'Berlin'),
#  ('jGuedex', None),
#  ('ahmedkotb98', 'Egypt'),
#  ('ypirkani', None),
#  ('duedme', None),
#  ('cangozpi', None),
#  ('ai-john', 'Stanford'),
#  ('neurite', 'Seattle, WA'),
#  ('Shane-Neeley', None),
#  ('M-Salti', 'Dubai, UAE'),
#  ('benj3542', 'Denmark'),
#  ('SantiagoEG', 'Murcia, Spain'),
#  ('nlpLover123', None),
#  ('pallavimitra', 'Berlin, Germany'),
#  ('Abdelrhman-Hosny', None),
#  ('shauli-ravfogel', None),
#  ('dipanjanS', None),
#  ('tc64', None),
#  ('Nkonstan', None),
#  ('seo-95', None),
#  ('SarangSanjayGujar-lilly', None),
#  ('AlexanderKUA', None),
#  ('Khreas', None),
#  ('yakazimir', None),
#  ('notooth1', None),
#  ('sumanthd17', 'Hyderabad'),
#  ('abhishekkrthakur', '127.0.0.1'),
#  ('BirgerMoell', None),
#  ('francescorubbo', None),
#  ('frost-768', None),
#  ('ahmetgunduz', None),
#  ('hi-weiyuan', None),
#  ('Madhuri05thorat', None),
#  ('Anku5hk', 'Pune, Maharashtra.'),
#  ('Prettyyyyyyyyy', None),
#  ('JunjieHu', None),
#  ('tbabinet', None),
#  ('moniquebm', None),
#  ('vedantg12', 'New Jersey'),
#  ('olix20', 'Earth'),
#  ('junhuang-ifast', None),
#  ('shunyuzh', 'Beijing'),
#  ('laifi', None),
#  ('Ted8000', None),
#  ('severo', 'La Paz, Bolivia'),
#  ('nittonfemton', 'Stockholm'),
#  ('daniel-z-kaplan', None),
#  ('jinkilee', 'Pangyo'),
#  ('lui-shex', None),
#  ('ddofer', 'Israel'),
#  ('hbchen121', 'Beijing'),
#  ('kongzii', 'Prague'),
#  ('mthrok', None),
#  ('tine8899', 'Mars'),
#  ('jorgtied', None),
#  ('V-Sher', None),
#  ('thelou1s', None),
#  ('AmmarRashed', 'Canada'),
#  ('marhlder', 'Hedehusene (Denmark)'),
#  ('feverer', 'BeiJing'),
#  ('artemisart', 'Paris, France'),
#  ('shreyaspatil276', None),
#  ('YuanGongND', 'Cambridge, MA'),
#  ('cdo03c', 'United States'),
#  ('thedomdom', 'Heidelberg'),
#  ('abhigenie92', 'San Jose, California'),
#  ('XikunZhang', None),
#  ('YixuanCao', None),
#  ('LunaJang', None),
#  ('apugachev', 'Moscow, Chisinau'),
#  ('Odimmsun', None),
#  ('Junpliu', 'Hong Kong'),
#  ('ViktorTorp', None),
#  ('meetps', 'Mountain View, CA'),
#  ('pradeepsinghnitk', 'India'),
#  ('yagelardan', None),
#  ('alvitawa', None),
#  ('innat', 'Dhaka, Bangladesh'),
#  ('pidugusundeep', 'Seattle, USA'),
#  ('sunshineatnoon', 'Merced, CA'),
#  ('neuromaancer', 'Paris'),
#  ('aazqueta', 'Oxford'),
#  ('sjrl', 'Munich'),
#  ('SysuJayce', 'Guangzhou, China'),
#  ('sgugger', None),
#  ('cemanughian', 'Los Angeles'),
#  ('vinhngx', 'Melbourne, Australia'),
#  ('dinsausti', None),
#  ('0xnakul', None),
#  ('eyalshafran', 'Salt Lake City'),
#  ('lalitr994', None),
#  ('capitanA', 'Great Toronto Area'),
#  ('alphanlp', None),
#  ('zhjohnchan', 'Stanford, CA'),
#  ('andbloch', 'Zuerich'),
#  ('murugeshmanthiramoorthi', 'Toulouse, France'),
#  ('Mahima-ai', None),
#  ('aced125', None),
#  ('amy-hyunji', None),
#  ('lbda1', None),
#  ('rbehzadan', 'Toronto'),
#  ('kushalj001', 'Seattle'),
#  ('Warra07', 'Paris - France'),
#  ('zachflam', None),
#  ('ZhishanQ', 'Chicago, Illinois'),
#  ('Ricco48', 'Jakarta, Indonesia'),
#  ('jannisborn', 'Zurich'),
#  ('aribenjamin', None),
#  ('miketrimmel', 'Vienna'),
#  ('danaarad', None),
#  ('LeoXinhaoLee', None),
#  ('atom00', None),
#  ('yana-xuyan', 'Hong Kong'),
#  ('Marc-Morcos', None),
#  ('karthik19967829', 'Sanfrancisco, USA'),
#  ('prassanna-ravishankar', 'London'),
#  ('649459021', None),
#  ('scellat', None),
#  ('cpcdoy', None),
#  ('qishibo', 'HD'),
#  ('WenxiongLiao', None),
#  ('lukesalamone', 'Bay Area'),
#  ('Leeyaa', 'BeiJing'),
#  ('amogkam', None),
#  ('gmaratos', None),
#  ('nguyentthong', 'Singapore'),
#  ('123-kalai', None),
#  ('kmckiern', 'San Francisco, CA'),
#  ('mareloraby', 'Cairo, EGY'),
#  ('lorr1', 'Seattle, WA'),
#  ('axhiao', None),
#  ('CryptoLordSheogorath', None),
#  ('shinishiho', 'Ho Chi Minh City, Vietnam'),
#  ('sophial05', 'Stanford'),
#  ('dimka11', 'Russia, Omsk'),
#  ('Aureole-1210', None),
#  ('Stupack', None),
#  ('nlp-sudo', None),
#  ('qipeng', None),
#  ('nooralahzadeh', 'Zurich/Switzerland'),
#  ('lehaoqu', 'No. 37, Xueyuan Road, Haidian District, Beijing'),
#  ('amalad', None),
#  ('hoangthangta', 'Ho Chi Minh city'),
#  ('zhujun5164', None),
#  ('yuvalkirstain', 'Tel Aviv'),
#  ('limapedro', None),
#  ('ChongMingWei', None),
#  ('james-vincent', None),
#  ('aqibsaeed', 'Netherlands'),
#  ('evros-chris', 'Paphos, Cyprus'),
#  ('adhithyaarun', 'Bangalore | Hyderabad | Chennai | Doha'),
#  ('Am1n3e', 'Canada'),
#  ('monsieurpooh', None),
#  ('czonios', 'Ioannina, Greece'),
#  ('anshoomehra', None),
#  ('renjithsasidharan', 'Bangalore'),
#  ('imxiaomin', None),
#  ('yobekiko', None),
#  ('dtsukiyama', None),
#  ('mmiakashs', 'Washington, US'),
#  ('ycj0123', 'Taiwan'),
#  ('udeepam', None),
#  ('jolinxql', None),
#  ('Nannigalaxy', 'Bengaluru, India'),
#  ('etiennedi', 'Germany'),
#  ('sasi143', None),
#  ('justStarG', None),
#  ('cozek', 'Bangalore <-> Guwahati'),
#  ('macleginn', 'Manchester'),
#  ('Kitiro', None),
#  ('khashei', None),
#  ('jcsilva', 'Brazil'),
#  ('arnavc1712', 'San Francisco, California'),
#  ('fansiawang', None),
#  ('LouisCastricato', None),
#  ('A-kali', 'Guangzhou, Guangdong, China'),
#  ('abesalom10', None),
#  ('scratchmex', None),
#  ('llStringll', None),
#  ('pratt3000', 'San Francisco'),
#  ('mespla', None),
#  ('HongyuanLuke', None),
#  ('patdflynn', None),
#  ('kaiidams', 'Tokyo'),
#  ('hoangcuong2011', None),
#  ('bendboaz', 'Israel'),
#  ('chrisdt1998', None),
#  ('GeassTaiga', None),
#  ('rabeehk', None),
#  ('tan-xu', 'Beijing, China'),
#  ('hikf3', None),
#  ('chqiwang', None),
#  ('lucasjinreal', 'Sanfancisco'),
#  ('kristjanArumae', 'Seattle'),
#  ('Kayne88', None),
#  ('rpoli40', None),
#  ('AbdallahHefny', None),
#  ('WaterKnight1998', None),
#  ('sbecon', 'United States'),
#  ('anum94', 'Munich, Germany'),
#  ('antoniomrfranco', None),
#  ('borisfom', 'Gig Harbor, WA'),
#  ('polly-morphism', None),
#  ('ttanida', 'Barcelona, Spain'),
#  ('xjw-nlp', None),
#  ('jandonov', None),
#  ('johncookds', None),
#  ('MohammedRakib', 'Stillwater, Oklahoma, United States'),
#  ('david-adametz', None),
#  ('liesun1994', 'Suzhou'),
#  ('LeeJuly30', 'Tianjin China'),
#  ('angeloskath', 'United States'),
#  ('DanKing1903', None),
#  ('LukeLIN-web', None),
#  ('timpal0l', 'Stockholm, Sweden'),
#  ('thomas-happify', None),
#  ('zartdinov', None),
#  ('yuanzhedong', 'Palo Alto'),
#  ('dkawahara', 'Tokyo, Japan'),
#  ('gro1m', None),
#  ('rishibommasani', None),
#  ('not-william', 'London, UK'),
#  ('reidsanders', 'Boston, MA'),
#  ('reneix', None),
#  ('Qbiwan', 'Singapore'),
#  ('thunderock', 'Bay Area'),
#  ('orenkobo', None),
#  ('bricksdont', 'Switzerland'),
#  ('ajsanjoaquin', 'Barcelona, Spain'),
#  ('wangyems', 'San Jose'),
#  ('garaud', 'France / Bordeaux'),
#  ('anonymous2ch', None),
#  ('AmbiTyga', 'India'),
#  ('aliasneo1', None),
#  ('guowenying111', None),
#  ('devsteppe9', 'IA, US'),
#  ('mrinalTheCoder', 'Atlanta'),
#  ('mohith7548', 'India'),
#  ('depshad', None),
#  ('ahmedkobtan', None),
#  ('minh-h-ng', None),
#  ('quest4next', None),
#  ('rhamnett', None),
#  ('ba305', None),
#  ('jiangke-sr', None),
#  ('lucadinidue', 'Pisa'),
#  ('lighteternal', 'Athens, GR'),
#  ('sherlcok314159', 'China'),
#  ('xienian87', None),
#  ('puzzler10', 'London'),
#  ('Deamoner', 'Ottawa'),
#  ('ronakice', 'Waterloo, ON'),
#  ('Petroncini', None),
#  ('jamesr66a', 'Redwood City, CA'),
#  ('khoda81', 'Iran, Guilan, Rasht'),
#  ('keaideii', 'Wuhan'),
#  ('nikitakit', None),
#  ('vin136', None),
#  ('shirley-wu', None),
#  ('kuppulur', 'Apex, NC'),
#  ('Chidu2000', 'Jamkhandi'),
#  ('NPap0', None),
#  ('vivekatwal', 'Mumbai'),
#  ('mitsuix', None),
#  ('zainsarwar865', 'Chicago, USA'),
#  ('Tanman2001', None),
#  ('ayalaall', None),
#  ('eureka336', 'shenyang'),
#  ('itssimon', 'Sunshine Coast, Australia'),
#  ('f-lng', None),
#  ('xuanzebi', 'Beijng'),
#  ('shimoshida', 'Japan'),
#  ('ZeJ0hn', None),
#  ('vsocrates', 'New Haven, CT'),
#  ('elfprince13', 'New England'),
#  ('mqliu7', None),
#  ('arditobryan', None),
#  ('Decem-Y', 'Chendu, Sichuan'),
#  ('calebdkofahl', None),
#  ('Cppowboy', 'Beijing, China'),
#  ('srikar2097', None),
#  ('jaideep11061982', None),
#  ('25icecreamflavors', None),
#  ('zxk19981227', None),
#  ('chenxran', 'Ann Arbor'),
#  ('djberenberg', 'New York, NY'),
#  ('naveenjafer', 'India'),
#  ('DCNemesis', None),
#  ('seyuboglu', None),
#  ('weiwei1206', None),
#  ('RomanKornev', 'London, UK'),
#  ('prince14322', 'Bombay'),
#  ('Celsollopes', ' Brazil and Portugal'),
#  ('Choitsugun', 'Tokyo'),
#  ('jmasom', None),
#  ('ghk829', 'San Francisco'),
#  ('laurence-lin', 'Taiwan'),
#  ('levskaya', 'san francisco, ca'),
#  ('dbonner', 'Canberra Australia'),
#  ('Sam131112', None),
#  ('wyin-Salesforce', 'Palo Alto'),
#  ('kforkaran', 'Ludiana, Punjab'),
#  ('Blaizzy', 'Poland'),
#  ('kl0211', 'Spokane, Washington'),
#  ('shihgianlee', 'Seattle, WA'),
#  ('Lollipop', None),
#  ('katiele47', None),
#  ('Charonnnnn', None),
#  ('dkaterenchuk', 'NYC'),
#  ('PrithivirajDamodaran', 'Bangkok'),
#  ('kldarek', None),
#  ('naga-dsalgo', None),
#  ('shubhangi-tandon', None),
#  ('mehdimashayekhi', 'San Francisco, CA'),
#  ('pavlion', 'CA, USA'),
#  ('Terahezi', None),
#  ('bkj', None),
#  ('dheeraj7596', 'La Jolla, CA'),
#  ('rajo19', None),
#  ('bhack', None),
#  ('praateekmahajan', 'San Francisco, California'),
#  ('spate141', 'Chicago'),
#  ('AayushSameerShah', 'Bhuj — Ahmedabad'),
#  ('Lassehhansen', 'Aarhus'),
#  ('ad6398', 'New York'),
#  ('lyriccoder', None),
#  ('rubby33', None),
#  ('dimitreOliveira', 'Brazil'),
#  ('creat89', 'Paris, France'),
#  ('vkaul11', None),
#  ('efeiefei', 'Beijing'),
#  ('nvs-abhilash', 'Bangalore, India'),
#  ('nabito', 'Tokyo, Japan'),
#  ('xixiaoyao', 'Beijing, China'),
#  ('cstorm125', 'Nakhon Nayok'),
#  ('lyan62', None),
#  ('hemingkx', 'Hong Kong, China'),
#  ('arain60gb', None),
#  ('yushao2', 'Singapore'),
#  ('BayanIssa', None),
#  ('JueXiuHuang', None),
#  ('gomerudo', 'Mexico City'),
#  ('gustavengstrom', None),
#  ('angelorodem', 'Brazil'),
#  ('pierre-si', 'London, United Kingdom'),
#  ('joelgrus', 'Boerne, TX'),
#  ('ameet-1997', None),
#  ('Liuxiaowang123', None),
#  ('trexanhvnn', None),
#  ('zxv', None),
#  ('sharpant', None),
#  ('mingyang3github', 'Raleigh, NC'),
#  ('DecstionBack', None),
#  ('divyanshu16', 'Gurugram'),
#  ('mirth', None),
#  ('biro-mark', None),
#  ('Arsmart123', None),
#  ('metemadi', None),
#  ('spigo900', None),
#  ('mazicwong', 'China'),
#  ('jaanli', 'Brooklyn'),
#  ('bsmhmmlf', 'Heifei, Anhui, China'),
#  ('pelegb', None),
#  ('ngoyal2707', None),
#  ('ceatlinar', None),
#  ('steffenvan', 'Zürich, Switzerland'),
#  ('ultrons', 'Santa Clara, CA'),
#  ('yyanhan', None),
#  ('xiaowaiii', None),
#  ('chitkwan', None),
#  ('cabal-daniel', None),
#  ('clmnt', 'New York'),
#  ('dongdongyang-houzz', None),
#  ('kishorekumar1505028', None),
#  ('smiles724', None),
#  ('giuliorav', 'Milan, Italy'),
#  ('cservan', None),
#  ('michaelomahony-edgetier', None),
#  ('hui-po-wang', 'Saarbrucken, Germany'),
#  ('RikVN', None),
#  ('hamelsmu', 'Portland, OR'),
#  ('taesikna', 'Atlanta, GA'),
#  ('ShivaleelaH', None),
#  ('Neptune-Trojans', 'Tel Aviv - Israel'),
#  ('tchaton', 'London'),
#  ('SunYanCN', 'BeiJing'),
#  ('RakshaAg', None),
#  ('haozheji', 'Beijing, China'),
#  ('umairahmad-ua', None),
#  ('harupy', 'Japan'),
#  ('LeiYangJustin', 'HKSAR, China'),
#  ('Dirkster99', 'Munich, Germany'),
#  ('oobabooga', None),
#  ('k141303', 'Japan'),
#  ('skpig', 'Beijing, China'),
#  ('LifaSun', None),
#  ('sourabhdattawad', None),
#  ('Guidofaassen', None),
#  ('ccoay', None),
#  ('deepanwayx', 'Singapore'),
#  ('fferlito', 'Spain'),
#  ('pb6192', None),
#  ('SlinZhang', 'HangZhou'),
#  ('morganmcg1', 'Dublin, Ireland'),
#  ('FelipeAlb94', None),
#  ('schipiga', 'Tallinn'),
#  ('qwu01', None),
#  ('vuiseng9', None),
#  ('sinboyxx', None),
#  ('MaxGodTier', None),
#  ('KombangkoeDias', None),
#  ('kyxyxn', None),
#  ('StuartMesham', 'London, UK'),
#  ('Rachnas', None),
#  ('TobiGiese', None),
#  ('syu0000', None),
#  ('varun-tandon', None),
#  ('conan1024hao', 'Tokyo'),
#  ('HenryMaguire', 'London, UK'),
#  ('MesumRaza', 'Pakistan'),
#  ('sr5434', 'USA'),
#  ('astrocronopio', 'email me @ evecoronel.com'),
#  ('MatejUlcar', None),
#  ('jontypage', None),
#  ('vikramtharakan', 'San Francisco, CA'),
#  ('suliuzh', None),
#  ('rihabfounoun', 'CASABLANCA'),
#  ('tejavenkat473', None),
#  ('abdulsalam-bande', 'Istanbul'),
#  ('lcswillems', 'Paris, France'),
#  ('jorabara', None),
#  ('melaniebeck', 'Minneapolis, MN'),
#  ('mamun3600', None),
#  ('aolko', None),
#  ('benschreiber', 'Santa Clara, CA'),
#  ('ProSurfer73', 'France'),
#  ('vanh17', 'Boston, MA'),
#  ('PeijinV5', None),
#  ('ACForward', None),
#  ('fdugzc', 'Shanghai'),
#  ('Abdulrahman-Yasser', 'Egypt, Cairo'),
#  ('ChinaLinZhen', None),
#  ('saurabhLinqia', None),
#  ('akshayudnur', 'Pune'),
#  ('iandanforth-alation', None),
#  ('tuner007', None),
#  ('korymath', 'Montreal, Canada'),
#  ('ArtanisTheOne', 'Globe'),
#  ('liuhoward', None),
#  ('moseshu', None),
#  ('SouravDutta91', 'Dortmund, Germany'),
#  ('DeepFool', 'beijing'),
#  ('zhanwenchen', 'Charlottesville, VA'),
#  ('Demetrio92', None),
#  ('cdpierse', 'Ireland'),
#  ('cloudyskyy', 'Nanjing, China'),
#  ('2hip3ng', 'Beijing, China'),
#  ('joshpxyne', 'Stanford, CA'),
#  ('gpucce', None),
#  ('lyutovad', 'Moscow'),
#  ('binhna', 'Vietnam'),
#  ('RZinman', None),
#  ('MantasLukauskas', 'Kaunas'),
#  ('FlorinAndrei', 'California'),
#  ('luofuli', None),
#  ('gajeshladhar', None),
#  ('AprilSongRits', None),
#  ('gamebird96', None),
#  ('learnercat', None),
#  ('Mozen', None),
#  ('girijesh97', None),
#  ('MarkusSagen', 'Stockholm, Sweden'),
#  ('priyankarasakonda', None),
#  ('louisabraham', 'Paris'),
#  ('HuXiangkun', 'Shanghai'),
#  ('maschasap', None),
#  ('beyondbeneath', None),
#  ('GaussianNeurons', None),
#  ('0xEdgar', '☁️'),
#  ('ck37', 'Boston, MA'),
#  ('hungph-dev-ict', None),
#  ('shivamakhauri04', None),
#  ('hlynurd', None),
#  ('fcakyon', 'Ankara, Turkiye'),
#  ('toomtobias', 'Sweden'),
#  ('libing125', None),
#  ('plageon', 'Haidian District, Beijing'),
#  ('carlose2108', 'Santiago de Chile'),
#  ('ShuGao0810', None),
#  ('oshindow', 'Singapore'),
#  ('kimcando', None),
#  ('krstp', 'K2-18b'),
#  ('ledaat', None),
#  ('krahnikblis', None),
#  ('tobyych', None),
#  ('ramsrigouthamg', 'Hyderabad, India'),
#  ('HamidShojanazeri', 'Bay Area'),
#  ('anitaj-j', None),
#  ('jerry1993-tech', 'chendu'),
#  ('KChalk', None),
#  ('Puranjay-del-Mishra', 'Buffalo, New York'),
#  ('ssriram1978', 'Westford, MA'),
#  ('PanQiWei', 'Shanghai'),
#  ('wfangtw', 'Cambridge, MA, USA'),
#  ('CaesarWWK', 'Shanghai'),
#  ('krzysztoffiok', None),
#  ('suyashhchougule', None),
#  ('volosincu', 'Iași, România'),
#  ('SimplyJuanjo', 'Abu Dhabi, UAE'),
#  ('klyuhang9', None),
#  ('MajaRolevski', None),
#  ('MathewPerez', None),
#  ('roymondliao', 'Taiwan'),
#  ('ankandrew', None),
#  ('Martine307', None),
#  ('akornilo', None),
#  ('boyleconnor', 'Seattle'),
#  ('dmytyar', "L'viv, Ukraine"),
#  ('pablorp80', 'United States'),
#  ('BrandonLiang', 'New York'),
#  ('avacariu', 'Vancouver, Canada'),
#  ('tetsu9923', None),
#  ('crisz', 'Palermo'),
#  ('roetezadi', 'Canada'),
#  ('yuhui-zh15', 'Stanford'),
#  ('saeedrafieyan', 'Tehran'),
#  ('OliVinz', 'Glasgow'),
#  ('michaelroyzen', 'San Francisco'),
#  ('pranavpawar3', 'San Francisco, CA'),
#  ('viva2202', None),
#  ('thaitrinh', None),
#  ('mrtoronto', None),
#  ('leng-yue', 'Mountain View'),
#  ('rumeshmadhusanka', None),
#  ('harshavardhanpinnapureddy', None),
#  ('kuchenrolle', None),
#  ('MilesQLi', 'Montreal, Canada'),
#  ('chirico85', None),
#  ('rclough', 'New York, NY'),
#  ('gstranger', 'Portland'),
#  ('Linyxus', 'Wuxi, China'),
#  ('Nishitha-GK', None),
#  ('Ahmedniz1', 'Cottbus Germany'),
#  ('matin-amiri', None),
#  ('jonnyzhang02', 'Beijing'),
#  ('hairzooc', None),
#  ('lindan1128', 'New York'),
#  ('superRookie007', None),
#  ...}

# %%
nodes_df_updated = pd.DataFrame(nodes, columns=['id', 'location'])

# %%
nodes_df_updated
# Out:
#                  id              location
# 0            LianaN     Spain (Barcelona)
# 1       aclifton314                  None
# 2     HuangZhenyang                  None
# 3         shijie-wu          Bethesda, MD
# 4         wasiahmad  Santa Clara, CA, USA
# ...             ...                   ...
# 9379          AI678                  None
# 9380      hrdxwandg              shanghai
# 9381    13015517713                    广州
# 9382         Rizhiy            London, UK
# 9383      HaokunLiu                  None
#
# [9384 rows x 2 columns]

# %%
# Update the location column using the df's mapping for unclean location names
# Create a lookup dictionary from df
location_to_country = df.set_index('location')['country'].to_dict()
nodes_df_updated['country'] = nodes_df_updated['location'].map(location_to_country)

# %%
nodes_df_updated.head()
# Out:
#               id              location        country
# 0         LianaN     Spain (Barcelona)          Spain
# 1    aclifton314                  None            NaN
# 2  HuangZhenyang                  None            NaN
# 3      shijie-wu          Bethesda, MD  United States
# 4      wasiahmad  Santa Clara, CA, USA  United States

# %%
n_df = nodes_df_updated.drop('location', axis=1)

# %%
n_df.to_csv('/home/chef/src/DAT6003/data/network/nodes_locations.csv', index=False)

# %%
comment_issue_data = [
    issue for issue in issues_data 
    if "comments" in issue and len(issue["comments"]["nodes"]) > 0
]

print(f"Filtered out {len(issues_data) - len(comment_issue_data)} issues.")
# Out:
# Filtered out 439 issues.

# %%
# re-get nodes from new data
nodes = []

for issue in comment_issue_data:
    if issue['author'] == {} or issue['author'] is None:
        continue
    else:
        nodes.append((issue['author']['login'], issue['author'].get('location')))

    if "comments" in issue and len(issue["comments"]["nodes"]) > 0:
        for comment in issue["comments"]["nodes"]:
            if comment['author'] == {}:
                continue
            author = comment.get('author')
            if author and 'login' in author:
                nodes.append((author['login'], author.get('location')))

nodes = set(nodes)
len(nodes)
# Out:
# 9278

# %%
nodes_df_updated = pd.DataFrame(nodes, columns=['id', 'location'])
nodes_df_updated.head()
# Out:
#               id              location
# 0         LianaN     Spain (Barcelona)
# 1    aclifton314                  None
# 2  HuangZhenyang                  None
# 3      shijie-wu          Bethesda, MD
# 4      wasiahmad  Santa Clara, CA, USA

# %%
nodes_df_updated['country'] = nodes_df_updated['location'].map(location_to_country)
n_df = nodes_df_updated.drop('location', axis=1)
n_df.to_csv('/home/chef/src/DAT6003/data/network/nodes2.csv', index=False)
